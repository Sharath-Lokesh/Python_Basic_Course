# %% [markdown]
# # Python Assignment: Module 7 - Object-Oriented Programming (Capstone)
#
# This assignment covers classes, objects, `__init__`, `self`, class and instance properties, inheritance, polymorphism, encapsulation, magic methods and inner classes. It also brings back **everything you have learned since Module 0** - strings, collections, operators, conditionals, `match`, loops, functions, scope, decorators, lambda, recursion, generators and files - but always used **inside** classes and objects, never tested on its own.
#
# ## How to use this assignment
# - Answer theory questions in your own words. Add a new markdown cell under the question for your answer.
# - For a Predict question, write your prediction FIRST, then run the code and compare.
# - Questions marked ERROR QUESTION raise an error on purpose. Predict which error appears and explain why.
# - Every code snippet is complete on its own. It does not depend on any earlier question.
#
# ## Before Section C: restart the kernel
# Section C contains scope questions. A variable left over from an earlier cell can silently change the answer. Before starting Section C, use the menu: Kernel, then Restart Kernel.
#
# ## Before Sections I and J: use your practice folder
# A few questions create real files. Keep this notebook inside your practice folder from Module 6 so nothing important is affected.
#
# ## Tool 1: the object state table
# Objects hold data that changes over time, and it is easy to lose track of which object holds what. An object state table has one row per step and one column per property.
#
# **Worked example 1**
#
# ```python
# class Rocket:
#     fleet_size = 0
#
#     def __init__(self, name, fuel):
#         self.name = name
#         self.fuel = fuel
#         Rocket.fleet_size += 1
#
# r1 = Rocket("Ares", 80)
# r2 = Rocket("Orion", 50)
# r1.fuel = 100
# ```
#
# | Step | Line that ran | r1.name | r1.fuel | r2.name | r2.fuel | Rocket.fleet_size |
# |---|---|---|---|---|---|---|
# | 0 | class defined | - | - | - | - | 0 |
# | 1 | `r1 = Rocket("Ares", 80)` | Ares | 80 | - | - | 1 |
# | 2 | `r2 = Rocket("Orion", 50)` | Ares | 80 | Orion | 50 | 2 |
# | 3 | `r1.fuel = 100` | Ares | 100 | Orion | 50 | 2 |
#
# Notice that `fleet_size` has only ONE column. It belongs to the class and is shared, while each object has its own `name` and `fuel`.
#
# ## Tool 2: the attribute lookup table
# When you write `obj.something`, Python searches for `something` in a fixed order, and stops at the first place it finds it. This is the object version of the LEGB rule you learned for scope.
#
# **The search order:** the object itself, then its class, then the parent class, then the grandparent, and so on. If it is found nowhere, Python raises an `AttributeError`.
#
# **Worked example 2**
#
# ```python
# class Spacecraft:
#     engines = 1
#
# class Probe(Spacecraft):
#     target = "Jupiter"
#
# p = Probe()
# p.name = "Juno"
# print(p.engines)
# ```
#
# | Step | Where Python looks | Is `engines` there? | Decision |
# |---|---|---|---|
# | 1 | the object `p` itself | No, it only has `name` | keep searching |
# | 2 | its class `Probe` | No, it only has `target` | keep searching |
# | 3 | the parent class `Spacecraft` | Yes, 1 | STOP - use this |
#
# So it prints 1.
#
# ## Tool 3: the loop trace table (from Module 5)
# Loop questions inside methods use the trace table you already know. For a `while` loop, remember to include the final row where the condition FAILS.
#
# ```python
# fuel = 60
# burns = 0
# while fuel > 20:
#     fuel -= 20
#     burns += 1
# ```
#
# | Pass | fuel at start | Is fuel > 20? | fuel AFTER | burns AFTER |
# |---|---|---|---|---|
# | 1 | 60 | Yes | 40 | 1 |
# | 2 | 40 | Yes | 20 | 2 |
# | 3 | 20 | No - loop stops | 20 | 2 |
#
# ## Difficulty levels
# - **[Core]** is the essential set. Do these first.
# - **[Stretch]** goes deeper.
# - **[Research]** expects you to look something up.
#
# ## Suggested first session
# A1 to A12, B1 to B10, and C1 to C8. The later sections can be spread over several sessions.

# %% [markdown]
# #### Section A: Theory - Object-Oriented Programming - Answer each question in your own words. Add a new markdown cell under this one for your answers.
# 1. [Core] In your own words, what problem does Object-Oriented Programming solve? Use your calculator project and its `global expression` line as your example.
# 2. [Core] Explain the difference between a class and an object using the idea of a blueprint and the things built from it. Give a space example.
# 3. [Core] What does it mean to create an instance of a class? Write the line of code that creates an object called `probe` from a class called `Spacecraft`.
# 4. [Core] What is the `__init__()` method for, and when does it run? Do you ever call it yourself by name?
# 5. [Core] What is `self`? When you write `r1.launch()`, what does Python actually do behind the scenes, and what does `self` become?
# 6. [Core] The name `self` is only a convention. Explain what that means, and why you should still always use it.
# 7. [Core] What is a method? How is it the same as a function you learned in Module 5, and what is the one new rule?
# 8. [Core] Explain the difference between an instance property and a class property. Where is each one created, and who owns it?
# 9. [Core] Some tutorials say that every object gets its own copy of a class property. Explain why that statement is wrong.
# 10. [Core] What is inheritance? Explain what a parent class and a child class are, and why inheritance helps you avoid repeating code.
# 11. [Core] What does `super()` do? Why is `super().__init__(...)` usually better than writing the parent class name directly?
# 12. [Core] What is method overriding? If a child and its parent both have a method called `describe`, which one runs when you call it on a child object?
# 13. [Core] What does polymorphism mean? Explain how one loop can call the same method on many different kinds of object without using any `if` statements.
# 14. [Core] What is encapsulation, and what is it trying to protect? Explain the difference between `name`, `_name` and `__name`.
# 15. [Core] What is name mangling? What does Python actually rename `self.__fuel` to inside a class called `Rocket`?
# 16. [Core] What are getters and setters? Why is a setter a good place to put an `if` statement?
# 17. [Core] What is a magic method? You have used `len()`, `+`, `==`, `in` and `print()` since Module 2. Explain how magic methods are connected to these.
# 18. [Core] What is the difference between `__str__()` and `__repr__()`? Who is each one written for?
# 19. [Stretch] What is an inner class? Give an example of something in space that could sensibly be modelled as a class inside another class.
# 20. [Stretch] Name the four big ideas of OOP: abstraction, encapsulation, inheritance and polymorphism. Write one sentence for each in your own words.
# 21. [Stretch] Explain the difference between `is` and `==` when comparing two objects. When could two objects be `==` but not `is`?
# 22. [Stretch] Almost everything in Python is an object. Give three examples of objects you have used since Module 2, and name one method that belongs to each.

# %% [markdown]
# #### Section B: Classes, Objects, __init__ and self - Predict first, then run and compare. Use object state tables wherever a question provides one.

# %% [markdown]
# Q1. [Core] Predict the output.
# ```python
# class Planet:
#     moons = 0
#
# p = Planet()
# print(p.moons)
# ```

# %% [markdown]
# Q2. [Core] Predict both lines of output.
# ```python
# class Person:
#     def __init__(self, name, age):
#         self.name = name
#         self.age = age
#
# p1 = Person("John", 36)
# p2 = Person("Ada", 12)
# print(p1.name, p1.age)
# print(p2.name, p2.age)
# ```

# %% [markdown]
# Q3. [Core] Predict both lines, and say what `self` refers to on each call.
# ```python
# class Person:
#     def __init__(self, name):
#         self.name = name
#
#     def greet(self):
#         print("Hello, my name is " + self.name)
#
# p1 = Person("John")
# p2 = Person("Ada")
# p1.greet()
# p2.greet()
# ```
#
# | Call | What self refers to | self.name |
# |---|---|---|
# | `p1.greet()` | | |
# | `p2.greet()` | | |

# %% [markdown]
# Q4. [Core] ERROR QUESTION. Predict the error. Then explain what Python tried to pass into the method, and why that caused a problem.
# ```python
# class Person:
#     def greet():
#         print("Hello")
#
# p = Person()
# p.greet()
# ```

# %% [markdown]
# Q5. [Core] Predict the output IN ORDER. One method calls another method through `self`.
# ```python
# class Rocket:
#     def __init__(self, name):
#         self.name = name
#
#     def check(self):
#         print("checking", self.name)
#         return True
#
#     def launch(self):
#         print("launch requested")
#         if self.check():
#             print(self.name, "launched")
#
# Rocket("Ares").launch()
# ```
# Draw the call stack at the moment "checking Ares" is printed.

# %% [markdown]
# Q6. [Core] Predict all three lines. Default values from Module 5 work in `__init__()` too.
# ```python
# class Probe:
#     def __init__(self, name, target="Mars", fuel=100):
#         self.name = name
#         self.target = target
#         self.fuel = fuel
#
# a = Probe("Viking")
# b = Probe("Juno", "Jupiter")
# c = Probe("Rosetta", fuel=40)
# print(a.target, a.fuel)
# print(b.target, b.fuel)
# print(c.target, c.fuel)
# ```

# %% [markdown]
# Q7. [Core] Predict both lines of output.
# ```python
# class Rocket:
#     def __init__(self, name):
#         self.name = name
#
# r1 = Rocket("Falcon")
# r2 = r1
# r2.name = "Atlas"
# print(r1.name)
# print(r1 is r2)
# ```
# How many Rocket objects exist here? Explain why changing `r2` also changed `r1`.

# %% [markdown]
# Q8. [Core] Predict both lines, and compare them with the previous question.
# ```python
# class Rocket:
#     def __init__(self, name):
#         self.name = name
#
# r1 = Rocket("Falcon")
# r2 = Rocket("Falcon")
# print(r1 is r2)
# print(r1.name == r2.name)
# ```

# %% [markdown]
# Q9. [Core] Predict all three lines. This is about printing versus returning, from Module 5.
# ```python
# class Planet:
#     def __init__(self, name):
#         self.name = name
#
#     def show(self):
#         print("Planet:", self.name)
#
#     def label(self):
#         return "Planet: " + self.name
#
# p = Planet("Venus")
# a = p.show()
# b = p.label()
# print(a)
# print(b)
# ```

# %% [markdown]
# Q10. [Core] Predict the output. A list can hold objects, and a loop can call a method on each one.
# ```python
# class Star:
#     def __init__(self, name, mag):
#         self.name = name
#         self.mag = mag
#
#     def describe(self):
#         print(self.name, "has magnitude", self.mag)
#
# stars = [Star("Sirius", -1.46), Star("Vega", 0.03)]
# for s in stars:
#     s.describe()
# ```

# %% [markdown]
# Q11. [Core] ERROR QUESTION. Predict the first line, then the error on the last line.
# ```python
# class Person:
#     def __init__(self, name, age):
#         self.name = name
#         self.age = age
#
# p1 = Person("John", 36)
# p1.age = 40
# print(p1.age)
# del p1.age
# print(p1.age)
# ```

# %% [markdown]
# Q12. [Core] Fill in the object state table, then predict the output.
# ```python
# class Tank:
#     def __init__(self, fuel):
#         self.fuel = fuel
#
#     def fill(self, amount):
#         self.fuel = self.fuel + amount
#
# t1 = Tank(10)
# t2 = Tank(50)
# t1.fill(30)
# t2.fill(5)
# t1.fill(20)
# print(t1.fuel, t2.fuel)
# ```
#
# | Step | Line that ran | t1.fuel | t2.fuel |
# |---|---|---|---|
# | 1 | `t1 = Tank(10)` | | |
# | 2 | `t2 = Tank(50)` | | |
# | 3 | `t1.fill(30)` | | |
# | 4 | `t2.fill(5)` | | |
# | 5 | `t1.fill(20)` | | |

# %% [markdown]
# Q13. [Core] Write a class `Planet` with an `__init__()` that stores a name and a number of moons, and a method `describe()` that prints one sentence about the planet using an f-string. Create three planets and call `describe()` on each.

# %% [markdown]
# Q14. [Core] Write a class `Astronaut` with a name and a mission, and a method `introduce()` that RETURNS a greeting instead of printing it. Store the returned value in a variable and print it.

# %% [markdown]
# Q15. [Stretch] Explain why `print(p)` on an object without a `__str__()` method shows an unhelpful line. Run it, and describe WHAT KIND of information appears rather than the exact text, since the exact text changes every run.

# %% [markdown]
# Q16. [Stretch] Write a class with an `__init__()` that prints a message. Create three objects in a loop and predict how many times the message appears before you run it.

# %% [markdown]
# #### Section C: Object State and Attribute Lookup - This is the priority section. Restart the kernel before you begin. Use the object state table and the attribute lookup table from the top of this notebook.

# %% [markdown]
# Q1. [Core] Predict both lines. Then explain what this proves about class properties.
# ```python
# class MyClass:
#     x = 5
#
# p1 = MyClass()
# p2 = MyClass()
# MyClass.x = 99
# print(p1.x)
# print(p2.x)
# ```

# %% [markdown]
# Q2. [Core] This is the most important bug in this assignment. Fill in the object state table, then predict both lines.
# ```python
# class Rocket:
#     crew = []
#
#     def add(self, name):
#         self.crew.append(name)
#
# r1 = Rocket()
# r2 = Rocket()
# r1.add("Ada")
# print("r1.crew:", r1.crew)
# print("r2.crew:", r2.crew)
# ```
#
# | Step | Line that ran | The list that r1.crew points to | The list that r2.crew points to |
# |---|---|---|---|
# | 1 | `r1 = Rocket()` | | |
# | 2 | `r2 = Rocket()` | | |
# | 3 | `r1.add("Ada")` | | |
#
# How many lists exist in total? Explain why `r2` appears to have a crew member it never added.

# %% [markdown]
# Q3. [Core] Predict both lines, then explain exactly what the fix changed.
# ```python
# class Rocket:
#     def __init__(self):
#         self.crew = []
#
#     def add(self, name):
#         self.crew.append(name)
#
# r1 = Rocket()
# r2 = Rocket()
# r1.add("Ada")
# print("r1.crew:", r1.crew)
# print("r2.crew:", r2.crew)
# ```

# %% [markdown]
# Q4. [Core] Predict all three values.
# ```python
# class MyClass:
#     x = 5
#
# p1 = MyClass()
# p2 = MyClass()
# p1.x = 100
# print(p1.x, p2.x, MyClass.x)
# ```
# Did the assignment change the class property? What did it create instead?

# %% [markdown]
# Q5. [Core] Fill in the attribute lookup table for each print, then predict both lines.
# ```python
# class Sensor:
#     unit = "cm"
#
# s = Sensor()
# s.unit = "mm"
# print(s.unit)
# del s.unit
# print(s.unit)
# ```
#
# | Print | Found on the object itself? | Found on the class? | Value printed |
# |---|---|---|---|
# | first | | | |
# | second | | | |
#
# Explain why deleting the property did not make it disappear completely.

# %% [markdown]
# Q6. [Core] This is a trap. Predict all three numbers.
# ```python
# class Rocket:
#     count = 0
#
#     def __init__(self):
#         self.count += 1
#
# a = Rocket()
# b = Rocket()
# print(Rocket.count, a.count, b.count)
# ```
# Hint: `self.count += 1` means `self.count = self.count + 1`. The right-hand side READS `count` and finds the class property. The left-hand side then ASSIGNS to `self.count`, which creates a new instance property. Explain how this is the same mechanism as a local variable hiding a global variable in Module 5.

# %% [markdown]
# Q7. [Core] Predict both numbers, and explain why this version counts correctly.
# ```python
# class Rocket:
#     count = 0
#
#     def __init__(self):
#         Rocket.count += 1
#
# a = Rocket()
# b = Rocket()
# c = Rocket()
# print(Rocket.count, a.count)
# ```

# %% [markdown]
# Q8. [Core] ERROR QUESTION. Restart the kernel before running this. Predict the error.
# ```python
# class Planet:
#     gravity = 9.8
#
#     def show(self):
#         print(gravity)
#
# Planet().show()
# ```
# The name `gravity` is right there in the class. Explain why the method cannot see it. Hint: the body of a class is NOT one of the four LEGB scopes. A method only reaches class properties through `self.` or through the class name.

# %% [markdown]
# Q9. [Core] This is the hardest scope question in the assignment. Restart the kernel first. Predict both lines.
# ```python
# x = "global"
#
# class Demo:
#     x = "class"
#
#     def show(self):
#         print(x)
#         print(self.x)
#
# Demo().show()
# ```
# Fill in a lookup table for each print.
#
# | Print | Search method | Where x is found | Value printed |
# |---|---|---|---|
# | `print(x)` | LEGB (scope) | | |
# | `print(self.x)` | attribute lookup (object, class, parents) | | |
#
# Why did the two lines give different answers, when both are written inside the same class?

# %% [markdown]
# Q10. [Core] Predict the output.
# ```python
# class Circle:
#     pi = 3.14159
#
#     def __init__(self, radius):
#         self.radius = radius
#
#     def area(self):
#         return Circle.pi * self.radius * self.radius
#
# print(Circle(2).area())
# print(Circle(5).area())
# ```
# Why is it sensible for `pi` to be a class property but `radius` to be an instance property?

# %% [markdown]
# Q11. [Core] Explain in your own words the difference between the LEGB rule (used for plain names like `x`) and attribute lookup (used for names with a dot like `self.x`). When does Python use each one?

# %% [markdown]
# Q12. [Core] Write a class `Satellite` that counts how many satellites have been created using a class property, and gives each satellite its own name as an instance property. Create three and print the count.

# %% [markdown]
# Q13. [Stretch] Write a small class with a class property that is a list. Show the shared-list bug happening, then fix it. Explain the fix in one sentence.

# %% [markdown]
# Q14. [Stretch] Using your understanding of the counter trap, predict what `a.count` would be if you created a fourth Rocket in the trap version above. Explain your answer before checking it.

# %% [markdown]
# Q15. [Stretch] A class property can hold a value that genuinely belongs to every object, such as the speed of light. Give two more examples of values that should be class properties, and two that should be instance properties.

# %% [markdown]
# Q16. [Stretch] [Research] Find out what `vars(obj)` shows. Use it on an object after setting some instance properties, and explain why class properties do not appear in the result.

# %% [markdown]
# #### Section D: Inheritance, super() and Method Lookup - Draw an attribute lookup table whenever a method is found in a parent class. Watch carefully which object self refers to.

# %% [markdown]
# Q1. [Core] Predict the output.
# ```python
# class Person:
#     def __init__(self, fname, lname):
#         self.firstname = fname
#         self.lastname = lname
#
#     def printname(self):
#         print(self.firstname, self.lastname)
#
# class Student(Person):
#     pass
#
# Student("Mike", "Olsen").printname()
# ```
# Where did `printname` come from? Fill in the attribute lookup table.
#
# | Step | Where Python looks for printname | Found? |
# |---|---|---|
# | 1 | the object | |
# | 2 | class Student | |
# | 3 | class Person | |

# %% [markdown]
# Q2. [Core] ERROR QUESTION. Predict the first line of output, and then the error.
# ```python
# class Spacecraft:
#     def __init__(self, name):
#         self.name = name
#
# class Probe(Spacecraft):
#     def __init__(self, name, target):
#         self.target = target
#
# p = Probe("Juno", "Jupiter")
# print(p.target)
# print(p.name)
# ```
# The child defined its own `__init__()`. What happened to the parent's `__init__()`? Which one line would fix this?

# %% [markdown]
# Q3. [Core] Predict both lines of output.
# ```python
# class Person:
#     def __init__(self, fname, lname):
#         self.firstname = fname
#         self.lastname = lname
#
#     def printname(self):
#         print(self.firstname, self.lastname)
#
# class Student(Person):
#     def __init__(self, fname, lname, year):
#         super().__init__(fname, lname)
#         self.graduationyear = year
#
#     def welcome(self):
#         print("Welcome", self.firstname, "to the class of", self.graduationyear)
#
# s = Student("Mike", "Olsen", 2019)
# s.printname()
# s.welcome()
# ```

# %% [markdown]
# Q4. [Core] Predict all three lines.
# ```python
# class Animal:
#     def speak(self):
#         print("Some generic sound")
#
# class Dog(Animal):
#     def speak(self):
#         print("Woof")
#
# class Cat(Animal):
#     def speak(self):
#         print("Meow")
#
# Animal().speak()
# Dog().speak()
# Cat().speak()
# ```

# %% [markdown]
# Q5. [Core] Predict the output. The child extends the parent's method rather than replacing it.
# ```python
# class Rocket:
#     def status(self):
#         print("Rocket systems nominal")
#
# class CrewedRocket(Rocket):
#     def status(self):
#         super().status()
#         print("Crew life support nominal")
#
# CrewedRocket().status()
# ```

# %% [markdown]
# Q6. [Core] Predict the output IN ORDER. This connects inheritance with the call stack from your sequence analysis unit.
# ```python
# class A:
#     def __init__(self):
#         print("A start")
#         print("A end")
#
# class B(A):
#     def __init__(self):
#         print("B start")
#         super().__init__()
#         print("B end")
#
# class C(B):
#     def __init__(self):
#         print("C start")
#         super().__init__()
#         print("C end")
#
# C()
# ```
# Draw the call stack at the moment "A start" is printed.

# %% [markdown]
# Q7. [Core] This is the deepest idea in inheritance. Predict all six lines.
# ```python
# class Mission:
#     def run(self):
#         print("start")
#         self.step()
#         print("end")
#
#     def step(self):
#         print("generic step")
#
# class MarsMission(Mission):
#     def step(self):
#         print("land on Mars")
#
# MarsMission().run()
# Mission().run()
# ```
# The method `run` is written in the PARENT class, yet in the first call it ran the CHILD's `step`. Fill in the table and explain.
#
# | Call | Class whose code is running | What self refers to | Which step() runs |
# |---|---|---|---|
# | `MarsMission().run()` | | | |
# | `Mission().run()` | | | |

# %% [markdown]
# Q8. [Core] Predict both lines. A child can override a class property as well as a method.
# ```python
# class Vehicle:
#     wheels = 4
#
#     def describe(self):
#         print(type(self).__name__, "has", self.wheels, "wheels")
#
# class Bike(Vehicle):
#     wheels = 2
#
# class Car(Vehicle):
#     pass
#
# Bike().describe()
# Car().describe()
# ```

# %% [markdown]
# Q9. [Core] Predict the output.
# ```python
# class Vehicle:
#     def describe(self):
#         print("I am a vehicle")
#
# class Car(Vehicle):
#     pass
#
# class SportsCar(Car):
#     pass
#
# SportsCar().describe()
# ```
# Fill in the lookup table showing each place Python searched before finding `describe`.

# %% [markdown]
# Q10. [Core] Predict all four values.
# ```python
# class Animal: pass
# class Dog(Animal): pass
#
# d = Dog()
# print(isinstance(d, Dog))
# print(isinstance(d, Animal))
# print(issubclass(Dog, Animal))
# print(issubclass(Animal, Dog))
# ```

# %% [markdown]
# Q11. [Core] Write a parent class `Spacecraft` with a name and a `describe()` method, and two child classes `Orbiter` and `Lander` that each override `describe()`. Put one of each in a list and loop over it.

# %% [markdown]
# Q12. [Core] Write a child class `Rover` that inherits from your `Lander`, uses `super().__init__()` to set the name, adds a `max_speed` property, and extends `describe()` using `super().describe()`.

# %% [markdown]
# Q13. [Stretch] Write a three-level chain of classes where each `__init__()` prints a message before and after calling `super().__init__()`. Predict the full output order before running it.

# %% [markdown]
# Q14. [Stretch] Explain why the parent-calls-`self.step()` pattern is powerful. Describe a real program where the parent class decides the ORDER of steps, and each child fills in the details.

# %% [markdown]
# Q15. [Stretch] Explain, using an attribute lookup table, what happens when you call a method that does not exist anywhere in the chain of classes. Which error appears?

# %% [markdown]
# Q16. [Stretch] [Research] Find out what `ClassName.__mro__` shows. Print it for your `SportsCar` class and explain how it matches the lookup tables you have been drawing.

# %% [markdown]
# #### Section E: Polymorphism - Predict first, then run. Notice how the calling code never needs to check what kind of object it has.

# %% [markdown]
# Q1. [Core] Predict the output.
# ```python
# class Car:
#     def __init__(self, brand):
#         self.brand = brand
#     def move(self):
#         print("Drive!")
#
# class Boat:
#     def __init__(self, brand):
#         self.brand = brand
#     def move(self):
#         print("Sail!")
#
# class Plane:
#     def __init__(self, brand):
#         self.brand = brand
#     def move(self):
#         print("Fly!")
#
# for v in (Car("Ford"), Boat("Ibiza"), Plane("Boeing")):
#     print(v.brand)
#     v.move()
# ```
# These classes are not related by inheritance. Why does the loop still work?

# %% [markdown]
# Q2. [Core] Predict both lines.
# ```python
# class Duck:
#     def sound(self):
#         return "Quack"
#
# class Robot:
#     def sound(self):
#         return "Beep"
#
# def make_noise(thing):
#     print(thing.sound())
#
# make_noise(Duck())
# make_noise(Robot())
# ```
# The function never checks what type `thing` is. Explain why that is fine.

# %% [markdown]
# Q3. [Core] ERROR QUESTION. Predict the error.
# ```python
# class Rock:
#     pass
#
# def make_noise(thing):
#     print(thing.sound())
#
# make_noise(Rock())
# ```
# What is the one requirement an object must meet for `make_noise` to work?

# %% [markdown]
# Q4. [Core] Predict all three lines, and explain how this is polymorphism in built-in Python.
# ```python
# print(len("Mars"))
# print(len([1, 2, 3]))
# print(len({"a": 1, "b": 2}))
# ```

# %% [markdown]
# Q5. [Core] Explain why adding a new `Submarine` class with its own `move()` method needs NO change to the loop in question 1. Why is that valuable in a large program?

# %% [markdown]
# Q6. [Core] Write three classes, `Star`, `Planet` and `Comet`, each with a method `info()` that returns a different sentence. Store one of each in a list and print the result of `info()` for all three with a single loop.

# %% [markdown]
# Q7. [Stretch] Rewrite your answer to the previous task WITHOUT polymorphism, using a single function with `if` and `elif` that checks the type of each object. Compare the two versions. Which is easier to extend?

# %% [markdown]
# Q8. [Stretch] Write a `match` statement that decides what to print based on an object's class name, using `type(obj).__name__`. Then explain why polymorphism is usually a cleaner choice than this.

# %% [markdown]
# Q9. [Stretch] Explain the difference between polymorphism through inheritance and polymorphism between unrelated classes. Give one example of each from this assignment.

# %% [markdown]
# #### Section F: Encapsulation - Pay close attention to the exact names that appear in the error messages. They reveal what name mangling is doing.

# %% [markdown]
# Q1. [Core] ERROR QUESTION. Predict the first two lines and then the error.
# ```python
# class Sensor:
#     def __init__(self):
#         self.name = "Accelerometer"
#         self._location = "Lab 2"
#         self.__version = "1.0"
#
# s = Sensor()
# print(s.name)
# print(s._location)
# print(s.__version)
# ```
# Which of the three is protected only by a polite convention?

# %% [markdown]
# Q2. [Core] Predict the output.
# ```python
# class Sensor:
#     def __init__(self):
#         self.__version = "1.0"
#
# s = Sensor()
# print(s._Sensor__version)
# ```
# What does this prove about how private Python's private properties really are?

# %% [markdown]
# Q3. [Core] Predict all four lines.
# ```python
# class Rocket:
#     def __init__(self, fuel):
#         self.__fuel = fuel
#
#     def get_fuel(self):
#         return self.__fuel
#
#     def set_fuel(self, amount):
#         if amount >= 0:
#             self.__fuel = amount
#         else:
#             print("Rejected: fuel cannot be negative")
#
# r = Rocket(50)
# print(r.get_fuel())
# r.set_fuel(120)
# print(r.get_fuel())
# r.set_fuel(-30)
# print(r.get_fuel())
# ```

# %% [markdown]
# Q4. [Core] This one surprises everybody. Predict both lines.
# ```python
# class Rocket:
#     def __init__(self):
#         self.__fuel = 50
#
#     def get_fuel(self):
#         return self.__fuel
#
# r = Rocket()
# r.__fuel = 999
# print(r.get_fuel())
# print(r.__fuel)
# ```
# The outside code tried to change the fuel. Explain why the rocket's real fuel did not change. Hint: name mangling only happens for code written INSIDE the class. Think about what name the private property really has.

# %% [markdown]
# Q5. [Stretch] ERROR QUESTION. Predict the error. Pay close attention to the exact name in the error message.
# ```python
# class Parent:
#     def __init__(self):
#         self.__secret = 42
#
# class Child(Parent):
#     def reveal(self):
#         return self.__secret
#
# print(Child().reveal())
# ```
# Explain why a child class cannot reach its parent's double-underscore property using `self.__secret`.

# %% [markdown]
# Q6. [Core] Write a class `Thermometer` with a private temperature. Add a getter, and a setter that rejects any temperature below absolute zero (-273.15 degrees Celsius) with a message.

# %% [markdown]
# Q7. [Core] Write a class `BankVault` for a space station's supply store, with a private `__supplies` count, a method `deposit(amount)` that only accepts positive numbers, and a method `withdraw(amount)` that refuses to go below zero.

# %% [markdown]
# Q8. [Core] Explain in your own words why encapsulation matters, using the example of a rocket that must never have negative fuel.

# %% [markdown]
# Q9. [Stretch] Explain the difference between `_name` and `__name` in terms of what Python actually does. Which one does Python change, and which one is only a message to other programmers?

# %% [markdown]
# Q10. [Stretch] Write a class where a setter uses a `match` statement to accept only the values `"idle"`, `"armed"` or `"launched"` for a private `__state`, and rejects anything else.

# %% [markdown]
# Q11. [Stretch] [Research] Python also has a decorator called `@property`. Find out what it does, and explain in words how it could replace a getter method. You do not need to use it in code.

# %% [markdown]
# #### Section G: Magic Methods - For each magic method, identify which ordinary piece of syntax triggers it.

# %% [markdown]
# Q1. [Core] Predict the output.
# ```python
# class Planet:
#     def __init__(self, name):
#         self.name = name
#
#     def __str__(self):
#         return "Planet: " + self.name
#
# print(Planet("Mars"))
# ```
# Which magic method did `print()` call?

# %% [markdown]
# Q2. [Core] Predict all three lines.
# ```python
# class Planet:
#     def __init__(self, name):
#         self.name = name
#
#     def __str__(self):
#         return "the planet " + self.name
#
#     def __repr__(self):
#         return "Planet('" + self.name + "')"
#
# p = Planet("Mars")
# print(p)
# print(repr(p))
# print([p])
# ```
# Why did the list show a different version from the first line?

# %% [markdown]
# Q3. [Core] Predict both lines.
# ```python
# class Star:
#     def __init__(self, name):
#         self.name = name
#
# a = Star("Sirius")
# b = Star("Sirius")
# print(a == b)
# print(a.name == b.name)
# ```
# Without `__eq__()`, what is `==` actually comparing?

# %% [markdown]
# Q4. [Core] Predict both lines.
# ```python
# class Star:
#     def __init__(self, name):
#         self.name = name
#
#     def __eq__(self, other):
#         return self.name == other.name
#
# a = Star("Vega")
# b = Star("Vega")
# print(a == b)
# print(a is b)
# ```
# Explain why `==` and `is` now disagree.

# %% [markdown]
# Q5. [Core] Predict both lines.
# ```python
# class Distance:
#     def __init__(self, km):
#         self.km = km
#
#     def __add__(self, other):
#         return Distance(self.km + other.km)
#
# a = Distance(10)
# b = Distance(5)
# c = a + b
# print(c.km, a.km, b.km)
# print(c is a)
# ```
# Did `+` change `a`, or did it make something new?

# %% [markdown]
# Q6. [Core] ERROR QUESTION. Predict the error.
# ```python
# class Distance:
#     def __init__(self, km):
#         self.km = km
#
#     def __add__(self, other):
#         return Distance(self.km + other.km)
#
# d = Distance(5) + 3
# ```
# Explain what `other` was on this call, and why `other.km` failed.

# %% [markdown]
# Q7. [Core] Predict the output.
# ```python
# class Fleet:
#     def __init__(self, ships):
#         self.ships = ships
#
#     def __len__(self):
#         return len(self.ships)
#
# print(len(Fleet(["Orion", "Apollo", "Artemis"])))
# ```

# %% [markdown]
# Q8. [Stretch] Predict both lines. This connects magic methods with conditionals from Module 3.
# ```python
# class Fleet:
#     def __init__(self, ships):
#         self.ships = ships
#
#     def __len__(self):
#         return len(self.ships)
#
# f1 = Fleet([])
# f2 = Fleet(["Orion"])
# print(len(f1), bool(f1), bool(f2))
# if f1:
#     print("f1 has ships")
# else:
#     print("f1 is empty")
# ```
# How did Python decide whether `f1` counts as True or False?

# %% [markdown]
# Q9. [Core] Predict both lines.
# ```python
# class Star:
#     def __init__(self, name, magnitude):
#         self.name = name
#         self.magnitude = magnitude
#
#     def __lt__(self, other):
#         return self.magnitude < other.magnitude
#
#     def __repr__(self):
#         return self.name
#
# stars = [Star("Vega", 0.03), Star("Sirius", -1.46), Star("Polaris", 1.98)]
# print(Star("Vega", 0.03) < Star("Polaris", 1.98))
# print(sorted(stars))
# ```
# Why did `sorted()` suddenly work on your own objects?

# %% [markdown]
# Q10. [Core] Predict both lines.
# ```python
# class Fleet:
#     def __init__(self, ships):
#         self.ships = ships
#
#     def __contains__(self, item):
#         return item in self.ships
#
# f = Fleet(["Orion", "Apollo"])
# print("Orion" in f)
# print("Zeus" in f)
# ```

# %% [markdown]
# Q11. [Core] Predict all three lines.
# ```python
# class Multiplier:
#     def __init__(self, factor):
#         self.factor = factor
#
#     def __call__(self, value):
#         return value * self.factor
#
# double = Multiplier(2)
# triple = Multiplier(3)
# print(double(11))
# print(triple(11))
# print(callable(double))
# ```
# In Module 5 you made a doubler with a function that returned a lambda: `mydoubler = myfunc(2)`. Compare that approach with this class. Which do you find clearer?

# %% [markdown]
# Q12. [Core] Copy this table and fill in the right-hand column.
#
# | Magic method | Python calls it when you write |
# |---|---|
# | `__init__` | |
# | `__str__` | |
# | `__repr__` | |
# | `__eq__` | |
# | `__add__` | |
# | `__len__` | |
# | `__lt__` | |
# | `__contains__` | |
# | `__call__` | |

# %% [markdown]
# Q13. [Core] Write a class `Vector` for a spacecraft's velocity with `x` and `y` properties. Add `__add__()` so two vectors can be added, `__eq__()` so they can be compared, and `__str__()` so they print neatly.

# %% [markdown]
# Q14. [Stretch] Write a class `Constellation` that holds a list of star names. Add `__len__()`, `__contains__()` and `__str__()`, and test all three.

# %% [markdown]
# Q15. [Stretch] Write a class `Planet` with a name and a mass. Add `__lt__()` so that a list of planets can be sorted by mass with `sorted()`, and `__repr__()` so the sorted list prints readably.

# %% [markdown]
# #### Section H: Inner Classes - Predict first, then run.

# %% [markdown]
# Q1. [Core] Predict both lines.
# ```python
# class Rocket:
#     def __init__(self, name, engine_count):
#         self.name = name
#         self.engine = self.Engine(engine_count)
#
#     class Engine:
#         def __init__(self, count):
#             self.count = count
#
#         def describe(self):
#             print("This rocket has", self.count, "engines")
#
# r = Rocket("Falcon Heavy", 27)
# print(r.name)
# r.engine.describe()
# ```
# How many objects exist after `r` is created? Name their classes.

# %% [markdown]
# Q2. [Core] Predict the output.
# ```python
# class Outer:
#     class Inner:
#         def hello(self):
#             print("hello from Inner")
#
# i = Outer.Inner()
# i.hello()
# ```

# %% [markdown]
# Q3. [Core] When is an inner class a sensible choice? Explain using the rocket and engine example.

# %% [markdown]
# Q4. [Core] Write a class `SpaceStation` with an inner class `Module`. The station should create three modules in its `__init__()` and store them in a list. Add a method that prints the name of every module.

# %% [markdown]
# Q5. [Stretch] Explain the difference between an inner class and inheritance. Does an `Engine` inside a `Rocket` inherit anything from `Rocket`?

# %% [markdown]
# #### Section I: OOP Meets Everything Else - Every earlier module appears here, used inside classes. Fill in the trace tables for the loop questions. Keep this notebook in your practice folder, since one question creates a real file.

# %% [markdown]
# Q1. [Core] Loops inside methods. Fill in the trace table, then predict the output.
# ```python
# class Fleet:
#     def __init__(self, fuel_levels):
#         self.fuel_levels = fuel_levels
#
#     def total_fuel(self):
#         total = 0
#         for f in self.fuel_levels:
#             total += f
#         return total
#
# print(Fleet([40, 25, 60]).total_fuel())
# ```
#
# | Pass | f | total BEFORE | total AFTER |
# |---|---|---|---|
# | 1 | | | |
# | 2 | | | |
# | 3 | | | |

# %% [markdown]
# Q2. [Core] A `while` loop inside a method that changes the object. Fill in the trace table, including the row where the condition fails, then predict the output.
# ```python
# class Rocket:
#     def __init__(self, fuel):
#         self.fuel = fuel
#
#     def burn(self):
#         burns = 0
#         while self.fuel > 30:
#             self.fuel -= 25
#             burns += 1
#         return burns
#
# r = Rocket(100)
# print(r.burn(), r.fuel)
# ```
#
# | Pass | self.fuel at start | Is self.fuel > 30? | self.fuel AFTER | burns AFTER |
# |---|---|---|---|---|
# | 1 | | | | |
# | 2 | | | | |
# | 3 | | | | |
# | 4 | | | | |
#
# The loop changed `self.fuel`. Does that change survive after the method returns? Why?

# %% [markdown]
# Q3. [Core] A `match` statement inside a method, together with a string method from Module 2. Predict the output.
# ```python
# class Planet:
#     def __init__(self, name):
#         self.name = name
#
#     def kind(self):
#         match self.name.lower():
#             case "mercury" | "venus" | "earth" | "mars":
#                 return "rocky"
#             case "jupiter" | "saturn":
#                 return "gas giant"
#             case _:
#                 return "unknown"
#
# print(Planet("Earth").kind(), Planet("Saturn").kind(), Planet("Pluto").kind())
# ```

# %% [markdown]
# Q4. [Core] `*args` from Module 5, used in `__init__()`. Predict the output.
# ```python
# class Mission:
#     def __init__(self, name, *crew):
#         self.name = name
#         self.crew = crew
#
# m = Mission("Apollo 11", "Armstrong", "Aldrin", "Collins")
# print(type(m.crew).__name__, len(m.crew), m.crew[0])
# ```

# %% [markdown]
# Q5. [Core] `**kwargs` from Module 5, used in `__init__()`. Predict both lines.
# ```python
# class Planet:
#     def __init__(self, name, **facts):
#         self.name = name
#         self.facts = facts
#
# p = Planet("Mars", moons=2, colour="red")
# print(p.facts)
# print(p.facts["moons"])
# ```

# %% [markdown]
# Q6. [Core] Lambda and `sorted()` from Module 5, used on objects. Predict the output.
# ```python
# class Star:
#     def __init__(self, name, mag):
#         self.name = name
#         self.mag = mag
#
# stars = [Star("Polaris", 1.98), Star("Sirius", -1.46), Star("Vega", 0.03)]
# for s in sorted(stars, key=lambda s: s.mag):
#     print(s.name)
# ```
# This class has no `__lt__()`. How did `sorted()` still know what order to use?

# %% [markdown]
# Q7. [Core] A decorator from Module 5, used on a method. Predict all four lines.
# ```python
# def logged(func):
#     def wrapper(*args, **kwargs):
#         print("calling", func.__name__)
#         return func(*args, **kwargs)
#     return wrapper
#
# class Rocket:
#     def __init__(self, name):
#         self.name = name
#
#     @logged
#     def launch(self, countdown=3):
#         return self.name + " launched after " + str(countdown)
#
# print(Rocket("Ares").launch())
# print(Rocket("Ares").launch(countdown=10))
# ```
# The wrapper uses `*args`. Which value ends up as the first item in `args`, and why is that essential for the method to work?

# %% [markdown]
# Q8. [Core] Recursion from Module 5, inside a method. Predict the output.
# ```python
# class Countdown:
#     def run(self, n):
#         if n == 0:
#             print("Liftoff")
#             return
#         print(n)
#         self.run(n - 1)
#
# Countdown().run(3)
# ```
# What is the base case? Why does the recursive call need `self.` in front of it?

# %% [markdown]
# Q9. [Core] A generator from Module 5, as a method. Predict all three lines.
# ```python
# class Mission:
#     def __init__(self, crew):
#         self.crew = crew
#
#     def roll_call(self):
#         for member in self.crew:
#             yield "Present: " + member
#
# m = Mission(["Ada", "Lin"])
# g = m.roll_call()
# print(type(g).__name__)
# print(next(g))
# for line in g:
#     print(line)
# ```

# %% [markdown]
# Q10. [Core] File handling from Module 6, inside methods. Predict the number printed.
# ```python
# import os
#
# class Log:
#     def __init__(self, filename):
#         self.filename = filename
#
#     def add(self, text):
#         with open(self.filename, "a") as f:
#             f.write(text + "\n")
#
#     def count(self):
#         n = 0
#         with open(self.filename) as f:
#             for line in f:
#                 n += 1
#         return n
#
# if os.path.exists("mission_log.txt"):
#     os.remove("mission_log.txt")
#
# log = Log("mission_log.txt")
# log.add("Launch")
# log.add("Orbit")
# print(log.count())
# ```
# Why does `add` use mode `"a"` rather than `"w"`? What would `count()` return if it used `"w"`?

# %% [markdown]
# Q11. [Core] A method used as a callback, connecting to your calculator's `command=` and to interrupts. Predict the output.
# ```python
# class Counter:
#     def __init__(self):
#         self.clicks = 0
#
#     def click(self):
#         self.clicks += 1
#
# c = Counter()
# handler = c.click
# handler()
# handler()
# handler()
# print(c.clicks)
# ```
# `handler` was called with no arguments, yet the method needs `self`. How did Python know which object to use?

# %% [markdown]
# Q12. [Core] The `math` module from Module 2, inside a method. Predict the output.
# ```python
# import math
#
# class Planet:
#     def __init__(self, radius_km):
#         self.radius_km = radius_km
#
#     def surface_area(self):
#         return round(4 * math.pi * self.radius_km ** 2)
#
# print(Planet(1).surface_area())
# ```

# %% [markdown]
# Q13. [Core] A shorthand if from Module 3, inside `__str__()`. Predict both lines.
# ```python
# class Star:
#     def __init__(self, name, mag):
#         self.name = name
#         self.mag = mag
#
#     def __str__(self):
#         label = "bright" if self.mag < 1 else "faint"
#         return self.name + " (" + label + ")"
#
# print(Star("Sirius", -1.46))
# print(Star("Polaris", 1.98))
# ```

# %% [markdown]
# Q14. [Core] Write a class `Catalogue` that stores a dictionary of star names mapped to magnitudes. Add a method that returns a LIST of the bright stars (magnitude below 1), using a loop and an `if`.

# %% [markdown]
# Q15. [Core] Write a class `Mission` whose `__init__()` takes a name and any number of crew names using `*args`. Add a method that returns a SET of the crew names' first letters, using a loop.

# %% [markdown]
# Q16. [Core] Write a class `Probe` with a method `report(**readings)` that prints each reading on its own line, using `.items()` in a `for` loop.

# %% [markdown]
# Q17. [Stretch] Write a class `Countdown` with a generator method `ticks(start)` that yields from `start` down to 1 and then yields `"Liftoff"`. Use `next()` twice, then a `for` loop for the rest.

# %% [markdown]
# Q18. [Stretch] Write a decorator `announce` that prints the name of any method before it runs, and apply it to two different methods of the same class. Explain why the wrapper must accept `*args` and `**kwargs`.

# %% [markdown]
# Q19. [Stretch] Write a class `Journal` with `save()` and `load()` methods that write its entries to a file and read them back, using the `with` statement. Show that a brand new `Journal` object can load entries saved by an earlier one.

# %% [markdown]
# Q20. [Stretch] Write a recursive method `total(self, index)` that adds up a list stored on the object, starting from a given index. State the base case before you write it.

# %% [markdown]
# #### Section J: Coding Practice - Write and run each class in the cell below the task. Create objects and call their methods to prove your code works.

# %% [markdown]
# Q1. [Core] Write a class `Rocket` with a name and fuel. Add methods `launch()` (only succeeds if fuel is at least 100) and `refuel(amount)`. Create two rockets and show that refuelling one does not affect the other.

# %% [markdown]
# Q2. [Core] Write a class `Star` with a name and a magnitude, and a method `is_bright()` that returns `True` or `False`. Create a list of five stars and print the names of only the bright ones.

# %% [markdown]
# Q3. [Core] Write a class `Planet` that stores a name and a list of moons. Add a method `add_moon(name)` and a method `moon_count()`. Make sure each planet has its own separate list.

# %% [markdown]
# Q4. [Core] Write a class `Calculator` that stores its expression as an instance property, with methods `press(value)`, `clear()` and `show()`. Create two calculators and prove they do not interfere. Explain why this design needs no `global`.

# %% [markdown]
# Q5. [Core] Write a parent class `CelestialBody` with a name and a `describe()` method, and three child classes `Star`, `Planet` and `Moon` that each override `describe()`. Loop over a mixed list and call `describe()` on each.

# %% [markdown]
# Q6. [Core] Write a class `Spacecraft` with a private fuel property, a getter, and a setter that refuses negative values. Show the setter rejecting a bad value.

# %% [markdown]
# Q7. [Core] Write a class `Distance` in kilometres with `__add__()`, `__eq__()`, `__lt__()` and `__str__()`. Create a list of distances and print it sorted.

# %% [markdown]
# Q8. [Core] Write a class `CrewRoster` that stores names in a list and supports `len(roster)`, `name in roster` and `print(roster)` through magic methods.

# %% [markdown]
# Q9. [Core] Write a class with a class property that counts how many objects have been created. Create five objects in a loop and print the count.

# %% [markdown]
# Q10. [Core] Write a class `Telescope` with a method `observe(*targets)` that prints each target it is pointed at, numbered, using a counter variable.

# %% [markdown]
# Q11. [Stretch] Write a class `TemperatureLog` that stores readings in a list and has methods for the highest, lowest and average reading. Do not use `max()`, `min()` or `sum()`.

# %% [markdown]
# Q12. [Stretch] Write a class `Orbit` with a generator method that yields the position of a satellite for each of the next five minutes, given a starting position and a speed.

# %% [markdown]
# Q13. [Stretch] Write a class `Mission` with a method `countdown(n)` that works recursively, and a method `summary()` that returns a string using a shorthand if.

# %% [markdown]
# Q14. [Stretch] Write a class `SignalFilter` with `__call__()` so that an object of it can be used like a function to remove any reading above a limit from a list.

# %% [markdown]
# Q15. [Stretch] Write a class `SaveableStar` with `save(filename)` and a separate function `load_star(filename)` that reads the file back and RETURNS a new `SaveableStar` object built from it.

# %% [markdown]
# Q16. [Stretch] Write two unrelated classes that both have a `summary()` method, and a function that accepts a list of any objects and prints every summary. Explain why this is polymorphism even without inheritance.

# %% [markdown]
# Q17. [Stretch] Write a three-level inheritance chain, `Vehicle`, `Spacecraft` and `Shuttle`, where each level adds one property using `super().__init__()`. Print every property of a `Shuttle` object.

# %% [markdown]
# Q18. [Stretch] Write a class with an inner class, where the outer class creates several inner objects in a loop and stores them in a dictionary keyed by name.

# %% [markdown]
# #### Section K: Capstone Projects - Larger projects that bring the whole course together, including your calculator and your Wokwi circuits.

# %% [markdown]
# Q1. [Core] Solar System Model. Build a class `Planet` with a name, a distance from the Sun in millions of kilometres, and a list of moons. Build a class `SolarSystem` that holds a list of planets and has methods to add a planet, print every planet in order of distance (use `sorted()` with a lambda), and return the planet with the most moons.

# %% [markdown]
# Q2. [Core] Mission Control. Build a parent class `Mission` with a name, a crew list, and a `run()` method that prints a start message, calls `self.launch()`, and prints an end message. Build two child missions that override `launch()` differently. Run both and explain which class's code runs at each step.

# %% [markdown]
# Q3. [Core] Star Catalogue with Files. Build a class `StarCatalogue` that stores stars (name and magnitude), can `save()` them to a text file, can `load()` them back, and has `__len__()` and `__str__()`. Show that saving, creating a new catalogue, and loading gives back the same stars.

# %% [markdown]
# Q4. [Core] Refactor your Calculator. Rewrite your tkinter calculator's `press`, `clear` and `equal` logic as a class, so that `expression` is an instance property and no `global` is needed. Explain in three sentences what changed and why it is better.

# %% [markdown]
# Q5. [Stretch] Wokwi Sensor Class. Design a class `DistanceSensor` for your Raspberry Pi Pico project from Wokwi Assignment 2. It should store its trigger and echo pin numbers, have a `measure()` method, and keep a list of past readings. Write it in Wokwi and test it with the distance slider. Explain why wrapping the sensor in a class is useful.

# %% [markdown]
# Q6. [Stretch] RGB Status Light Class. Design a class `StatusLight` for your RGB LED circuit, with methods `green()`, `yellow()` and `red()`, and a method `show_distance(cm)` that chooses the colour. Combine it with your `DistanceSensor` to rebuild your Distance Traffic Light project using objects.

# %% [markdown]
# Q7. [Stretch] Spacecraft Fleet Manager. Combine inheritance, encapsulation and magic methods: a parent `Spacecraft` with private fuel, children `Probe` and `Shuttle`, `__lt__()` so a fleet can be sorted by fuel, `__str__()` for printing, and a fleet class with `__len__()` and `__contains__()`.

# %% [markdown]
# Q8. [Stretch] Event System. Build a class `Button` that stores a list of callback functions, a method `on_press(func)` to register one, and a method `press()` that calls all of them. Register two normal functions and one bound method. Explain how this connects to your calculator's `command=` and to hardware interrupts.

# %% [markdown]
# Q9. [Stretch] Make it your own. Design a program of your own that uses at least four of: a class property, inheritance, `super()`, encapsulation, a magic method, an inner class, a generator method, a decorator, and file saving. Explain what it does and why you chose each feature.

# %% [markdown]
# Q10. [Core] Reflection. In six sentences, explain to a friend what a class and an object are, what `self` really is, the difference between a class property and an instance property, and what inheritance and polymorphism let you do. Then say which idea from the whole course, Module 0 to Module 7, you now understand best, and which you would still like more practice on.
