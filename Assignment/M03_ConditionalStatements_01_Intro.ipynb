# %% [markdown]
# # Python Assignment — Module 3: Conditional Statements

# %% [markdown]
# #### Theory Questions - Answer in markdown - one cell per answer (question, then your answer in your own words).
# 1. In your own words, what is an `if`, `elif`, and `else` statement used for? Give the syntax for each followed by an example for each.
# 2. The condition inside an `if` must work out to one of only two possible values before Python decides what to do. What are those two values, and what data type are they?
# 3. Why is indentation (the spaces at the start of a line) so important in a Python `if` statement? What does the indentation decide?
# 4. What is the difference between `if` and `elif`? Why is using `elif` better than writing several separate `if` statements when only one option should be chosen?
# 5. What does `else` do? Does `else` need a condition of its own? Explain why or why not.
# 6. What is the difference between `=` and `==`? Which one is used inside an `if` condition, and which one is used to store a value in a variable?
# 7. When Python works out the comparison `temperature >= 100`, it produces a value first, and then the `if` uses that value. What data type is that value?
# 8. Explain in your own words what each of `and`, `or`, and `not` does. Then write one condition (one line each) that uses `and`, one that uses `or`, and one that uses `not`.
# 9. How can the `in` operator be used inside an `if` condition? Give an example that checks whether a planet's name is inside a list of planets.
# 10. The `input()` function always gives you back a value of one particular data type. Which data type is it? If you ask the user for their age and want to compare it as a number inside an `if`, what must you do to it first? Provide a smaple code for this scenario.
# 11. Will the condition `"7" == 7` be True or False? Explain why, using what you know about data types.
# 12. Two thermometers read `15` and `15.0`. Will `15 == 15.0` be True or False? Explain why, using what you know about `int` and `float`.
# 13. What is the difference between writing `if fuel > 50:` and `if fuel >= 50:`? Give one value of `fuel` for which the two conditions give different results.
# 14. In an `if` / `elif` / `elif` / `else` chain, suppose two of the conditions happen to both be True. How many of the code blocks will actually run, and which one?
# 15. Why must there always be a colon `:` at the end of an `if`, `elif`, or `else` line? What kind of problem happens if you forget it?

# %% [markdown]
# #### Predict the Output & Logical Reasoning - Write what each snippet prints, add a short comment on each line, and explain why. For the reasoning questions, you can test your thinking in the empty cell.

# %% [markdown]
# Q1. Predict the output:
# ```python
# fuel = 80
# if fuel >= 100:
#     print("Ready for launch")
# else:
#     print("Need more fuel")
# ```

# %% [markdown]
# Q2. Predict the output:
# ```python
# distance = 778
# if distance < 200:
#     print("Inner planet")
# elif distance < 500:
#     print("Middle zone")
# elif distance < 1000:
#     print("Outer zone")
# else:
#     print("Way out in deep space")
# ```

# %% [markdown]
# Q3. Predict the output:
# ```python
# oxygen = 95
# pressure = 80
# if oxygen > 90 and pressure > 90:
#     print("Cabin is safe")
# else:
#     print("Check the systems")
# ```

# %% [markdown]
# Q4. Predict the output:
# ```python
# is_weekend = False
# is_holiday = True
# if is_weekend or is_holiday:
#     print("Telescope time!")
# else:
#     print("School day")
# ```

# %% [markdown]
# Q5. Predict the output:
# ```python
# storm_warning = False
# if not storm_warning:
#     print("Safe to observe tonight")
# else:
#     print("Stay indoors")
# ```

# %% [markdown]
# Q6. Predict the output:
# ```python
# visible = ["Mars", "Venus", "Jupiter"]
# target = "Saturn"
# if target in visible:
#     print("You can see it tonight")
# else:
#     print("Not visible tonight")
# ```

# %% [markdown]
# Q7. Predict the output:
# ```python
# answer = "MARS"
# if answer.lower() == "mars":
#     print("Correct!")
# else:
#     print("Try again")
# ```

# %% [markdown]
# Q8. Predict the output:
# ```python
# crew = ["Aisha", "Tom", "Lin"]
# if len(crew) >= 3:
#     print("Full crew aboard")
# else:
#     print("Still waiting for crew")
# ```

# %% [markdown]
# Q9. Predict the output:
# ```python
# orbit_number = 7
# if orbit_number % 2 == 0:
#     print("Even orbit")
# else:
#     print("Odd orbit")
# ```

# %% [markdown]
# Q10. Predict the output:
# ```python
# typed_value = "100"
# if typed_value == 100:
#     print("Match")
# else:
#     print("No match")
# ```
# Why does it print what it prints? Think carefully about the data type of `typed_value`.

# %% [markdown]
# Q11. Predict the output:
# ```python
# code = "APOLLO11"
# if code[:6] == "APOLLO":
#     print("Apollo mission detected")
# else:
#     print("Unknown mission")
# ```

# %% [markdown]
# Q12. Predict the output:
# ```python
# planet_moons = {"Earth": 1, "Mars": 2, "Jupiter": 95}
# if planet_moons["Mars"] == 2:
#     print("Phobos and Deimos")
# else:
#     print("Check the data")
# ```

# %% [markdown]
# Q13. Predict the output:
# ```python
# score = 95
# if score >= 50:
#     print("Pass")
# elif score >= 90:
#     print("Excellent")
# else:
#     print("Fail")
# ```
# Even though `95` is greater than `90`, the word "Excellent" never prints. Explain why. What does this teach you about the order of the conditions in an `if` / `elif` chain?

# %% [markdown]
# Q14. Predict the output:
# ```python
# temperature = 15.0
# if temperature == 15:
#     print("Comfortable")
# else:
#     print("Adjust the thermostat")
# ```
# Explain why `15.0 == 15` gives the result it does.

# %% [markdown]
# Q15. Predict the output:
# ```python
# age = 12
# height = 150
# if age >= 10 and height >= 140 or age >= 16:
#     print("Cleared for the flight simulator")
# else:
#     print("Not cleared yet")
# ```
# Hint: Python checks `and` before it checks `or`. Use that to explain your answer.

# %% [markdown]
# Q16. Look at this condition:
# ```python
# if fuel < 50:
#     print("Low fuel")
# ```
# Rewrite the condition so it means *exactly* the same thing, but uses the word `not`.

# %% [markdown]
# Q17. A student writes this, hoping it checks for both "Mars" and "Earth":
# ```python
# if planet == "Mars" or "Earth":
#     print("Rocky planet")
# ```
# Look carefully at each side of the `or`. What is written on the left side? What is written on the right side? Then write the correct condition that is True when `planet` is either "Mars" or "Earth".

# %% [markdown]
# Q18. Suppose `fuel = 50`. Does the block inside `if fuel > 50:` run? Does the block inside `if fuel >= 50:` run? Explain the difference between the two operators in your own words.

# %% [markdown]
# #### Coding Exercises - Write your code in the empty cell below each task and run it. Use only if, elif, and else.

# %% [markdown]
# Q1. Ask the user for their age using `input()`, convert it to a whole number, and use `if` / `else` to print whether they are old enough (16 or over) to join the Junior Program.

# %% [markdown]
# Q2. A space probe reports the surface temperature in degrees Celsius. Start with:
# ```python
# temperature_c = -60
# ```
# Write `if` / `elif` / `else` code that prints `Freezing` when the temperature is below 0, `Cold` when it is from 0 up to 15, and `Comfortable` when it is above 15.

# %% [markdown]
# Q3. Ask the user to type a palnet name. Using a string method, make your check work no matter how they capitalise it (for example `mars`, `Mars`, or `MARS`). Then use `if` / `else` to print whether they typed `Mars`.

# %% [markdown]
# Q4. Start with this list of rocky planets:
# ```python
# planets = ["Mercury", "Venus", "Earth", "Mars"]
# ```
# Ask the user for a planet name, then use the `in` operator inside an `if` / `else` to tell them whether it is one of the four rocky planets.

# %% [markdown]
# Q5. Ask the user for the fuel the rocket needs and the fuel it actually has (two separate inputs). Convert both to decimal numbers, then use `if` / `else` to print whether there is enough fuel. If there is enough, also print how much fuel is left over.

# %% [markdown]
# Q6. Ask the user for an number and convert it to a whole number. Using the `%` operator and `if` / `else`, print whether the number is even or odd.

# %% [markdown]
# Q7. Start with these three readings:
# ```python
# is_fueled = True
# is_crew_ready = True
# is_weather_clear = False
# ```
# Write a single `if` / `else` that prints `LAUNCH` only when all three are True, and `HOLD` otherwise. In a comment, explain why you used `and` and not `or`.

# %% [markdown]
# Q8. A star's brightness is measured by its magnitude --- and here is a real astronomy fact: a *smaller* magnitude means a *brighter* star. Start with:
# ```python
# magnitude = 1.5
# ```
# Write `if` / `elif` / `else` that prints `Very bright` when the magnitude is below 1, `Bright` when it is from 1 up to 3, and `Faint` otherwise.

# %% [markdown]
# Q9. Ask the user for the name of their favourite constellation and store it in a variable. Using `len()` and an `if` / `else`, print one friendly message (using an f-string that includes the name) if the name is longer than 6 letters, and a different message if it is not.

# %% [markdown]
# Q10. Start with this dictionary describing a mission:
# ```python
# mission = {"name": "Artemis", "crew": 4, "ready": True}
# ```
# Write `if` / `else` code that prints `Cleared` when the mission is ready *and* has at least 3 crew members, and `Not cleared` otherwise.

# %% [markdown]
# #### Real-World Coding Scenarios - Bigger mission-style programs. Read the scenario, then build it step by step

# %% [markdown]
# Q1. **Mission Control --- Launch Decision System**
# You are the launch officer, and your program must make the final call.
# - Ask for the fuel level as a percentage and convert it to a number.
# - Ask whether the weather is clear (the user types `yes` or `no`); use a string method so capital or small letters both work.
# - Ask how many crew members are ready and convert it to a whole number.
# - Print `GO FOR LAUNCH` only when the fuel is 90 or more, AND the weather is clear, AND at least 3 crew are ready (use `and`).
# - If the fuel is from 70 up to 89 (and the other checks are fine), print `Fuel low - top up before launch`.
# - In every other case, print `LAUNCH ON HOLD`.
# - Extra challenge: after your decision, use separate `if` statements to print a line for each check that failed (for example, `Weather not clear`).

# %% [markdown]
# Q2. **Exoplanet Habitability Checker**
# Astronomers want to know whether a newly found planet could support life.
# - Ask for the planet's average surface temperature in degrees Celsius and convert it to a decimal number.
# - Ask whether liquid water is present (`yes` or `no`).
# - Print `Possibly habitable!` when the temperature is from 0 up to 50 AND water is present.
# - Print `Right temperature, but no water` when the temperature is from 0 up to 50 but there is no water.
# - Print `Too cold` when the temperature is below 0.
# - Print `Too hot` for anything else.

# %% [markdown]
# Q3. **Mars Rover Battery Manager**
# A Mars rover decides what to do based on how much battery it has left.
# - Ask for the battery level as a percentage and convert it to a whole number.
# - Print `Battery full - explore freely` when it is 80 or more.
# - Print `Battery good - continue mission` when it is from 50 up to 79.
# - Print `Battery low - return to base` when it is from 20 up to 49.
# - Print `Critical - enter sleep mode` for anything lower.
# - Then ask whether it is currently daytime (`yes` or `no`). Using a separate `if` statement, print `Solar panels charging` only when it is daytime.

# %% [markdown]
# ### Bonus Part 1 - must do - Calculator

# %% [markdown]
# **Task 1**: Push the changes to your Calculator repository. The clofder structure must be "Calculator/src/main.py"

# %% [markdown]
# **Task 2**: Insert buttons (can be circular or square) and a display to the current skeleton of the calculator app, at the end of this the app design must be completed and should resemble the ios calculator app. **Use all the tools available to get it done: YouTube, ChatGPT, Gemini etc.**

# %% [markdown]
# **Task 3**: Once the design is ready - understand the complete code (line by line - add a short comment at the end of each line) - push the changes to the calculator repository

# %% [markdown]
# ### Bonus Part 2 - must do

# %% [markdown]
# **Task 1**: What are sensors, actuators and computing systems? Provide an analogy with respect to human body and also with python

# %% [markdown]
# **Task 2**: WHat is a micro-controller? Give few examples. For each example - list the componets/ parts/ pheriperals/ features present in it.

# %% [markdown]
# **Task 3**: What is Wokwi (https://wokwi.com/)? also read this documentation: https://docs.wokwi.com/?utm_source=wokwi
