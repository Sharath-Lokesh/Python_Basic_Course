# %% [markdown]
# # Assignment 1

# %% [markdown]
# ### 1. Which variable names are valid in Python? (Print “valid/invalid” with reasons)
# - age
# - 2cool
# - _planet
# - my-var
# - total_volume
# - class
# - Age
# - first name
#
# ***Hint: Refer Python Variable Naming Rules***

# %% [markdown]
# ### 2. What is the difference between these variable names? (Use print to justify your answer)
# - speed, Speed, SPEED

# %% [markdown]
# ### 3. Match the naming style to the example (Camel / Pascal / Snake): (Use print to display your answer)
# - personName
# - PersonName
# - person_name

# %% [markdown]
# ### 4. What does `type(x)` do? (Do not use print - write your answer in the current cell)
#
#
# your answer goes here
#
#
# ***Hint: Refer to markdown script in Jupyter Notebook***

# %% [markdown]
# ### 5. Naming + readability
#
# **Create variables for:**
# - your student’s name
# - favorite planet
# - age
# - distance to moon (km) (you can pick any number)
#
# **Rules:**
# - Use snake_case for multi-word names.
# - Print them with clear labels.

# %% [markdown]
# ### 6. Case sensitivity mini-test
#
# - Create:
# ```
#     a = 4
#     A = "Sally"
# ```
# - Print both.
# - In one sentence: explain why they are different.

# %% [markdown]
# ### 7. Scope: global vs local (cookie jar test)
# - Goal: See what works inside vs outside a function.
# - Write:
#     - A global variable planet = "Mars" (outside any function)
#     - A function show_planet() that prints "Planet is Mars" using that variable
# - Call the function.
# - Print planet outside the function too.
#
# ***Hint: Briefly understand what are `functions` and `indentation` in python***

# %% [markdown]
# ### 8. Fix the “string + number” problem
# - Write:
# ```
#     age = 12
#     print("I am " + age + " years old")
# ```
# - Observe the error.
# - Fix it, so it prints correctly.
#
# ***Hint: Read about string concatination and type-casting***

# %% [markdown]
# ### 9. Convert input to the right type - add comments
# - Ask the user for their age using input().
# - print the `new_age` after 15 years
# - Print: “After 15 years you will be …”

# %% [markdown]
# ### 10. Identify the following:
# - type, scope and naming style of all the variables used in the program
# - explain what each line of code is doing - answer using comments
# - what will be the expected output of the program

# %%
planet_name = "Mars" 
missionCount = 3
SPEED_OF_LIGHT = 300000

def prepare_report():
    message = "Report: "
    echo = "GO! " * int("2")
    global missionCount
    missionCount = missionCount + int("1")
    report_line = message + planet_name + " " + echo
    print(report_line)

prepare_report()
print("Missions:", missionCount)
print("Speed:", str(SPEED_OF_LIGHT) + " km/s")
