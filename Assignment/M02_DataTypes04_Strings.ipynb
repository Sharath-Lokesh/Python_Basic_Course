# %% [markdown]
# ***Note:*** <br>
# - Complete the previous week's assignment `M02_Git_CLI_Introduction.ipynb`
# - Theory questions must be answered in markdown file - **do not use print statements**

# %% [markdown]
# # Git - should be done via CLI (Command line interface)
# - For this assignment clone the repository `https://github.com/Sharath-Lokesh/Python_Basic_Course.git`
# - Create a new folder called `Solutions`. The contents of this directory must be puhed onto a new bracnh called `Solutions`
# - The contents of this folder - all the previous week's assignment solutions - rename the files to be similar to the file names in the Assignment directory
# - Add descriptive commit messages
# - Note down the commands used - and explain what happens in each command - use markdown and not print statements

# %% [markdown]
# # Strings
# ### Theory Questions
# 1. What is a string in Python?
# 2. Why are strings written inside quotes? How to we declare multiline string?
# 3. What is indexing in strings? Explain negative indexing and positive indexing. Explain the concept of steps in indexing.
# 4. What is slicing?
# 5. What does `len()` do?
# 6. Why do we need escape characters?
# 7. What are f-strings? Explain the need of it.

# %% [markdown]
# ### Coding:
# 1. Write a python code to check if the string is palindrome or not
# 2. Provide an expmple to demostrate identity operator and membership operator.
# 3. Examples for the string methods - refer to `M02_Datatypes02_Strings.ipynb`
# 4. Code to extract `HELLO` and `ASTRONAUT` from `HELLOASTRONAUT`
# 5. String concatenationt
# ```
# Input: <First_Name>, <Last_Name>
# Output: <First_Name> <Last_Name>
#
# example:
# input1: Jonny
# input2: Bravo
#
# output: Jonny Bravo
# ```
# 6. What will be the output of the following code
# ```
# text = "Python"
# print(text[-1])
# print(text[-3:])
# ```
