# %% [markdown]
# # Python Assignment: Module 6 - File Management
#
# Creating, reading, updating and deleting files. Concepts from earlier modules - loops, conditionals, strings, lists, dictionaries, casting and functions - are built into the questions rather than tested separately.
#
# ## Important: these are real files
# Everything you do in this assignment creates, changes or deletes **real files** on your computer. They will appear in the same folder as this notebook.
#
# - Before you start, make a **new empty folder** (for example `module6_practice`) and put this notebook inside it. Then nothing important can be damaged.
# - The `"w"` mode **erases a file completely** before writing to it, and `os.remove()` **deletes a file permanently**. Neither can be undone.
#
# ## Run the setup cell first
# The cell below creates the practice files used throughout this assignment. Run it before Section A.
#
# **Many questions change or delete these files.** Whenever a question tells you to, or whenever an answer looks wrong, scroll back up and **run the setup cell again** to restore the files to their original state.
#
# ## What to hand back
# - Your prediction or answer for every question, plus your working code where a task asks for it.
# - For a Predict question, write your prediction FIRST, then run the code and compare.
# - Questions marked ERROR QUESTION raise an error on purpose. Predict which error appears. You have not broken anything.
#
# ## How to fill in a cursor position table
# A file object remembers **how far through the file it has read**. That position is called the **cursor**. It is invisible, so we write it down.
#
# Suppose `notes.txt` contains exactly `Hello\nWorld\n` (12 characters, counting each newline as one).
#
# **Worked example**
#
# ```python
# f = open("notes.txt", "r")
# print(repr(f.read(4)))
# print(repr(f.readline()))
# f.close()
# ```
#
# | Step | Operation | What it returns | Cursor position after |
# |---|---|---|---|
# | 0 | file just opened | - | 0 |
# | 1 | `f.read(4)` | `'Hell'` | 4 |
# | 2 | `f.readline()` | `'o\n'` | 6 |
#
# Step 2 is the important one. `readline()` did not return the whole first line, because the cursor was already at position 4. It returned only what was **left** of that line.
#
# You can check any cursor position yourself with **`f.tell()`**.
#
# ## Difficulty levels
# - **[Core]** is the essential set. Do these first.
# - **[Stretch]** goes deeper.
# - **[Research]** expects you to look something up.

# %%
# SETUP CELL - run this first, and run it again whenever a question tells you to.
# It creates the practice files and restores them to their original contents.

with open("mission.txt", "w") as f:
    f.write("Apollo 11\n")
    f.write("Apollo 12\n")
    f.write("Apollo 13\n")

with open("readings.txt", "w") as f:
    f.write("120\n")
    f.write("85\n")
    f.write("40\n")
    f.write("15\n")

print("Setup complete.")
print()
print("mission.txt contains:")
with open("mission.txt") as f:
    print(f.read())
print("readings.txt contains:")
with open("readings.txt") as f:
    print(f.read())

# %% [markdown]
# #### Section A: Theory - Files, open() and Modes - Answer each question in your own words. Add a new markdown cell under this one for your answers.
# 1. [Core] Why do we need files at all? Explain the difference between a value stored in a variable and a value stored in a file, thinking about what happens when the program ends.
# 2. [Core] Which built-in function is used to open a file? What two pieces of information does it need?
# 3. [Core] What does `open()` give back to you? What do we normally do with that returned thing?
# 4. [Core] Name the four main file modes and write one short sentence for each saying what it does.
# 5. [Core] Which two modes will raise an error in certain situations? State exactly when each one fails.
# 6. [Core] Which three modes will create a file that does not exist yet?
# 7. [Core] What is the difference between text mode and binary mode? Give one example of a file you would open in each.
# 8. [Core] These two lines do exactly the same thing. Explain why.
#    ```python
#    f = open("demofile.txt")
#    f = open("demofile.txt", "rt")
#    ```
# 9. [Core] What does `close()` do, and why does it matter? Mention what buffering means in your answer.
# 10. [Core] What does the `with` statement do for you that a plain `open()` does not? Write out its general shape.
# 11. [Core] Why is `with` described as safer than remembering to call `close()` yourself? Think about what happens if an error occurs halfway through.
# 12. [Core] Explain the difference between a relative path and an absolute path. Give one example of each.
# 13. [Core] Why should you use forward slashes in a file path in Python, rather than backslashes? What does a backslash normally mean inside a string?
# 14. [Stretch] Which module do you need to import before you can delete a file or a folder? Why is deleting handled by that module rather than by `open()`?
# 15. [Stretch] Explain what a file cursor is, in your own words, and why every file object needs one.
# 16. [Stretch] In Module 5 you learned that a generator remembers where it paused. Explain how a file object is similar. What does each one remember between calls?
# 17. [Core] In Module 5 you learned that a local variable disappears when a function returns. Explain how a file is different, and why that difference is useful.
# 18. [Stretch] Give three examples of real programs that must save data to a file. For each one, say what would go wrong if it could not.

# %% [markdown]
# #### Section B: Modes - What Happens to the File - Several questions here change or destroy the practice files. Re-run the setup cell whenever a question tells you to.

# %% [markdown]
# Q1. [Core] Fill in the file state table. For each mode, say what happens in both situations. Do not run anything yet - answer from what you know.
#
# | Mode | If the file does NOT exist | If the file DOES exist |
# |---|---|---|
# | `"r"` | | |
# | `"a"` | | |
# | `"w"` | | |
# | `"x"` | | |

# %% [markdown]
# Q2. [Core] Predict what is printed. Then run it and check. Afterwards, RE-RUN THE SETUP CELL.
# ```python
# with open("mission.txt", "a") as f:
#     f.write("Artemis 1\n")
#
# with open("mission.txt") as f:
#     print(f.read())
# ```
# How many lines does the file have now?

# %% [markdown]
# Q3. [Core] Predict what is printed. This is the mode that surprises people. Afterwards, RE-RUN THE SETUP CELL.
# ```python
# with open("mission.txt", "w") as f:
#     f.write("Artemis 1\n")
#
# with open("mission.txt") as f:
#     print(f.read())
# ```
# What happened to the three Apollo lines? Compare your answer with the previous question and explain the difference between `"a"` and `"w"` in one sentence.

# %% [markdown]
# Q4. [Core] ERROR QUESTION. Predict which error appears and explain why.
# ```python
# f = open("mission.txt", "x")
# ```

# %% [markdown]
# Q5. [Core] ERROR QUESTION. Predict which error appears and explain why.
# ```python
# f = open("a_file_that_is_not_there.txt", "r")
# ```

# %% [markdown]
# Q6. [Core] Predict what is printed.
# ```python
# with open("newlog.txt", "a") as f:
#     f.write("first line\n")
#
# with open("newlog.txt") as f:
#     print(f.read())
# ```
# The file `newlog.txt` did not exist before. Explain what `"a"` did.

# %% [markdown]
# Q7. [Stretch] ERROR QUESTION. Predict the error. The file exists and the mode is valid, so what is actually wrong?
# ```python
# with open("mission.txt", "r") as f:
#     f.write("oops")
# ```

# %% [markdown]
# Q8. [Core] Predict what is printed.
# ```python
# with open("mission.txt") as f:
#     pass
#
# print(f.closed)
# ```
# Explain what the `with` statement did at the end of its block.

# %% [markdown]
# Q9. [Core] You want to add a new reading to a log file every time your program runs, keeping everything that came before. Which mode do you choose, and why would the other three be wrong?

# %% [markdown]
# Q10. [Core] You want to write a fresh report every time your program runs, replacing yesterday's completely. Which mode do you choose, and why?

# %% [markdown]
# Q11. [Core] You want to create a brand new file, and you want the program to stop with an error if a file of that name already exists, so nothing is ever overwritten by accident. Which mode do you choose?

# %% [markdown]
# Q12. [Stretch] Explain why `"w"` is the most dangerous mode of the four. Describe a situation where using it by mistake would lose someone's work.

# %% [markdown]
# Q13. [Stretch] Using `os.path.exists()` and an `if` statement, describe in words (no code yet) how you could get the safety of `"x"` while still using `"w"`.

# %% [markdown]
# Q14. [Core] Which of the four modes let you READ from the file object once it is open? Which let you WRITE to it?

# %% [markdown]
# Q15. [Stretch] Predict the number that is printed. Most people do not know that `write()` returns anything at all.
# ```python
# with open("out.txt", "w") as f:
#     n = f.write("Hello")
#
# print(n)
# ```
# What do you think that number represents?

# %% [markdown]
# Q16. [Stretch] [Research] There are combined modes such as `"r+"` and `"a+"`. Find out what the plus sign adds, and write one sentence explaining `"r+"`.

# %% [markdown]
# #### Section C: The File Cursor - This is the priority section. Fill in each cursor position table BEFORE running anything, following the worked example at the top of this notebook. Run the setup cell first.

# %% [markdown]
# Q1. [Core] Run the setup cell first. `mission.txt` contains `Apollo 11`, `Apollo 12` and `Apollo 13`, each ending with a newline.
#
# Fill in the cursor position table, then predict all three printed lines.
# ```python
# f = open("mission.txt", "r")
# print(repr(f.read(3)))
# print(repr(f.read(2)))
# print(repr(f.readline()))
# f.close()
# ```
#
# | Step | Operation | What it returns | Cursor position after |
# |---|---|---|---|
# | 0 | file just opened | - | 0 |
# | 1 | `f.read(3)` | | |
# | 2 | `f.read(2)` | | |
# | 3 | `f.readline()` | | |
#
# Step 3 is the interesting one. Explain why `readline()` did NOT return the whole first line.

# %% [markdown]
# Q2. [Core] Check your answers to the previous question using `tell()`. Predict all three numbers first.
# ```python
# f = open("mission.txt", "r")
# print(f.tell())
# f.read(5)
# print(f.tell())
# f.readline()
# print(f.tell())
# f.close()
# ```

# %% [markdown]
# Q3. [Core] Predict the two numbers.
# ```python
# f = open("mission.txt", "r")
# a = f.read()
# b = f.read()
# print(len(a), len(b))
# f.close()
# ```
# Explain why the second `read()` returned what it did. Where was the cursor sitting at that moment?

# %% [markdown]
# Q4. [Core] Predict both printed values.
# ```python
# f = open("mission.txt", "r")
# print(repr(f.read(5)))
# f.seek(0)
# print(repr(f.read(5)))
# f.close()
# ```
# What does `seek(0)` do to the cursor?

# %% [markdown]
# Q5. [Core] Predict what is printed.
# ```python
# f = open("mission.txt", "r")
# f.read()
# print(repr(f.readline()))
# f.close()
# ```
# What does an empty string returned by `readline()` tell you?

# %% [markdown]
# Q6. [Core] Predict what is printed.
# ```python
# f = open("mission.txt", "r")
# f.read()
# print(f.readlines())
# f.close()
# ```
# Explain the result using the cursor.

# %% [markdown]
# Q7. [Core] Predict both printed values.
# ```python
# f = open("mission.txt", "r")
# print(repr(f.readline()))
# print(repr(f.read()))
# f.close()
# ```
# The second line prints everything that is left. Explain what "left" means here.

# %% [markdown]
# Q8. [Core] Fill in the cursor table and predict the output. `readings.txt` contains `120`, `85`, `40` and `15`, each on its own line.
# ```python
# f = open("readings.txt", "r")
# print(repr(f.readline()))
# print(repr(f.readline()))
# print(f.tell())
# f.close()
# ```
#
# | Step | Operation | What it returns | Cursor position after |
# |---|---|---|---|
# | 0 | file just opened | - | 0 |
# | 1 | `f.readline()` | | |
# | 2 | `f.readline()` | | |
# | 3 | `f.tell()` | (prints the position) | |

# %% [markdown]
# Q9. [Core] A student opens a file, loops over it printing every line, and then immediately loops over the same file object a second time. Nothing is printed the second time. Explain why, using the cursor.

# %% [markdown]
# Q10. [Core] Following on from the previous question, describe two different ways to fix it so the second loop works.

# %% [markdown]
# Q11. [Stretch] Explain why counting characters in a file is not the same as counting letters you can see. What invisible characters are also counted?

# %% [markdown]
# Q12. [Stretch] Predict the number that is printed. `readings.txt` contains `120`, `85`, `40` and `15`, each followed by a newline. Count carefully by hand before running it.
# ```python
# with open("readings.txt") as f:
#     print(len(f.read()))
# ```
# Show your working: how many visible characters, and how many newline characters?

# %% [markdown]
# Q13. [Stretch] Compare the file cursor with a generator from Module 5. Both remember a position between calls. Describe one way they are similar and one way they are different.

# %% [markdown]
# Q14. [Core] Why does opening a file with `with` and then opening it again in a second `with` block start reading from the beginning again, while two reads inside the SAME block do not?

# %% [markdown]
# Q15. [Stretch] [Research] `seek()` can take a second argument. Find out what `f.seek(0, 2)` does and describe where it puts the cursor.

# %% [markdown]
# Q16. [Stretch] Write a short program of your own that proves the cursor moves, by printing `tell()` before and after three different read operations. Explain your output.

# %% [markdown]
# #### Section D: Reading Files - Predict the Output - Run the setup cell first so both practice files are in their original state. Predict first, then run and compare.

# %% [markdown]
# Q1. [Core] Run the setup cell first. Predict the output.
# ```python
# with open("mission.txt") as f:
#     print(f.read())
# ```

# %% [markdown]
# Q2. [Core] Predict the output exactly, including the quotes and any `\n` characters.
# ```python
# with open("mission.txt") as f:
#     print(f.readlines())
# ```
# What data type is printed? What is at the end of each item?

# %% [markdown]
# Q3. [Core] Predict the output.
# ```python
# with open("mission.txt") as f:
#     for line in f:
#         print(repr(line))
# ```

# %% [markdown]
# Q4. [Core] Predict the output. Count the blank lines carefully.
# ```python
# with open("mission.txt") as f:
#     for line in f:
#         print(line)
# ```
# Why are there blank lines between the mission names?

# %% [markdown]
# Q5. [Core] Predict the output.
# ```python
# with open("mission.txt") as f:
#     for line in f:
#         print(line.strip())
# ```
# What did `strip()` fix?

# %% [markdown]
# Q6. [Core] Predict the number printed.
# ```python
# count = 0
# with open("mission.txt") as f:
#     for line in f:
#         count += 1
# print(count)
# ```

# %% [markdown]
# Q7. [Core] Predict the number printed. This combines file reading with casting from Module 1.
# ```python
# total = 0
# with open("readings.txt") as f:
#     for line in f:
#         total += int(line)
# print(total)
# ```
# Why is `int()` needed here? What would happen without it?

# %% [markdown]
# Q8. [Core] Predict the output.
# ```python
# with open("mission.txt") as f:
#     lines = f.readlines()
#
# print(len(lines))
# print(lines[0].strip())
# print(lines[-1].strip())
# ```

# %% [markdown]
# Q9. [Stretch] Predict the output.
# ```python
# with open("readings.txt") as f:
#     biggest = 0
#     for line in f:
#         value = int(line)
#         if value > biggest:
#             biggest = value
# print(biggest)
# ```
# Fill in a short trace table showing `value` and `biggest` on each pass.

# %% [markdown]
# Q10. [Stretch] Predict the output.
# ```python
# with open("mission.txt") as f:
#     for line in f:
#         if "12" in line:
#             print("Found:", line.strip())
# ```
# Which Module 2 operator is doing the searching here?

# %% [markdown]
# Q11. [Core] Explain the difference between `read()`, `readline()` and `readlines()` in a table with three rows. For each, give the data type returned.

# %% [markdown]
# Q12. [Core] Why is looping over a file object line by line usually better than calling `read()` on a very large file? Think about memory.

# %% [markdown]
# Q13. [Stretch] `readlines()` and a `for` loop over the file both give you the lines. Describe one advantage of each approach.

# %% [markdown]
# Q14. [Stretch] Predict the output. This uses a dictionary from Module 2.
# ```python
# counts = {}
# with open("mission.txt") as f:
#     for line in f:
#         name = line.strip()
#         counts[name] = len(name)
# print(counts)
# ```

# %% [markdown]
# Q15. [Core] A file's last line has no newline at the end of it. Explain how that would change the result of `readlines()` compared with a file where every line ends in a newline.

# %% [markdown]
# Q16. [Stretch] Write a short program that reads `mission.txt` and prints only the SECOND line, without using `readlines()`. Explain your approach.

# %% [markdown]
# #### Section E: Writing and Creating Files - These questions create and overwrite files. Re-run the setup cell whenever a question tells you to, or whenever a later answer looks wrong.

# %% [markdown]
# Q1. [Core] Predict what the file contains afterwards. Then run it and check with a read.
# ```python
# with open("planets.txt", "w") as f:
#     f.write("Mars")
#     f.write("Venus")
# ```
# Why are the two names stuck together? What is missing?

# %% [markdown]
# Q2. [Core] Predict exactly what is printed, including any `\n`.
# ```python
# with open("planets.txt", "w") as f:
#     f.writelines(["Mars", "Venus", "Earth"])
#
# with open("planets.txt") as f:
#     print(repr(f.read()))
# ```
# Does `writelines()` add newlines for you?

# %% [markdown]
# Q3. [Core] Predict the output.
# ```python
# planets = ["Mercury\n", "Venus\n", "Earth\n"]
#
# with open("planets.txt", "w") as f:
#     f.writelines(planets)
#
# with open("planets.txt") as f:
#     print(f.read())
# ```
# What is different about this list compared with the previous question?

# %% [markdown]
# Q4. [Core] Write a program that saves the four planet names Mercury, Venus, Earth and Mars into a file called `rocky.txt`, one per line, using a `for` loop and `write()`.

# %% [markdown]
# Q5. [Core] Write a program that takes this dictionary and writes one line per entry into `moons.txt`, in the form `Earth has 1 moon(s)`. Use an f-string.
# ```python
# moons = {"Earth": 1, "Mars": 2, "Jupiter": 95}
# ```

# %% [markdown]
# Q6. [Core] Write a program that appends a single new line to `mission.txt` without destroying what is already there, then reads the whole file back and prints it. Afterwards, re-run the setup cell.

# %% [markdown]
# Q7. [Core] Write a program that creates a file called `crew.txt` using the mode that fails if the file already exists. Then run your program a second time and describe what happens.

# %% [markdown]
# Q8. [Core] Write a program that asks the user for their favourite planet and saves the answer to a file, then reads the file back and prints a friendly message using an f-string.

# %% [markdown]
# Q9. [Stretch] Write a program that reads `readings.txt`, and writes a NEW file `report.txt` containing one line per reading in the form `Reading 1: 120 cm`. Use a counter variable for the numbering.

# %% [markdown]
# Q10. [Stretch] Write a program that reads `readings.txt` and writes only the readings below 100 into a file called `close_objects.txt`.

# %% [markdown]
# Q11. [Stretch] Write a program that copies `mission.txt` into a new file `mission_backup.txt`, line by line, without using any copying module.

# %% [markdown]
# Q12. [Stretch] Write a program that reads `mission.txt`, converts every line to UPPERCASE, and writes the result back into the same file. Think carefully about the order of operations, and say why you cannot read and write the file at the same moment in the same `with` block.

# %% [markdown]
# Q13. [Core] Explain in your own words why `write()` does not add a newline automatically. Would it be better if it did? Give one reason for and one against.

# %% [markdown]
# Q14. [Stretch] Predict what the file ends up containing.
# ```python
# with open("log.txt", "w") as f:
#     f.write("line one\n")
#
# with open("log.txt", "w") as f:
#     f.write("line two\n")
#
# with open("log.txt") as f:
#     print(f.read())
# ```
# Explain what the second `with` block did to the first line.

# %% [markdown]
# Q15. [Core] Write a function `save_list(filename, items)` that writes every item of a list to a file, one per line. Test it with a list of planet names.

# %% [markdown]
# Q16. [Stretch] Write a matching function `load_list(filename)` that reads that file back and returns the items as a list, with the newlines removed. Test that saving then loading gives you back what you started with.

# %% [markdown]
# #### Section F: Deleting Files and the os Module - Remember that deleting is permanent. Work only inside your practice folder.

# %% [markdown]
# Q1. [Core] Which module must you import before deleting a file? Write the line of code that imports it.

# %% [markdown]
# Q2. [Core] Which function deletes a file? Write one line showing how you would delete a file called `old_data.txt`.

# %% [markdown]
# Q3. [Core] ERROR QUESTION. Predict the error.
# ```python
# import os
# os.remove("a_file_that_is_not_there.txt")
# ```

# %% [markdown]
# Q4. [Core] Predict both printed values.
# ```python
# import os
# print(os.path.exists("mission.txt"))
# print(os.path.exists("ghost.txt"))
# ```
# What data type does `os.path.exists()` return?

# %% [markdown]
# Q5. [Core] Write a program that deletes `planets.txt` only if it exists, and prints a sensible message either way. Explain why the check is worth doing.

# %% [markdown]
# Q6. [Core] Which function removes a folder? What important restriction does it have?

# %% [markdown]
# Q7. [Stretch] ERROR QUESTION. Predict the error and explain the restriction it demonstrates.
# ```python
# import os
# os.mkdir("folder")
# with open("folder/inside.txt", "w") as f:
#     f.write("something")
# os.rmdir("folder")
# ```

# %% [markdown]
# Q8. [Core] Write a program that creates a folder called `logs`, checks that it exists and prints the result, then removes it and checks again.

# %% [markdown]
# Q9. [Stretch] Deleting with `os.remove()` does not send the file to the recycle bin. Explain what that means for how carefully you should use it.

# %% [markdown]
# Q10. [Stretch] Describe in words how you would write a program that deletes a file only after first copying its contents somewhere safe. Why might that be a sensible habit?

# %% [markdown]
# Q11. [Stretch] [Research] Find out what `os.rename()` does and write one line showing how you would rename `old.txt` to `new.txt`.

# %% [markdown]
# Q12. [Stretch] [Research] Find out what `os.listdir()` returns. Write a short program that prints the name of every file in the current folder.

# %% [markdown]
# #### Section G: Coding Practice - Write and run your code in the cell below each task. Use the with statement throughout.

# %% [markdown]
# Q1. [Core] Write a program that creates a file called `countdown.txt` containing the numbers 10 down to 1, one per line, followed by the word `Liftoff`. Use a loop.

# %% [markdown]
# Q2. [Core] Write a program that reads `countdown.txt` back and prints every line without the newline characters.

# %% [markdown]
# Q3. [Core] Write a program that counts how many lines are in `mission.txt` and prints the count using an f-string.

# %% [markdown]
# Q4. [Core] Write a program that reads `readings.txt` and prints the total, the largest and the smallest reading. Use loops, not the built-in `max()` or `min()`.

# %% [markdown]
# Q5. [Core] Write a program that asks the user for three planet names one at a time and saves all three into `my_planets.txt`, one per line.

# %% [markdown]
# Q6. [Core] Write a program that reads `mission.txt` and prints each mission with a line number in front of it, like `1: Apollo 11`. Use a counter variable.

# %% [markdown]
# Q7. [Core] Write a program that searches `mission.txt` for a word the user types, and prints whether it was found and on which line.

# %% [markdown]
# Q8. [Core] Write a function `line_count(filename)` that returns the number of lines in any file it is given. Test it on both practice files.

# %% [markdown]
# Q9. [Stretch] Write a function `append_entry(filename, text)` that adds one line to a file and returns the new total number of lines. Test it three times in a row.

# %% [markdown]
# Q10. [Stretch] Write a program that reads `readings.txt` and writes a new file containing the same readings sorted from largest to smallest. You may use a list.

# %% [markdown]
# Q11. [Stretch] Write a program that merges `mission.txt` and `readings.txt` into a single file called `combined.txt`, with a heading line before each section.

# %% [markdown]
# Q12. [Stretch] Write a program that reads a file and prints only the lines longer than eight characters, using `len()` and an `if`.

# %% [markdown]
# Q13. [Stretch] Write a function `safe_read(filename)` that returns the contents of a file, or the string `"File not found"` if it does not exist. Use `try` and `except`. Test both cases.

# %% [markdown]
# Q14. [Stretch] Write a program that counts how many times each letter appears across the whole of `mission.txt`, storing the counts in a dictionary and printing it.

# %% [markdown]
# Q15. [Core] Write a program that makes a backup copy of any file, by reading it fully and writing the contents to a new file whose name ends in `_backup.txt`.

# %% [markdown]
# Q16. [Stretch] Write a function that takes a filename and a number, and returns the first that many lines of the file as a list. Handle the case where the file has fewer lines than asked for.

# %% [markdown]
# #### Section H: Real-World Mini Projects - Larger tasks that combine file handling with loops, dictionaries, functions and your earlier projects.

# %% [markdown]
# Q1. [Core] Mission Log. Write a program that appends one new mission entry to `mission_log.txt` each time it runs, including a line number. Run it four times and show the resulting file. Explain which mode you chose and why.

# %% [markdown]
# Q2. [Core] Star Catalogue. Write a program that saves a dictionary of star names and their magnitudes to a file, one star per line, then reads it back and prints only the bright stars (magnitude below 3). Remember that a smaller magnitude means a brighter star.

# %% [markdown]
# Q3. [Core] High Score Table. Write a program that stores scores in a file, adds a new score each time it runs, and prints the highest score so far. Use a loop and casting when reading the scores back.

# %% [markdown]
# Q4. [Stretch] Sensor Data Logger. In your Wokwi assignment you measured distances with the ultrasonic sensor. Write a program that saves a list of distance readings to a file, then reads them back and reports how many were closer than 50 cm. Explain why saving readings to a file is useful for a real space mission.

# %% [markdown]
# Q5. [Stretch] Calculator History. Your calculator project forgot every calculation as soon as it closed. Describe in words, then write the code, for a function that appends each completed calculation to a history file. Which mode must it use, and why would the other modes be wrong?

# %% [markdown]
# Q6. [Stretch] Observation Journal. Build a small program that lets the user add an observation, then view all past observations. No loops are needed for the menu - just handle one action per run.

# %% [markdown]
# Q7. [Stretch] Make it your own. Invent a small program of your own that saves something useful to a file and reads it back later. Describe what it does and why you chose it.

# %% [markdown]
# Q8. [Core] Reflection. In five sentences, explain to a friend what a file is, the difference between the `"a"` and `"w"` modes, and what the file cursor is. Then say which idea in this module surprised you most.
