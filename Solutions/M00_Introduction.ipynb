# %% [markdown]
# ### Add comments - multiline and single line comments - print the following pattern using only print statements
# ```
# *
# * *
# * * *
# * * * *
# * * * * *
# ```

# %%
print("*"), print("* *"), print("* * *"), print("* * * *"), print("* * * * *")
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *
# (None, None, None, None, None)

# %% [markdown]
# ### Add comments - multiline and single line comments - print the following pattern using only print statements
# ```
# * * * * *
# * * * *
# * * *
# * *
# * * *
# * * * *
# * * * * *
# ```

# %%
print ("* * * * *"), print("* * * *"), print("* * *"), print("* *"), print("* * *"), print("* * * *"), print("* * * * *")
# Out:
# * * * * *
# * * * *
# * * *
# * *
# * * *
# * * * *
# * * * * *
# (None, None, None, None, None, None, None)

# %% [markdown]
# ### Add comments - multiline and single line comments
# Take a value (integer) as an input from the user, say 5, the output should be `*****` (5 stars).
# If the input is 12 the output should be (12 stars) `************`
#
# ***Hint:*** Look for string repetition concept

# %%
print("*" *7)
# Out:
# *******

# %%
print("*" *12)
# Out:
# ************
