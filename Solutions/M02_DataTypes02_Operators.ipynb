# %% [markdown]
# ***Before you start this Assignment, make sure you complete the `Bonus section` from the previous assignment***<br>
# -

# %% [markdown]
# **1. What is a Boolean value? Why does Python need Boolean Values? Name the two Boolean values in Python.**

# %%
print("A boolean value is a true or false statement in python, which is needed if a programmer wants to include a true or false function. Two boolean values are true and false")
# Out:
# A boolean value is a true or false statement in python, which is needed if a programmer wants to include a true or false function. Two boolean values are true and false

# %% [markdown]
# **2. What are operators and operands?**

# %%
print("an operator is a mathematical function, such as addition and subtraction. operands are the number that operators support, such as 1 or 2")
# Out:
# an operator is a mathematical function, such as addition and subtraction. operands are the number that operators support, such as 1 or 2

# %% [markdown]
# **3. What are arithmetic operators? List all the arithmetic operators with example.** <br>
# **video link**
# https://youtu.be/GEMZpw7ug-k?si=nIaiUrDXxSll8pYm

# %%
print("An arithmetic operator is one of many symbols that perform a certain mathematical action on operands. All arithmetic operators are addition, unary plus, subtraction, unary minus, multiplication, division, floor division, modulus, and power.")
# Out:
# An arithmetic operator is one of many symbols that perform a certain mathematical action on operands. All arithmetic operators are addition, unary plus, subtraction, unary minus, multiplication, division, floor division, modulus, and power.

# %% [markdown]
# **4. What are comparision operators? List all the arithmetic operators with example.** <br>
# **video link** https://youtu.be/6ZQtBK-dM9c?si=gLZ5r_OjuRi1fc7s

# %%
print("A comparison operator is an operator used to compare two operands, the comparison operators are either greater, or less.")
# Out:
# A comparison operator is an operator used to compare two operands, the comparison operators are either greater, or less.

# %% [markdown]
# **5. What are binary numbers? How do you convert an integer into a binary value (explain the math behind it) and vice versa? How to convert an int into a binary value in python?** <br>
# ***Hint: Watch YouTube Videos***

# %%
print("Binary numbers are ones and zeros, used to better communicate with a computer. to convert an integer to binary, divide by two, and if there is a remainder, that is a binary 1, and if there is not a remainder, that is a binary 0. to convert binary values to an integer, you can multiply each binary digit by 2 to the power of a certain number, or you can use the bin() function.")
# Out:
# Binary numbers are ones and zeros, used to better communicate with a computer. to convert an integer to binary, divide by two, and if there is a remainder, that is a binary 1, and if there is not a remainder, that is a binary 0. to convert binary values to an integer, you can multiply each binary digit by 2 to the power of a certain number, or you can use the bin() function.

# %% [markdown]
# **6. What are Logical operators? Explain why do we need it.** <br>
# **Video Link** https://youtu.be/vNdYpmJt3Qc?si=VBARy0-z6rq7RQjT

# %%
print("Logical operators are operators that the computer has to use general logic to answer. We need this, because these operators allow us to, in a way, ask computers question.")
# Out:
# Logical operators are operators that the computer has to use general logic to answer. We need this, because these operators allow us to, in a way, ask computers question.

# %% [markdown]
# **7. What is the difference between the following logical operators:**
# - or
# - not
# - and

# %%
print("or chooses between two operands, not chooses anything but a certain operand, and 'and' prints multiple operands.")
# Out:
# or chooses between two operands, not chooses anything but a certain operand, and 'and' prints multiple operands.

# %% [markdown]
# **8. What is a memory? How is data stored in the memory? Explain what happens when you assign a value to a variable (with respect to how it is stored in the memory)**
#
# ***Hint: Watch YouTube Videos and ask chat GPT if needed***

# %%
print("A memory is where the computer stores data, using functions like variables. when you assign a value to a variable it is stored in the memory, and each variable, gets its own adress, that another variable cannot overtake.")
# Out:
# A memory is where the computer stores data, using functions like variables. when you assign a value to a variable it is stored in the memory, and each variable, gets its own adress, that another variable cannot overtake.

# %% [markdown]
# **9. What are identity operators? Which two operators are used for identity comparison? Give Example codes and explain them in detail.**
#
# **Video Links** <br>
# part 1: https://youtu.be/nYgIHfYxMD8?si=0GXjmGJzRxfAuBvT
# <br>
# part 2: https://youtu.be/5QzI99Plkqc?si=fJUkRWtML3xqGjnw

# %%
print("identity operators are operators that can identify a variable. the two operators used for this are,is, and is not.")
hello=hi
hi="hola"
print(hello is "hola")
# Out:
# identity operators are operators that can identify a variable. the two operators used for this are,is, and is not.
# True

# %% [markdown]
# **10. What are membership operators? Give an example using the word "Mars".**
#
# **Video Links** <br>
# https://youtu.be/zS_pt7QjpsI?si=487qaFaA1TC8o6Pp

# %%
print("Membership operators check the existence of a certain value in a sequence.")
Mars=a,b,c,d
print(a in Mars)
# Out:
# Membership operators check the existence of a certain value in a sequence.
# True

# %% [markdown]
# **11. What are bitwise operators used for? List all the bitwise operators with example code.**
# **Video Links** <br>
# part 1: https://youtu.be/F_UIOvfmsew?si=kN50dY9uEDemSBNQ
# <br>
# part 2: https://youtu.be/QH0hCFC9LeM?si=Rs148cn-zUu4Ig68

# %% [markdown]
# **12. What is operator precedence? Explain why the following expressions give different answers:**
#
# ```
# 5 + 3 * 2
# (5 + 3) * 2
# ```

# %%
print("operator precedence is the same thing as BODMAS or PEMDAS, as it is an order of operations. If we follow this order, then the results of the equations above are, 11, and 16.")
# Out:
# operator precedence is the same thing as BODMAS or PEMDAS, as it is an order of operations. If we follow this order, then the results of the equations above are, 11, and 16.

# %%
5+3*2
# Out:
# 11

# %%
(5+3)*2
# Out:
# 16

# %% [markdown]
# **13. Predict the Output and explain each line of code and it's results**
#
# ```
# 1.  print(10 + 5 * 2)
# 2.  print(True and False)
# 3.  print(True or False)
# 4.  print(not True)
# 5.  planet = "Mars"
# 6.  print("M" in planet)
# 7.  print("z" in planet)
# 8.  a = 100
# 9.  b = 100
# 10. c = b
# 11. print(a is b)
# 12. print(a is c)
# 13. print(b is c)
# 14. print(c is b)
# ```

# %%
print(10 + 5 * 2)
print(True and False)
print(True or False)
print(not True)
planet = "Mars"
print("M" in planet)
print("z" in planet)
a = 100
b = 100
c = b
print(a is b)
print(a is c)
print(b is c)
print(c is b)
# Out:
# 20
# False
# True
# False
# True
# False
# True
# True
# True
# True

# %%
print("The first line prints the answer to an unsolved math problem, the second line print the words true, and false, the third line gives the comnputer the option to print either true or false, the fourth line prints the opposite of true, False, the fifth line establishes a variable, the sixth line prints whether there is a m in planet or not, the seventh line prints whether there is a z in planet or not, the eighth line establishes a variable, the ninth line establishes a variable, the tenth line line establishes a variable, the eleventh line prints whether the variable a is the same as the variable b, the twelfth line print whether the variable a is equivalent to the variable c, the thirteenth line prints whether the variable b is the same as the variable c, and the fourteenth line prints whether the variable c is the same as the variable b")
print("_____________________________________________________________________________________________________________________")
print("I predict the output of the code will be 20, true, false, false or true, false, true, false, true, true, true, true")
# Out:
# The first line prints the answer to an unsolved math problem, the second line print the words true, and false, the third line gives the comnputer the option to print either true or false, the fourth line prints the opposite of true, False, the fifth line establishes a variable, the sixth line prints whether there is a m in planet or not, the seventh line prints whether there is a z in planet or not, the eighth line establishes a variable, the ninth line establishes a variable, the tenth line line establishes a variable, the eleventh line prints whether the variable a is the same as the variable b, the twelfth line print whether the variable a is equivalent to the variable c, the thirteenth line prints whether the variable b is the same as the variable c, and the fourteenth line prints whether the variable c is the same as the variable b
# _____________________________________________________________________________________________________________________
# ...

# %% [markdown]
# **14. Coding: Space Fuel Calculation**
# - A rocket has: `fuel_tank1 = 50` and `fuel_tank2 = 30`
# - Write the total fuel using an arithmetic operator.
# - Print the result.

# %%
fuel_tank1=50
fuel_tank2=30

print(fuel_tank1+fuel_tank2)
# Out:
# 80

# %% [markdown]
# **15. Coding: Astronaut Eligibility**
# - Define 2 variables `trained` and `medical_clearance` as user input
# - Both the variables are of the type Boolean
# - Use a logical operator to combine these values to check the Astronaut Eligibility.
# - Print the result.

# %%
trained=True
medical_clearance=True

print(medical_clearance and trained)
# Out:
# True

# %% [markdown]
# **16. Coding: Planet Membership**
# - Create a list: `["Mercury", "Venus", "Earth", "Mars"]`
# - Check if "Mars" is inside the list.

# %%
a=["Mercury","Venus","Earth","Mars"]
print("Mars" in a)
# Out:
# True

# %% [markdown]
# **17. Coding: Identity Check**
# ```
# distance1 = 384400
# distance2 = 384400
# ```
# - Check if both variables refer to the same object using an identity operator.
# - If not how to make them to refer to the same object

# %%
distance1 = 384400
distance2 = 384400

print(distance1 is distance2)

distance1=distance2

print(distance1 is distance2)
# Out:
# False
# True

# %% [markdown]
# **18. Coding: Arithmetic**
# Write a program that calculates:
# - Sum
# - Difference
# - Multiplication
# - Division
# <br>
# for the numbers 20 and 5.
# <br>
#
# Print each result.

# %%
a=(20+5)
b=(20-5)
c=(20*5)
d=(20/5)
print(a,b,c,d)
# Out:
# 25 15 100 4.0

# %% [markdown]
# **19. Coding: Operator Precedence Test**
#
# Write a program that prints results for:
# ```
# 8 + 2 * 3
# (8 + 2) * 3
# 20 - 4 * 2
# (20 - 4) * 2
# ```
# Explain why the answers are different.

# %%
print(8 + 2 * 3)
print((8 + 2) * 3)
print(20 - 4 * 2)
print((20 - 4) * 2)
# Out:
# 14
# 30
# 12
# 32

# %%
print("These answers are different, because of computer following the order of operations")
# Out:
# These answers are different, because of computer following the order of operations

# %% [markdown]
# **20. Coding:**
#
# Create variables:
# ```
# astronaut_age = 14
# required_age = 12
#
# planet = "Mars"
# planets = ["Earth", "Mars", "Jupiter"]
#
# fuel_level = 80
# minimum_fuel = 50
#
# ```
# Print results of:
# - astronaut_age >= required_age
# - "Mars" in planets
# - fuel_level > minimum_fuel
# - "Moon" in planet
#
# Explain each result.

# %%
astronaut_age = 14
required_age = 12

planet = "Mars"
planets = ["Earth", "Mars", "Jupiter"]

fuel_level = 80
minimum_fuel = 50
print(astronaut_age >= required_age, "Mars" in planets, fuel_level > minimum_fuel, "Moon" in planet)
# Out:
# True True True False

# %%
print("astronaut_age >= required_age, means that astronaut_age is greater than required_age, as they are both integers, mars in 'planets' means that the string 'Mars' is in the list 'planets', fuel_level > minimum_fuel, meands that the integer 'fuel_level' is greater than the integer'minimum_fuel, and 'Moon' in 'planet' means that the string 'Moon' is not in the variable 'planet'")
# Out:
# astronaut_age >= required_age, means that astronaut_age is greater than required_age, as they are both integers, mars in 'planets' means that the string 'Mars' is in the list 'planets', fuel_level > minimum_fuel, meands that the integer 'fuel_level' is greater than the integer'minimum_fuel, and 'Moon' in 'planet' means that the string 'Moon' is not in the variable 'planet'
