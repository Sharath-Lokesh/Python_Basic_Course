# %% [markdown]
# # Assignment 1

# %% [markdown]
# ### 1. Which variable names are valid in Python? (Print “valid/invalid” with reasons)
# - age
# - 2cool
# - _planet
# - my-var
# - total_volume
# - class
# - Age
# - first name
#
# ***Hint: Refer Python Variable Naming Rules***

# %%
print("age -valid, is a variable name with only letters")
print("2cool -invalid, variables cannot start with numbers")
print("_planet -valid, variables can start with underscores")
print("my-var -invalid, variables cannot have hyphens")
print("total_volume -valid, variables can include underscores")
print("class -valid, is a variable name with only letters")
print("Age -valid, variables can include uppercase letters")
print("first name -invalid, variables cannot have spaces")
# Out:
# age -valid, is a variable name with only letters
# 2cool -invalid, variables cannot start with numbers
# _planet -valid, variables can start with underscores
# my-var -invalid, variables cannot have hyphens
# total_volume -valid, variables can include underscores
# class -valid, is a variable name with only letters
# Age -valid, variables can include uppercase letters
# first name -invalid, variables cannot have spaces

# %% [markdown]
# ### 2. What is the difference between these variable names? (Use print to justify your answer)
# - speed, Speed, SPEED

# %%
print('"speed" is in all lowercase')
print('as variables are case sensitive, "Speed" is a different variable')
print('"SPEED" is in all uppercase')
# Out:
# "speed" is in all lowercase
# as variables are case sensitive, "Speed" is a different variable
# "SPEED" is in all uppercase

# %% [markdown]
# ### 3. Match the naming style to the example (Camel / Pascal / Snake): (Use print to display your answer)
# - personName
# - PersonName
# - person_name

# %%
print('''personName -Camel
PersonName -Pascal
person_name -snake''')
# Out:
# personName -Camel
# PersonName -Pascal
# person_name -snake

# %% [markdown]
# ### 4. What does `type(x)` do? (Do not use print - write your answer in the current cell)
#
#
# type(x) shows the type of variable x is.
#
# ***Hint: Refer to markdown script in Jupyter Notebook***

# %% [markdown]
# ### 5. Naming + readability
#
# **Create variables for:**
# - your student’s name
# - favorite planet
# - age
# - distance to moon (km) (you can pick any number)
#
# **Rules:**
# - Use snake_case for multi-word names.
# - Print them with clear labels.

# %%
your_students_name = "Aditya Avunuri"
favorite_planet = "Jupiter"
age = "eleven"
distance_to_moon = 386243



print("My name is", your_students_name, "and I love", favorite_planet, "because I am", age, "and I am", distance_to_moon, "kilometers from the moon")
# Out:
# My name is Aditya Avunuri and I love Jupiter because I am eleven and I am 386243 kilometers from the moon

# %% [markdown]
# ### 6. Case sensitivity mini-test
#
# - Create:
# ```
#     a = 4
#     A = "Sally"
# ```
# - Print both.
# - In one sentence: explain why they are different.

# %%
a = 4
 A = "Sally"


these two variables are different, because variables are case sensitive.

# %% [markdown]
# ### 7. Scope: global vs local (cookie jar test)
# - Goal: See what works inside vs outside a function.
# - Write:
#     - A global variable planet = "Mars" (outside any function)
#     - A function show_planet() that prints "Planet is Mars" using that variable
# - Call the function.
# - Print planet outside the function too.
#
# ***Hint: Briefly understand what are `functions` and `indentation` in python***

# %%
planet = "Mars"

def show_planet():
    print("Planet is", planet)

show_planet()
# Out:
# Planet is Mars

# %% [markdown]
# ### 8. Fix the “string + number” problem
# - Write:
# ```
#     age = 12
#     print("I am " + age + " years old")
# ```
# - Observe the error.
# - Fix it, so it prints correctly.
#
# ***Hint: Read about string concatination and type-casting***

# %%
age=12

print("I am", + age, "years old")
# Out:
# I am 12 years old

# %% [markdown]
# ### 9. Convert input to the right type - add comments
# - Ask the user for their age using input().
# - print the `new_age` after 15 years
# - Print: “After 15 years you will be …”

# %%
age=input ("what is your current age?")
print(type(age))
age=int(age)
print(type(age))
print("after 15 years you will be",(age)+15)
type(age)
# Out:
# what is your current age? 11
# <class 'str'>
# <class 'int'>
# after 15 years you will be 26
# int

# %% [markdown]
# ### 10. Identify the following:
# - type, scope and naming style of all the variables used in the program
# - explain what each line of code is doing - answer using comments
# - what will be the expected output of the program

# %%
planet_name = "Mars" 
missionCount = 3
SPEED_OF_LIGHT = 300000

def prepare_report():
    message = "Report: "
    echo = "GO! " * int("2")
    global missionCount
    missionCount = missionCount + int("1")
    report_line = message + planet_name + " " + echo
    print(report_line)

prepare_report()
print("Missions:", missionCount)
print("Speed:", str(SPEED_OF_LIGHT) + " km/s")
print(type("mission count"))
# Out:
# Report: Mars GO! GO!
# Missions: 4
# Speed: 300000 km/s
# <class 'str'>

# %%
#the first line is creating a variable, the second line is also creating a variable, and the third line is also creating a variable, the fourth line includes a statement used to define a new function named prepare_report, the fifth line creates a new variable, the sixth line creates a new variable, the seventh line turns the a variable to a global variable, the eighth line alters a current variable, the ninth line creates a new variable, the tenth line inserts the prepare_repirt from before, the eleventh line is a print statement, and the twelth line is a print statement
print("the expected output of this code Report: Mars GO! GO! Missions: 4 Speed: 300000 km/s")
print ("variable 1 is a string, snake case, and global variable, variable 2 is a string, camel case, and a global variable, variable 3 is a string, snake case, and a global variable, variable 4 is a string, and local variable, variable 5 is a local variable, and a string, variable 6 is a string, a camel case, and a global variable, variable 7 is a string, a snake case, and a local variable.")
# Out:
# the expected output of this code Report: Mars GO! GO! Missions: 4 Speed: 300000 km/s
# variable 1 is a string, snake case, and global variable, variable 2 is a string, camel case, and a global variable, variable 3 is a string, snake case, and a global variable, variable 4 is a string, and local variable, variable 5 is a local variable, and a string, variable 6 is a string, a camel case, and a global variable, variable 7 is a string, a snake case, and a local variable.
