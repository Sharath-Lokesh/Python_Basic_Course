# %% [markdown]
# # Assignment on list

# %% [markdown]
# #### Theory Questions - Answers to be written in markdown language
# 1. What is a list in Python? A list is string written in square brackets seperated by commas in order to show multiple items
#
# 2. What is the difference between:
#     - list() constructor
#     - [] (square brackets) In parentheses, it is a tuple, which cannot be changed, but in square brackets, it can be changed later on via command
#
# 3. What does indexing mean in a list? What is the index of the first element in a list? indexing in a list is a way of assigning a numerical value to each digit of a list. the first index is always 0
#
# 4. Write the purpose of the following methods:
#     - append() adds a single value to end of list
#     - insert() adds a single value at a specified position
#     - remove() removes an added value of choice
#     - pop() returns previously removed value
#     - sort() rearranges values in ascending order
#     - reverse() reverses values so that the first becomes the last
# 5. What is the difference between:
#     - remove() and pop()  remove simply takes a value out of the list, meanwhile pop adds a removed value back to the list
#     - append() and extend() append adds one value to the end of a list, meanwhile entend adds as many values as preferred

# %% [markdown]
# #### Predict the output - add comments to each line (explain in brief)

# %% [markdown]
# Q1.
# ```
# planets = ["Earth", "Mars", "Jupiter"]
# planets.append("Saturn")
# print(planets)
# ```

# %%
planets = ["Earth", "Mars", "Jupiter"] #creates a list
planets.append("Saturn") #adds the word Saturn to the list
print(planets) # Prints the final list with Saturn added
# Out:
# ['Earth', 'Mars', 'Jupiter', 'Saturn']

# %% [markdown]
# \Q2.
# ```
# numbers = [10, 20, 30]
# numbers.insert(1, 15)
# print(numbers)
# ```

# %%
numbers = [10, 20, 30] #creates a list
numbers.insert(1, 15) #adds the number 15 at position 1
print(numbers) #prints the list thats was previously made
# Out:
# [10, 15, 20, 30]

# %% [markdown]
# Q3.
# ```
# items = ["pen", "book", "pen", "bag"]
# print(items.count("pen"))
# ```

# %%
items = ["pen", "book", "pen", "bag"] #creates a list
print(items.count("pen")) #Gives the exact index of a specific value
# Out:
# 2

# %% [markdown]
# Q4.
# ```
# values = [5, 2, 9, 1]
# values.sort()
# print(values)
# ```

# %%
values = [5, 2, 9, 1] #creates a list
values.sort() # sorts each value in numerical order
print(values) #prints the previously created list
# Out:
# [1, 2, 5, 9]

# %% [markdown]
# Q5.
# ```
# data = [1, 2, 3, 4]
# data.reverse()
# print(data)
# ```

# %%
data = [1, 2, 3, 4] #creates a list
data.reverse() #alters the list and reverses the list's order
print(data) #prints the list
# Out:
# [4, 3, 2, 1]

# %% [markdown]
# Q6.
# ```
# lst = ["A", "B", "C"]
# lst.pop(1)
# print(lst)
# ```

# %%
lst = ["A", "B", "C"] #creates a list
lst.pop(1) #takes out the digit at index 1
print(lst) #prints the list
# Out:
# ['A', 'C']

# %% [markdown]
# Q7.
# ```
# a = [1, 2, 3]
# b = a
# b.append(4)
# print(a)
# ```

# %%
a = [1, 2, 3] #creates a list
b = a #sorts the list under another variable
b.append(4) #adds the digit 4 to the end of the list
print(a) #prints the list
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# #### Coding Tasks and Logical Reasoning

# %% [markdown]
# Q1.
# ```
# planets = ["Earth", "Mars", "Jupiter"]
# ```
# - add "Saturn" at the end?
# - add "Venus" at index 1?

# %%
planets=["Earth","Mars","Jupiter"]
planets.append("Saturn")
planets.insert(1,"Venus")
print (planets)
# Out:
# ['Earth', 'Venus', 'Mars', 'Jupiter', 'Saturn']

# %% [markdown]
# Q2.
# ```
# tools = ["drill", "hammer", "drill", "wrench"]
# ```
# - Code to find how many times does "drill" appear?

# %%
tools = ["drill", "hammer", "drill", "wrench"] 
count=tools.count("drill")
print (count)
# Out:
# 2

# %% [markdown]
# Q3.
# ```
# a = [1, 2, 3]
# b = a.copy()
# ```
# - If you change b, does a change? Why?
#
# - changing b also changes a, since the code under b makes it so that b and a are the same.

# %% [markdown]
# Q4. Create a list using list constructor
# - Print the list
# - Print the first element
# - Print the last element

# %%
a=["hello","hi","hola"]
print (a)
print (a[0])
print (a[2])
# Out:
# ['hello', 'hi', 'hola']
# hello
# hola

# %% [markdown]
# Q5. Code to reverse the below list using reverse method and without using any list methods
# ```
# fruits = ["apple", "banana", "cherry"]
# ```

# %%
fruits=["apple", "banana", "cherry"]
fruits.reverse()
print (fruits)
# Out:
# ['cherry', 'banana', 'apple']

# %%
fruits=["apple", "banana", "cherry"]
fruits=reverse_fruits
reverse_fruits=["cherry","banana","apple"]
print (fruits)
# Out:
# ['cherry', 'banana', 'apple']

# %% [markdown]
# Q6. Create a list of your choice and explain all the list methods with an example

# %%
number = [1,2]; number.append(3)

# %%
choices=["append, extend, pop, remove, reverse, count, sort, insert"]
print (choices)

number = [1, 2]; number.append(3)
print (number)
print("append adds values to end of a list")

nums = [1, 2]; nums.extend([3, 4])
print (nums)
print ("extend adds values of a lists data type to the end of that list")

num= [1, 3]; num.insert(1, 2)
print (num)
print ("insert adds a certain value at a specific index")

nom = [1, 2, 1]; nom.remove(1)
print (nom)
print ("remove removes a certain value in a list")

no = [1, 2, 3]; no.pop(1)
print (no)
print ("pop removes and returns a specified value in a list")


n = [1, 2, 1, 1]; n.count(1)
print (n)
print ("count counts the characters in a list")

numb = [3,1,2]; numb.sort()
print (numb)
print ("sort sorts values in a string in an order such as numerical order")

numberr = [1, 2, 3]; numberr.reverse()
print (numberr)
print ("reverse reverses the values in a list")
# Out:
# ['append, extend, pop, remove, reverse, count, sort, insert']
# [1, 2, 3]
# append adds values to end of a list
# [1, 2, 3, 4]
# extend adds values of a lists data type to the end of that list
# [1, 2, 3]
# insert adds a certain value at a specific index
# [2, 1]
# remove removes a certain value in a list
# [1, 3]
# pop removes and returns a specified value in a list
# [1, 2, 1, 1]
# count counts the characters in a list
# [1, 2, 3]
# sort sorts values in a string in an order such as numerical order
# [3, 2, 1]
# reverse reverses the values in a list

# %% [markdown]
# #### Bonus - must do

# %% [markdown]
# Q1. What is the difference between `.py` and `.ipynb` files? When do we use them? <br>
# Q2. Understand `Tkinter` python module. What and Why?

# %% [markdown]
# .py files are used for ordinary files with python code in them, meanwhile .ipynb files are used for files containing python code in jupyter notebook.
#
# Tkinter is a built in python library used to create graphical user interfaces. this is good  to have, as it makes designing GUI's easier.
