# %% [markdown]
# # Python Assignment: Module 5 - Functions, Part 1
#
# Functions, return values, arguments, and the flexible argument forms `*args` and `**kwargs`. This assignment also contains a large section on tracing loops, so that you can follow exactly how a value changes on every single pass.
#
# ## How to use this assignment
# - Answer theory questions in your own words. Add a new markdown cell under the question for your answer.
# - For a Predict question, write your prediction FIRST, then run the code to check it. Being wrong and finding out why is the point.
# - For a coding task, write and run your code in the cell below the question.
# - Some questions deliberately cause an error. When a question says so, your job is to predict WHICH error appears and read the message. You have not broken anything.
#
# ## Section C is the priority section
# Section C teaches you how to trace a loop: how to follow a value as it changes on each pass. Work through it slowly. It is the most useful skill in this whole assignment.
#
# ## How to fill in a trace table
# A trace table has one row for each pass of the loop and one column for each variable that changes. You fill it in one row at a time, in order. You may type into the table in the markdown cell, or draw it on paper and photograph it.
#
# **Worked example 1 - a `for` loop**
#
# ```python
# def add_all(numbers):
#     total = 0
#     for num in numbers:
#         total += num
#     return total
#
# print(add_all([5, 2, 4]))
# ```
#
# Before the loop starts, `total` is 0. Now take it one pass at a time:
#
# | Pass | num | total BEFORE | total AFTER |
# |---|---|---|---|
# | 1 | 5 | 0 | 5 |
# | 2 | 2 | 5 | 7 |
# | 3 | 4 | 7 | 11 |
#
# The list has run out, so the loop stops and the function returns 11.
#
# **Worked example 2 - a `while` loop**
#
# ```python
# i = 1
# total = 0
# while i <= 3:
#     total += i
#     i += 1
# print(total)
# ```
#
# With a `while` loop, always check the condition before each pass:
#
# | Pass | i at start | Is i <= 3? | total AFTER | i AFTER |
# |---|---|---|---|---|
# | 1 | 1 | Yes | 1 | 2 |
# | 2 | 2 | Yes | 3 | 3 |
# | 3 | 3 | Yes | 6 | 4 |
# | 4 | 4 | No - loop stops | 6 | 4 |
#
# So the program prints 6. Notice that the last row is where the condition FAILS, which is what ends the loop.
#
# ## Difficulty levels
# - **[Core]** is the essential set. Do these first.
# - **[Stretch]** goes deeper and is optional. You do not have to finish them all.

# %% [markdown]
# #### Section A: Theory - Functions, Return Values and Arguments - Answer each question in your own words. Add a new markdown cell under this one for your answers.
# 1. [Core] What is a function? Explain in your own words when the code inside a function actually runs.
# 2. [Core] Which keyword is used to create a function, and which keyword sends a value back to the code that called it?
# 3. [Core] Why do functions help you avoid repeating yourself? Give one example where the same calculation is needed several times.
# 4. [Core] Write down the rules for naming a function. How are they similar to the rules for naming a variable?
# 5. [Core] Why must the code inside a function be indented? What does Python use the indentation for?
# 6. [Core] What is the difference between DEFINING a function and CALLING a function? Which one makes the code actually run?
# 7. [Core] What is the difference between a parameter and an argument? Use one short example to show which is which.
# 8. [Core] What does a function return if it has no `return` statement at all? What is the data type of that value?
# 9. [Core] What happens to any lines written AFTER a `return` statement inside a function? Explain why.
# 10. [Core] What is a default parameter value? Show the shape of a function definition that has one, and explain what happens if the caller leaves that argument out.
# 11. [Core] What is the difference between a positional argument and a keyword argument? With which of the two does the ORDER of the arguments matter?
# 12. [Core] A function definition cannot be empty. Which statement do you write inside it if you want to create the function now and fill in the details later?
# 13. [Stretch] What does adding `, /` after some parameters do? Write one sentence describing the rule it enforces.
# 14. [Stretch] What does adding `*,` before some parameters do? Write one sentence describing the rule it enforces.
# 15. [Core] Can a function take a list or a dictionary as an argument? Can a function return a list? Give one short example of each.
# 16. [Core] Explain the order in which Python runs the lines when the main code calls a function. Where does Python go, and where does it come back to?
# 17. [Stretch] The lecture used `def addition(x: int, y: int):`. The `: int` part is called a type hint. What do you think it is telling a human reader, and does it force the value to be a whole number?
# 18. [Stretch] Give one example of a task where writing a function would be overkill, and one where a function is clearly worth it. Explain your reasoning.

# %% [markdown]
# #What is a function?
# A function is a block of code that does a specific job. The code inside it only runs when you call the function.

# %% [markdown]
# #Which keywords are used?
# def creates a function, and return sends a value back.

# %% [markdown]
# #How do functions avoid repetition?
# You can write code once and use it over and over. For example, you could make a function to calculate the area of a rectangle instead of writing length * width every time.

# %% [markdown]
# #Rules for naming a function:
# Function names can use letters, numbers, and underscores. They can't start with a number, have spaces, or be a Python keyword. These rules are basically the same as variable names.

# %% [markdown]
# #Why does the code need to be indented?
# Python uses indentation to know which code belongs inside the function.

# %% [markdown]
# #Defining vs. calling a function:
# Defining means creating the function and telling it what to do. Calling means using the function. The function actually runs when you call it.

# %%
#Parameter vs. argument:
print("A parameter is the name in the function definition. An argument is the actual value you give it.")
print ("_______________")
def greet(name):
    print(name)

greet("Alex")
# Out:
# A parameter is the name in the function definition. An argument is the actual value you give it.
# _______________
# Alex

# %% [markdown]
# #What happens if there is no return?
# The function returns None, which is a NoneType.

# %% [markdown]
# #What happens after return?
# The function stops right away, so any code after return doesn't run.

# %%
#What is a default parameter?
print ("It's a value the function uses automatically if you don't give it one.")

print ("__________")

def greet(name="Guest"):
    print("Hello", name)

greet()
# Out:
# It's a value the function uses automatically if you don't give it one.
# __________
# Hello Guest

# %% [markdown]
# #Positional vs. keyword arguments:
# A positional argument is matched based on where it is:
# greet("Alex")
#
# A keyword argument uses the parameter's name:
# greet(name="Alex")
#
# The order matters for positional arguments, but usually doesn't matter for keyword arguments.

# %%
#A function definition cannot be empty. Which statement do you write inside it if you want to create the function now and fill in the details later?
def my_function():
    pass

# %% [markdown]
# #What does adding , / after some parameters do? Write one sentence describing the rule it enforces.
# Adding , / means the parameters before it must be passed by position, not by name.

# %% [markdown]
# #What does adding *, before some parameters do? Write one sentence describing the rule it enforces.
# Adding *, means the parameters after it must be passed by keyword (name).

# %%
#Can a function take a list or a dictionary as an argument? Can a function return a list? Give one short example of each.
print ("Yes, functions can take lists/dictionaries and return lists.")

def total(numbers):
    return sum(numbers)

    total([1, 2, 3])
    
def get_numbers():
    return [1, 2, 3]
# Out:
# Yes, functions can take lists/dictionaries and return lists.

# %% [markdown]
# #Explain the order in which Python runs the lines when the main code calls a function. Where does Python go, and where does it come back to?
# Python starts with the main code, reaches the function call, then jumps into the function and runs its lines. When the function finishes (or returns), Python goes back to the line after the function call.

# %% [markdown]
# #The lecture used def addition(x: int, y: int):. The : int part is called a type hint. What do you think it is telling a human reader, and does it force the value to be a whole number?
# : int tells a human reader that the parameter is expected to be a whole number. It does not force Python to only accept whole numbers.

# %% [markdown]
# #Give one example of a task where writing a function would be overkill, and one where a function is clearly worth it. Explain your reasoning.
# Writing a function would be overkill for printing “Hello” once, because it's a tiny one-time task. A function is worth it for calculating a student's average, especially if you need to do it for many students, because you can reuse the same code.

# %% [markdown]
# #### Section B: Predict the Output - Functions, Return and Arguments - Write your prediction first, then run the code to check. Some questions deliberately cause an error; predict which error it will be.

# %% [markdown]
# Q1. [Core] Predict everything that is printed, and say why the second line is what it is:
# ```python
# def greet(name):
#     print("Hello", name)
#
# result = greet("Ada")
# print(result)
# ```

# %% [markdown]
# Hello Ada
# None
#
# greet() only prints something; it doesn't return anything. So result gets None.

# %% [markdown]
# Q2. [Core] Predict the output. What happens to the `print` on the last line of the function?
# ```python
# def check(n):
#     if n > 10:
#         return "big"
#     return "small"
#     print("never runs")
#
# print(check(20))
# print(check(3))
# ```

# %% [markdown]
# big
# small
#
# The print("never runs") never runs because it comes after return. Once Python reaches return, the function ends immediately.

# %% [markdown]
# Q3. [Core] Predict both lines of output:
# ```python
# def launch(rocket, fuel=100):
#     print(rocket, fuel)
#
# launch("Falcon")
# launch("Falcon", 50)
# ```

# %% [markdown]
# Falcon 100
# Falcon 50
#
# The first call uses the default fuel=100. The second call provides 50, so it replaces the default.

# %% [markdown]
# Q4. [Core] Predict both lines. Explain why the two calls give different results even though the words are the same:
# ```python
# def pet(animal, name):
#     print(animal, name)
#
# pet(name="Buddy", animal="dog")
# pet("Buddy", "dog")
# ```

# %% [markdown]
# dog Buddy
# Buddy dog
#
# The first call uses keyword arguments, so name="Buddy" goes to name and animal="dog" goes to animal.
# The second call uses positional arguments, so "Buddy" goes to animal and "dog" goes to name.

# %% [markdown]
# Q5. [Core] Predict the output IN THE CORRECT ORDER. This question is about code flow, so think carefully about where Python jumps to and when it comes back:
# ```python
# def a():
#     print("in a")
#     return 1
#
# print("start")
# x = a()
# print("end", x)
# ```

# %% [markdown]
# start
# in a
# end 1
#
# Python prints "start", then jumps into a(). It prints "in a", returns 1, and comes back to continue with print("end", x).

# %% [markdown]
# Q6. [Core] Predict the output:
# ```python
# def placeholder():
#     pass
#
# print(placeholder())
# ```

# %% [markdown]
# None
#
# pass does nothing, and the function has no return, so it returns None.

# %% [markdown]
# Q7. [Core] Predict the output, and name the data type of the thing that is printed:
# ```python
# def stats(values):
#     return min(values), max(values)
#
# print(stats([4, 9, 1]))
# ```

# %% [markdown]
# (1, 9)
#
# The data type is a tuple.

# %% [markdown]
# Q8. [Core] Predict the output:
# ```python
# def get_fruits():
#     return ["apple", "banana", "cherry"]
#
# fruits = get_fruits()
# print(fruits[1])
# ```

# %% [markdown]
# banana
#
# fruits[1] means the second item in the list. Python starts counting at 0.

# %% [markdown]
# Q9. [Core] Predict the output:
# ```python
# def show(person):
#     print("Name:", person["name"])
#     print("Age:", person["age"])
#
# show({"name": "Emil", "age": 25})
# ```

# %% [markdown]
# Name: Emil
# Age: 25
#
# The function gets the values from the dictionary using the keys "name" and "age".

# %% [markdown]
# Q10. [Stretch] This code causes an ERROR. Predict which error appears and explain the rule that has been broken:
# ```python
# def f(name, /):
#     print("Hello", name)
#
# f(name="Emil")
# ```

# %% [markdown]
# Error: TypeError
# name is positional-only because of /. You cannot call it using name="Emil".

# %% [markdown]
# Q11. [Stretch] This code also causes an ERROR. Predict it and explain the rule:
# ```python
# def f(*, name):
#     print("Hello", name)
#
# f("Emil")
# ```

# %% [markdown]
# Error: TypeError
# name is keyword-only because of *. You must call it like:
#
# f(name="Emil")

# %% [markdown]
# Q12. [Stretch] Predict the number that is printed:
# ```python
# def f(a, b, /, *, c, d):
#     return a + b + c + d
#
# print(f(5, 10, c=15, d=20))
# ```

# %% [markdown]
# 50
#
# 5 + 10 + 15 + 20 = 50.
# a and b must be positional, while c and d must be keyword arguments.

# %% [markdown]
# Q13. [Core] Predict the output. Look carefully at what is being printed versus what is being returned:
# ```python
# def double(n):
#     print("Doubling", n)
#     return n * 2
#
# answer = double(6)
# print(answer)
# ```

# %% [markdown]
# Doubling 6
# 12

# %% [markdown]
# Q14. [Core] Predict the output:
# ```python
# def mission(name, crew=3, ready=True):
#     print(name, crew, ready)
#
# mission("Artemis")
# mission("Apollo", 5)
# mission("Gemini", ready=False)
# ```

# %% [markdown]
# Artemis 3 True
# Apollo 5 True
# Gemini 3 False

# %% [markdown]
# Q15. [Stretch] Predict the output. What is the value of `total` after all three calls, and why?
# ```python
# def add(a, b):
#     return a + b
#
# total = 0
# total = add(total, 5)
# total = add(total, 10)
# print(total)
# ```

# %% [markdown]
# 15
#
# total becomes 5, then 15.

# %% [markdown]
# Q16. [Stretch] Predict the output. A function may be called from inside another function:
# ```python
# def square(n):
#     return n * n
#
# def sum_of_squares(a, b):
#     return square(a) + square(b)
#
# print(sum_of_squares(3, 4))
# ```

# %% [markdown]
# 25
#
# 3² + 4² = 9 + 16 = 25.

# %% [markdown]
# #### Section C: Loop Analysis - Tracing Values Iteration by Iteration - This is the priority section. Fill in each trace table one row at a time before you run anything. Follow the two worked examples at the top of this notebook. You may fill the tables in the markdown cell or draw them on paper and photograph them.

# %% [markdown]
# Q1. [Core] Fill in the trace table, then say what the function returns.
# ```python
# def add_all(numbers):
#     total = 0
#     for num in numbers:
#         total += num
#     return total
#
# print(add_all([4, 7, 2]))
# ```
#
# | Pass | num | total BEFORE | total AFTER |
# |---|---|---|---|
# | 1 |4|0|4|
# | 2 |7|4|11|
# | 3 |2|11|13|
#
# Returned value:

# %% [markdown]
# this prints 13

# %% [markdown]
# Q2. [Core] Fill in the trace table for this `while` loop, then say what is printed. Remember the last row is the pass where the condition fails.
# ```python
# count = 1
# result = 0
# while count <= 4:
#     result += count
#     count += 1
# print(result)
# ```
#
# | Pass | count at start | Is count <= 4? | result AFTER | count AFTER |
# |---|---|---|---|---|
# | 1 | | | | |
# | 2 | | | | |
# | 3 | | | | |
# | 4 | | | | |
# | 5 | | | | |
#
# Printed value:

# %% [markdown]
# 10 is printed

# %% [markdown]
# Q3. [Core] Trace this loop over a STRING. Notice that `out` is built up from an empty string.
# ```python
# word = "MARS"
# out = ""
# for letter in word:
#     out = letter + out
# print(out)
# ```
#
# | Pass | letter | out BEFORE | out AFTER |
# |---|---|---|---|
# | 1 | M|""|"M"|
# | 2 | A|"M"|"AM"|
# | 3 |R |"AM"|"RAM"|
# | 4 | S|"RAM"|"SRAM"|
#
# Printed value:
#
# What does this loop do to the word?

# %% [markdown]
# it turns it backwards

# %% [markdown]
# Q4. [Core] Trace this loop over a list of STRINGS.
# ```python
# planets = ["Mars", "Venus", "Io"]
# longest = ""
# for p in planets:
#     if len(p) > len(longest):
#         longest = p
# print(longest)
# ```
#
# | Pass | p | len(p) | len(longest) before | Did it change? | longest AFTER |
# |---|---|---|---|---|---|
# | 1 |Mars|4|0|Yes|Mars|
# | 2 |Venus|5|4|Yes|Venus|
# | 3 |Io|2|5|No|Venus|
#
# Printed value:

# %% [markdown]
# it prints Venus

# %% [markdown]
# Q5. [Core] Trace this loop that uses `range()` with a step.
# ```python
# total = 0
# for n in range(1, 10, 3):
#     total += n
# print(total)
# ```
#
# First write out every value `range(1, 10, 3)` produces:
#
# | Pass | n | total BEFORE | total AFTER |
# |---|---|---|---|
# | 1 |1|0|1|
# | 2 |4|1|5|
# | 3 |7|5|2|
#
# Printed value:

# %% [markdown]
# it prints 12

# %% [markdown]
# Q6. [Core] Trace this loop over a DICTIONARY using `.items()`. Note that two variables change on each pass.
# ```python
# moons = {"Earth": 1, "Mars": 2, "Jupiter": 95}
# count = 0
# for planet, n in moons.items():
#     count += n
# print(count)
# ```
#
# | Pass | planet | n | count BEFORE | count AFTER |
# |---|---|---|---|---|
# | 1 |Earth|1|0|1|
# | 2 |Mars|2|1|3|
# | 3 |Jupiter|95|3|98|
#
# Printed value:

# %% [markdown]
# it prints 98

# %% [markdown]
# Q7. [Core] Trace this `while True` loop with a `break`.
# ```python
# i = 0
# while True:
#     i += 2
#     if i > 7:
#         break
# print(i)
# ```
#
# | Pass | i at start | i after adding 2 | Is i > 7? | Break? |
# |---|---|---|---|---|
# 1|0|2|2 > 7 is false
# 2|2|4|4 > 7 is false
# 3|4|6|6 > 7 is false
# 4|6|8|8 > 7 is true → break
#
#
#
# Printed value:

# %% [markdown]
# it prints 8

# %% [markdown]
# Q8. [Core] Trace this `while` loop with a `continue`. Be careful: on some passes `total` does not change at all.
# ```python
# n = 0
# total = 0
# while n < 6:
#     n += 1
#     if n % 2 == 0:
#         continue
#     total += n
# print(total)
# ```
#
# | Pass | n after adding 1 | Is n even? | Skipped? | total AFTER |
# |---|---|---|---|---|
# 1|1|No|No|1
# 2|2|Yes|Yes|1
# 3|3|No|No|4
# 4|4|Yes|Yes|4
# 5|5|No|No|9
# 6|6|Yes|Yes|9
#
# Printed value:

# %% [markdown]
# it prints 9

# %% [markdown]
# Q9. [Core] Trace this NESTED loop. The inner loop runs completely for every single pass of the outer loop.
# ```python
# pairs = 0
# for a in [1, 2]:
#     for b in ["x", "y", "z"]:
#         pairs += 1
# print(pairs)
# ```
#
# | Outer pass | a | Inner pass | b | pairs AFTER |
# |---|---|---|---|---|
# 1|1|1|"x"|1
# 1|1|2|"y"|2
# 1|1|3|"z"|3
# 2|2|1|"x"|4
# 2|2|2|"y"|5
# 2|2|3|"z"|6
#
#
# Printed value:

# %% [markdown]
# it prints 6

# %% [markdown]
# Q10. [Core] Trace this loop that BUILDS A LIST with `append`.
# ```python
# def doubles(values):
#     out = []
#     for v in values:
#         out.append(v * 2)
#     return out
#
# print(doubles([3, 5, 8]))
# ```
#
# | Pass | v | v * 2 | out AFTER |
# |---|---|---|---|
# 1 | 3 | 6 | [6]
# 2 | 5 | 10 | [6, 10]
# 3 | 8 | 16 | [6, 10, 16]
#
#
# Printed value:

# %% [markdown]
# it prints [6, 10, 16]

# %% [markdown]
# Q11. [Core] Trace this loop over a TUPLE.
# ```python
# readings = (12, 5, 20, 5)
# biggest = readings[0]
# for r in readings:
#     if r > biggest:
#         biggest = r
# print(biggest)
# ```
#
# | Pass | r | biggest BEFORE | Is r > biggest? | biggest AFTER |
# |---|---|---|---|---|
# 1 | 12 | 12 | No | 12
# 2 | 5 | 12 | No | 12
# 3 | 20 | 12 | Yes | 20
# 4 | 5 | 20 | No | 20
#
#
# Printed value:

# %% [markdown]
# it prints 20

# %% [markdown]
# Q12. [Core] Trace this `while` loop where TWO variables change every pass.
# ```python
# fuel = 100
# step = 0
# while fuel > 60:
#     fuel -= 15
#     step += 1
# print(fuel, step)
# ```
#
# | Pass | fuel at start | Is fuel > 60? | fuel AFTER | step AFTER |
# |---|---|---|---|---|
# 1 | 100 | Yes | 85 | 1
# 2 | 85 | Yes | 70 | 2
# 3 | 70 | Yes | 55 | 3
# 4 | 55 | No | 55 | 3
#
# Printed values:

# %% [markdown]
# it prints 55 3

# %% [markdown]
# Q13. [Core] Trace this loop that counts a letter inside a function.
# ```python
# def count_a(text):
#     count = 0
#     for ch in text:
#         if ch == "a":
#             count += 1
#     return count
#
# print(count_a("andromeda"))
# ```
#
# Write out the letters of "andromeda" in order, then complete the table.
#
# | Pass | ch | Is ch == "a"? | count AFTER |
# |---|---|---|---|
# 1 | a | Yes | 1
# 2 | n | No | 1
# 3 | d | No | 1
# 4 | r | No | 1
# 5 | o | No | 1
# 6 | m | No | 1
# 7 | e | No | 1
# 8 | d | No | 1
# 9 | a | Yes | 2
# Returned value:

# %% [markdown]
# a n d r o m e d a
#
# it prints 2

# %% [markdown]
# Q14. [Stretch] Trace this loop that builds a DICTIONARY as it goes.
# ```python
# def count_letters(word):
#     counts = {}
#     for ch in word:
#         if ch in counts:
#             counts[ch] += 1
#         else:
#             counts[ch] = 1
#     return counts
#
# print(count_letters("moon"))
# ```
#
# | Pass | ch | Already in counts? | counts AFTER |
# |---|---|---|---|
# 1 | m | No | {'m': 1}
# 2 | o | No | {'m': 1, 'o': 1}
# 3 | o | Yes | {'m': 1, 'o': 2}
# 4 | n | No | {'m': 1, 'o': 2, 'n': 1}
# Returned value:

# %% [markdown]
# {'m': 1, 'o': 2, 'n': 1}

# %% [markdown]
# Q15. [Core] Trace this loop and pay close attention to WHEN it stops. A `return` inside a loop ends the whole function immediately.
# ```python
# def first_big(values):
#     for v in values:
#         if v > 10:
#             return v
#     return None
#
# print(first_big([3, 8, 14, 20]))
# ```
#
# | Pass | v | Is v > 10? | What happens |
# |---|---|---|---|
# 1 | 3 | No | Continue
# 2 | 8 | No | Continue
# 3 | 14 | Yes | Return 14
#
# Returned value:
#
# How many passes did the loop actually make, and why did it not reach the value 20?

# %% [markdown]
# 14

# %% [markdown]
# Q16. [Core] Trace this loop that counts backwards.
# ```python
# for i in range(5, 0, -1):
#     print(i)
# ```
#
# | Pass | i | What is printed |
# |---|---|---|
# 1 | 5 | 5
# 2 | 4 | 4
# 3 | 3 | 3
# 4 | 2 | 2
# 5 | 1 | 1
#
# Why does the loop stop where it does, and why is 0 never printed?

# %% [markdown]
# It stops before 0 because range(5, 0, -1) does not include 0.

# %% [markdown]
# Q17. [Core] Trace this loop that uses an INDEX instead of the items directly.
# ```python
# planets = ["Mercury", "Venus", "Earth"]
# for i in range(len(planets)):
#     print(i, planets[i])
# ```
#
# | Pass | i | planets[i] | Line printed |
# |---|---|---|---|
# 1 | 0 | Mercury | 0 Mercury
# 2 | 1 | Venus | 1 Venus
# 3 | 2 | Earth | 2 Earth
#
#
# What value does `len(planets)` have, and what values does `range()` therefore produce?

# %% [markdown]
# len(planets) = 3
#
# range(3) produces: 0 | 1 | 2

# %% [markdown]
# Q18. [Stretch] Trace this nested loop and write down every line it prints, in order.
# ```python
# for a in ["red", "big"]:
#     for b in ["star", "moon"]:
#         print(a, b)
# ```
#
# | Outer pass | a | Inner pass | b | Line printed |
# |---|---|---|---|---|
# 1 | red | 1 | star | red star
# 1 | red | 2 | moon | red moon
# 2 | big | 1 | star | big star
# 2 | big | 2 | moon | big moon

# %% [markdown]
# red star
# red moon
# big star
# big moon

# %% [markdown]
# Q19. [Core] This loop goes over a SET. Work out the total.
# ```python
# sizes = {3, 1, 4, 1, 5}
# total = 0
# for s in sizes:
#     total += s
# print(total)
# ```
#
# First: how many items does the set actually contain, and why is that fewer than the number of values written?
#
# Total printed:13

# %% [markdown]
# The set contains 4 items because duplicate 1s are only stored once.

# %% [markdown]
# Q20. [Core] Following on from the previous question: why can you safely predict the TOTAL of a set, but NOT the order in which the items come out of the loop? What does this tell you about sets compared with lists?

# %% [markdown]
# You can predict the total because the set contains the same unique values.
# You cannot predict the order because sets do not guarantee an ordering.
# This tells me that lists have a fixed order while sets do not

# %% [markdown]
# Q21. [Stretch] Compare a `for` loop and a `while` loop for the same job: adding up the numbers 1 to 5. Write both versions, then explain which variables you had to create and update by hand in each one. Which loop needed more bookkeeping from you?

# %% [markdown]
# total = 0
# for n in range(1, 6):
#     total += n
# print(total)
#
# total = 0
# n = 1
# while n <= 5:
#     total += n
#     n += 1
# print(total)
#
# 15
#
# The for loop handles moving through 1 to 5 automatically.
# The while loop requires you to create and update n yourself.
#
# The while loop needs more bookkeeping.

# %% [markdown]
# Q22. [Stretch] Find the bug by tracing. This function is supposed to return the total of the list, but it always returns the last number instead. Trace it and explain exactly where it goes wrong.
# ```python
# def add_all(numbers):
#     for num in numbers:
#         total = 0
#         total += num
#     return total
#
# print(add_all([4, 7, 2]))
# ```

# %% [markdown]
# total = 0 is inside the loop, so it resets the total to 0 every time.

# %% [markdown]
# #### Section D: Arbitrary Arguments - *args and **kwargs - Theory, prediction and coding on flexible arguments. Pay special attention to the difference between the star symbol in a DEFINITION and the star symbol in a CALL.

# %% [markdown]
# Q1. [Core] What problem do `*args` and `**kwargs` solve? Explain what is difficult about a normal function definition when you do not know how many arguments will be sent.

# %% [markdown]
# *args and **kwargs let a function accept any number of arguments. A normal function needs a fixed number of parameters.

# %% [markdown]
# Q2. [Core] What single symbol do you put before a parameter name to make it accept any number of positional arguments? What data type does that parameter become inside the function?

# %% [markdown]
# it becomes a tuple.

# %% [markdown]
# Q3. [Core] What two symbols do you put before a parameter name to make it accept any number of keyword arguments? What data type does that parameter become inside the function?

# %% [markdown]
# It becomes a dictionary.

# %% [markdown]
# Q4. [Core] You have already learned about tuples and dictionaries. Explain why a tuple is a sensible choice for `*args`, and why a dictionary is a sensible choice for `**kwargs`. What does each one need to store?

# %% [markdown]
# *args uses a tuple to store positional arguments.
#
# **kwargs uses a dictionary to store keyword arguments and their values.

# %% [markdown]
# Q5. [Core] Is the name `args` compulsory? Could you write `*numbers` or `*kids` instead? What is the part that actually matters?

# %% [markdown]
# No. args is not compulsory. You can use *numbers or *kids.
# The * is what matters.

# %% [markdown]
# Q6. [Core] When a function uses regular parameters, `*args` and `**kwargs` together, what ORDER must they be written in? Write out an empty function definition showing the correct order.

# %%
print ("regular parameters, *args, **kwargs")

def example(a, *args, **kwargs):
    pass
# Out:
# regular parameters, *args, **kwargs

# %% [markdown]
# Q7. [Core] Predict all three lines of output:
# ```python
# def show(*args):
#     print(type(args))
#     print(len(args))
#     print(args)
#
# show(1, "two", 3.0)
# ```

# %% [markdown]
# <class 'tuple'>
# 3
# (1, 'two', 3.0)

# %% [markdown]
# Q8. [Core] Predict both lines of output:
# ```python
# def info(**kwargs):
#     print(type(kwargs))
#     print(kwargs)
#
# info(name="Ada", age=12)
# ```

# %% [markdown]
# <class 'dict'>
# {'name': 'Ada', 'age': 12}

# %% [markdown]
# Q9. [Core] Predict all three lines. Say exactly which values went into `values` and which went into `extras`, and why:
# ```python
# def report(label, *values, **extras):
#     print(label)
#     print(values)
#     print(extras)
#
# report("Scan", 10, 20, unit="cm", ok=True)
# ```

# %% [markdown]
# Scan
# (10, 20)
# {'unit': 'cm', 'ok': True}
#
# values = (10, 20)
# extras = {'unit': 'cm', 'ok': True}

# %% [markdown]
# Q10. [Core] Predict both printed values. The first call is the interesting one:
# ```python
# def total(*nums):
#     t = 0
#     for n in nums:
#         t += n
#     return t
#
# print(total())
# print(total(5))
# ```
# What is `nums` on the first call, and why does the loop body never run?

# %% [markdown]
# 0
# 5
#
# On the first call, nums is () because no arguments were given. The loop does not run because there are no values in the tuple.

# %% [markdown]
# Q11. [Core] Predict the output:
# ```python
# def youngest(*kids):
#     print(kids[-1])
#
# youngest("Emil", "Tobias", "Linus")
# ```
# What does the index `-1` mean here?

# %% [markdown]
# Linus
#
# -1 means the last item.

# %% [markdown]
# Q12. [Core] Predict both lines of output:
# ```python
# def my_function(greeting, *names):
#     for name in names:
#         print(greeting, name)
#
# my_function("Hello", "Emil", "Tobias")
# ```
# Which argument went into `greeting`, and which went into `names`?

# %% [markdown]
# Hello Emil
# Hello Tobias
#
# greeting = "Hello"
# names = ("Emil", "Tobias")

# %% [markdown]
# Q13. [Core] Trace this one carefully. It combines `*args` with a loop, so use a small trace table for `total`:
# ```python
# def add_all(*numbers):
#     total = 0
#     for num in numbers:
#         total += num
#     return total
#
# print(add_all(1, 2, 3))
# print(add_all(10, 20, 30, 40))
# ```
#
# For the first call:
#
# | Pass | num | total AFTER |
# |---|---|---|
# | 1 |1|1|
# | 2 |2|3|
# | 3 |3|6|

# %% [markdown]
# 6
# 100

# %% [markdown]
# Q14. [Core] Predict both printed values, including what happens on the second call:
# ```python
# def biggest(*numbers):
#     if len(numbers) == 0:
#         return None
#     m = numbers[0]
#     for n in numbers:
#         if n > m:
#             m = n
#     return m
#
# print(biggest(3, 7, 2, 9, 1))
# print(biggest())
# ```
# Why does the function check the length first?

# %% [markdown]
# 9
# None
#
# It checks the length first because there may be no numbers. Otherwise, numbers[0] would cause an error.

# %% [markdown]
# Q15. [Core] Predict the output. Note how a dictionary is looped over with `.items()`:
# ```python
# def profile(username, **details):
#     print("User:", username)
#     for key, value in details.items():
#         print(" ", key + ":", value)
#
# profile("emil123", age=25, city="Oslo")
# ```

# %% [markdown]
# User: emil123
#   age: 25
#   city: Oslo

# %% [markdown]
# Q16. [Core] These two calls look similar but behave very differently. Predict BOTH outputs and explain the difference:
# ```python
# def f(*args):
#     print(len(args))
#     print(args[0])
#
# f([1, 2, 3])
# f(*[1, 2, 3])
# ```
# This is the single most important idea about the `*` symbol. What does `*` do when used in a CALL, compared with when it is used in a DEFINITION?

# %% [markdown]
# First call:
# 1
# [1, 2, 3]
#
# Second call:
# 3
# 1
#
# In a definition, * collects arguments.
# In a call, * unpacks arguments.

# %% [markdown]
# Q17. [Core] Predict the output:
# ```python
# def add(a, b, c):
#     return a + b + c
#
# numbers = [1, 2, 3]
# print(add(*numbers))
# ```
# Rewrite the last line without using `*`, so that it does exactly the same thing.

# %% [markdown]
# 6
#
# Without *:

# %% [markdown]
# Q18. [Core] Predict the output:
# ```python
# def greet(fname, lname):
#     print("Hello", fname, lname)
#
# person = {"fname": "Emil", "lname": "Ray"}
# greet(**person)
# ```
# What would happen if the dictionary keys did not match the parameter names?

# %% [markdown]
# Hello Emil Ray
#
# If the dictionary keys do not match the parameter names, a TypeError occurs.

# %% [markdown]
# Q19. [Stretch] This code causes an ERROR. Predict which error appears, and explain why a keyword argument cannot be collected by `*args`:
# ```python
# def f(*args):
#     print(args)
#
# f(name="x")
# ```

# %% [markdown]
# ()
#
# name="x" is a keyword argument, so *args does not collect it.

# %% [markdown]
# Q20. [Stretch] This definition is legal, but the call causes an ERROR. Predict the error, then explain the rule: any parameter written AFTER `*args` can only be given by keyword. Where have you seen that same rule before in this module?
# ```python
# def f(*args, label):
#     print(args, label)
#
# f(1, 2)
# ```

# %% [markdown]
# A TypeError occurs.
# label must be given by keyword because it comes after *args.

# %% [markdown]
# Q21. [Core] Write a function called `count_items` that accepts any number of positional arguments and returns how many were given. Test it with zero, with one, and with five arguments.

# %%
def count_items(*items):
    return len(items)

print(count_items())
print(count_items(1))
print(count_items(1, 2, 3, 4, 5))
# Out:
# 0
# 1
# 5

# %% [markdown]
# Q22. [Core] Write a function called `describe_planet` that takes a required `name` and then any number of keyword arguments, and prints the name followed by each extra fact on its own line.

# %%
22.
def describe_planet(name, **facts):
    print(name)
    for key, value in facts.items():
        print(key, value)

describe_planet("Mars", color="red", moons=2, type="terrestrial")
# Out:
# Mars
# color red
# moons 2
# type terrestrial

# %% [markdown]
# Q23. [Stretch] Write a function called `mission_log` that takes a required `title`, then any number of positional event names, then any number of keyword details. Print all three parts clearly labelled. Test it with a mixture of all three.

# %%
def mission_log(title, *events, **details):
    print("Title:", title)
    print("Events:", events)
    print("Details:", details)

mission_log("Mission", "Launch", "Landing", crew=3, duration="5 days")
# Out:
# Title: Mission
# Events: ('Launch', 'Landing')
# Details: {'crew': 3, 'duration': '5 days'}

# %% [markdown]
# Q24. [Stretch] Write a function `average(*numbers)` that returns the average of however many numbers it is given, and returns `None` if it is given none at all. Explain why the empty case has to be handled separately.

# %%
def average(*numbers):
    if len(numbers) == 0:
        return None

    total = 0
    for number in numbers:
        total += number

    return total / len(numbers)

print ("The empty case must be handled separately because dividing by zero causes an error.")
# Out:
# The empty case must be handled separately because dividing by zero causes an error.

# %% [markdown]
# #### Section E: Coding Practice - Writing Your Own Functions - Write and run each function in the cell below the task. Test every function by calling it at least once.

# %% [markdown]
# Q1. [Core] Feel the problem first. Write out, WITHOUT any function, the code to convert 3 miles, then 5.7 miles, then 12 miles into kilometres (1 mile = 1.6 km), printing each result. Then rewrite the whole thing using a single function called `mile_to_km`. Which version would be easier to change if the conversion number was wrong?

# %%
print(3 * 1.6)
print(5.7 * 1.6)
print(12 * 1.6)

def mile_to_km(miles):
    return miles * 1.6

print(mile_to_km(3))
print(mile_to_km(5.7))
print(mile_to_km(12))

print ("The function version is easier because you only need to change 1.6 in one place")
# Out:
# 4.800000000000001
# 9.120000000000001
# 19.200000000000003
# 4.800000000000001
# 9.120000000000001
# 19.200000000000003
# The function version is easier because you only need to change 1.6 in one place

# %% [markdown]
# Q2. [Core] Write a function `greet_astronaut(name)` that prints a friendly greeting using an f-string. Call it three times with different names.

# %%
def greet_astronaut(name):
    print(f"Hello, {name}! Welcome aboard!")

greet_astronaut("Alex")
greet_astronaut("Maya")
greet_astronaut("Jordan")
# Out:
# Hello, Alex! Welcome aboard!
# Hello, Maya! Welcome aboard!
# Hello, Jordan! Welcome aboard!

# %% [markdown]
# Q3. [Core] Write a function `add(a, b)` that RETURNS the sum rather than printing it. Store the result in a variable and print that variable.

# %%
def add(a, b):
    return a + b

result = add(5, 7)
print(result)
# Out:
# 12

# %% [markdown]
# Q4. [Core] Write a function `circle_area(radius)` that returns the area of a circle. Import the `math` module and use `math.pi`. Print the area for three different radii, rounded to two decimal places.

# %%
import math

def circle_area(radius):
    return math.pi * radius ** 2

print(round(circle_area(2), 2))
print(round(circle_area(5), 2))
print(round(circle_area(10), 2))
# Out:
# 12.57
# 78.54
# 314.16

# %% [markdown]
# Q5. [Core] Write a function `is_even(number)` that returns `True` or `False`. Use it inside an `if` statement to print a message.

# %%
def is_even(number):
    return number % 2 == 0

if is_even(8):
    print("The number is even.")
else:
    print("The number is odd.")
# Out:
# The number is even.

# %% [markdown]
# Q6. [Core] Write a function `planet_report(name, moons=0)` where `moons` has a default value. Call it once with both arguments and once with only the name.

# %%
def planet_report(name, moons=0):
    print(f"{name} has {moons} moons.")

planet_report("Earth", 1)
planet_report("Mars")

# %% [markdown]
# Q7. [Core] Write a function `sum_list(values)` that takes a LIST of numbers and returns their total, using a `for` loop inside the function.

# %%
def sum_list(values):
    total = 0

    for value in values:
        total += value

    return total

print(sum_list([1, 2, 3, 4]))

# %% [markdown]
# Q8. [Core] Write a function `count_long_names(planets)` that takes a list of planet names and returns how many of them have more than five letters.

# %%
def count_long_names(planets):
    count = 0

    for planet in planets:
        if len(planet) > 5:
            count += 1

    return count

print(count_long_names(["Earth", "Jupiter", "Mars", "Saturn"]))
# Out:
# 2

# %% [markdown]
# Q9. [Core] Write a function `biggest(values)` that takes a list and returns the largest value, without using the built-in `max()`. Use a loop and a running variable.

# %%
def biggest(values):
    largest = values[0]

    for value in values:
        if value > largest:
            largest = value

    return largest

print(biggest([4, 9, 2, 15, 7]))
# Out:
# 15

# %% [markdown]
# Q10. [Core] Write a function `describe(person)` that takes a DICTIONARY with the keys `name` and `age`, and prints both values neatly.

# %%
def describe(person):
    print(f"Name: {person['name']}")
    print(f"Age: {person['age']}")

person = {"name": "Alex", "age": 25}
describe(person)
# Out:
# Name: Alex
# Age: 25

# %% [markdown]
# Q11. [Core] Write a function `make_planet_list()` that returns a list of three planet names. Call it, store the returned list, and print the second item.

# %%
def make_planet_list():
    return ["Mercury", "Venus", "Earth"]

planets = make_planet_list()
print(planets[1])
# Out:
# Venus

# %% [markdown]
# Q12. [Stretch] Write a function `countdown(start)` that uses a `while` loop to print from `start` down to 1 and then returns the string `"Liftoff"`. Print the returned value.

# %%
def countdown(start):
    while start >= 1:
        print(start)
        start -= 1

    return "Liftoff"

print(countdown(5))
# Out:
# 5
# 4
# 3
# 2
# 1
# Liftoff

# %% [markdown]
# Q13. [Stretch] Write a function `reverse_word(word)` that returns the word backwards, using a `for` loop and string building. You may not use any built-in reversing tool.

# %%
def reverse_word(word):
    reversed_word = ""

    for letter in word:
        reversed_word = letter + reversed_word

    return reversed_word

print(reverse_word("hello"))
# Out:
# olleh

# %% [markdown]
# Q14. [Stretch] Write a function `letter_count(word, letter)` that returns how many times a letter appears in a word. Test it with three different letters.

# %%
def letter_count(word, letter):
    count = 0

    for character in word:
        if character == letter:
            count += 1

    return count

print(letter_count("banana", "a"))
print(letter_count("banana", "n"))
print(letter_count("banana", "b"))
# Out:
# 3
# 2
# 1

# %% [markdown]
# Q15. [Stretch] Write a function `safe_divide(a, b)` that returns the result of `a / b`, but returns the string `"Cannot divide by zero"` if `b` is zero. Test both cases.

# %%
def safe_divide(a, b):
    if b == 0:
        return "Cannot divide by zero"

    return a / b

print(safe_divide(10, 2))
print(safe_divide(10, 0))
# Out:
# 5.0
# Cannot divide by zero

# %% [markdown]
# Q16. [Stretch] Write two functions where one calls the other: `square(n)` returns a number multiplied by itself, and `sum_of_squares(a, b)` uses `square` twice and returns the total.

# %%
def square(n):
    return n * n

def sum_of_squares(a, b):
    return square(a) + square(b)

print(sum_of_squares(3, 4))
# Out:
# 25

# %% [markdown]
# #### Section F: Real-World Mini Projects - Larger tasks that bring functions, loops and your earlier projects together.

# %% [markdown]
# Q1. [Core] Rocket Fuel Calculator. Write a function `fuel_needed(distance, rate=2.5)` that returns how much fuel is needed for a journey. Call it for three different distances, one of them using the default rate, and print a neat report for each.

# %%
def fuel_needed(distance, rate=2.5):
    return distance * rate

print(f"Distance: 10 km | Fuel needed: {fuel_needed(10)}")
print(f"Distance: 20 km | Fuel needed: {fuel_needed(20)}")
print(f"Distance: 30 km | Fuel needed: {fuel_needed(30, 3)}")
# Out:
# Distance: 10 km | Fuel needed: 25.0
# Distance: 20 km | Fuel needed: 50.0
# Distance: 30 km | Fuel needed: 90

# %% [markdown]
# Q2. [Core] Star Catalogue. Write a function `classify_star(magnitude)` that returns `"Very bright"`, `"Bright"` or `"Faint"` depending on the magnitude, remembering that a smaller magnitude means a brighter star. Then write a loop that calls your function for every star in a list and prints the result.

# %%
def classify_star(magnitude):
    if magnitude < 1:
        return "Very bright"
    elif magnitude < 3:
        return "Bright"
    else:
        return "Faint"

stars = [0.5, 2, 4, 1.5, 5]

for star in stars:
    print(f"Magnitude {star}: {classify_star(star)}")

# %% [markdown]
# Q3. [Core] Refactor your calculator. In your `calculator.py` project you already wrote `press`, `clear` and `equal`. Look at them again now that you have studied functions properly. For each one, write down which parameters it takes, what it returns, and whether it returns anything at all.

# %% [markdown]
# press() — takes the button/value as a parameter; usually updates the calculator and may not return anything.
#
# clear() — takes no parameters; clears the calculator and usually does not return anything.
#
# equal() — takes no parameters; calculates the answer and may return the result or display it, depending on the code.

# %% [markdown]
# Q4. [Core] Mission Control Report. Write a function `mission_report(name, *crew, **details)` that prints the mission name, then each crew member on their own line, then each extra detail. Call it with a realistic mission.

# %%
def mission_report(name, *crew, **details):
    print(f"Mission: {name}")

    for member in crew:
        print(f"Crew member: {member}")

    for key, value in details.items():
        print(f"{key}: {value}")

mission_report(
    "Artemis II",
    "Reid Wiseman",
    "Victor Glover",
    "Christina Koch",
    "Jeremy Hansen",
    launch_date="November 2026",
    destination="Moon"
)
# Out:
# Mission: Artemis II
# Crew member: Reid Wiseman
# Crew member: Victor Glover
# Crew member: Christina Koch
# Crew member: Jeremy Hansen
# launch_date: November 2026
# destination: Moon

# %% [markdown]
# Q5. [Stretch] Refactor your Wokwi sensor code. In Assignment 2 you wrote six lines that trigger the ultrasonic sensor and calculate a distance, and those lines had to sit inside your loop. Rewrite them as a function `measure_distance()` that returns the distance in centimetres. Explain how your main loop is now easier to read.

# %% [markdown]
# from machine import Pin, time_pulse_us
# import time
#
# trigger = Pin(17, Pin.OUT)
# echo = Pin(16, Pin.IN)
# red = Pin(15, Pin.OUT)
#
# def measure_distance():
#     trigger.value(0)
#     time.sleep_us(5)
#     trigger.value(1)
#     time.sleep_us(10)
#     trigger.value(0)
#     duration = time_pulse_us(echo, 1, 30000)
#     return duration * 0.0343 / 2
#
# while True:
#     distance = measure_distance()
#     delay = max(0.05, min(1.0, distance / 100))
#     red.value(1)
#     time.sleep(delay)
#     red.value(0)
#     time.sleep(delay)
#     print(f"Distance: {distance:.1f} cm")
#
# now the main loop is easier to ready because the code is shorter and seperated into nice sections

# %% [markdown]
# Q6. [Stretch] Statistics Toolkit. Write three functions that each accept any number of arguments using `*args`: one returns the total, one returns the average, and one returns the largest. Test all three with the same set of numbers.

# %%
def total(*args):
    return sum(args)

def average(*args):
    return sum(args) / len(args)

def largest(*args):
    biggest = args[0]

    for number in args:
        if number > biggest:
            biggest = number

    return biggest

numbers = (10, 20, 30, 40, 50)

print("Total:", total(*numbers))
print("Average:", average(*numbers))
print("Largest:", largest(*numbers))
# Out:
# Total: 150
# Average: 30.0
# Largest: 50

# %% [markdown]
# Q7. [Stretch] Make it your own. Write a function of your own design that solves a problem you find interesting, uses at least one loop inside it, and returns a value. Explain what it does and why you chose it.

# %%
def count_vowels(word):
    vowels = "aeiou"
    count = 0

    for letter in word.lower():
        if letter in vowels:
            count += 1

    return count

print(count_vowels("Astronaut"))

print ("This function counts how many vowels are in a word. I chose it because it is simple but useful, and it uses a loop to check each letter.")
# Out:
# 4
# This function counts how many vowels are in a word. I chose it because it is simple but useful, and it uses a loop to check each letter.

# %% [markdown]
# Q8. [Core] Reflection. In three to five sentences, explain to a friend what a function is, what `return` does, and why `*args` and `**kwargs` are useful. Then answer this: which was harder for you, writing functions or tracing loops, and what helped most?

# %% [markdown]
# A function is a reusable block of code that performs a specific task. return sends a value back from a function so you can store or use that result elsewhere. *args is useful when you want a function to accept any number of positional arguments, while **kwargs lets you accept any number of named arguments. in my opinion, writing functions are harder than tracing loops because i had to think about parameters and return values. small examples helped me the most
