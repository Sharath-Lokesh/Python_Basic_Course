# %% [markdown]
# # Wokwi Assignment 2: Building Circuits with the Raspberry Pi Pico
#
# Two circuits, built from scratch: an RGB LED (an output device that produces colour) and an HC-SR04 ultrasonic sensor (an input device that measures distance). The goal is not only to make them work, but to understand why every wire is where it is.
#
# ## Before you start
# - Open a new MicroPython on Raspberry Pi Pico project: https://wokwi.com/projects/new/micropython-pi-pico
# - Save the project before you begin, and keep saving as you go.
# - Build Part 1 (the RGB LED) first and get it working. Then add Part 2 (the sensor) to the SAME project, because the final mini projects need both together.
# - You will need paper and a pencil. Several tasks ask you to draw the circuit yourself, which is the fastest way to understand it.
#
# ## A note about the code cells
# The cells below are for keeping your Wokwi code. They will not run here, because the `machine` module only exists on the microcontroller.
#
# ## Difficulty levels
# - **[Core]** is the essential set. Do these first.
# - **[Stretch]** goes deeper and is optional.
# - **[Research]** expects you to look something up.

# %% [markdown]
# #### Section A: Part 1 - Building the RGB LED Circuit - Build the circuit step by step in Wokwi. Paste code and write your observations in the cell below each task.

# %% [markdown]
# Q1. [Core] Start a new MicroPython Pico project, save it, and give it a sensible name such as `Pico RGB and Distance`. Paste the project link here.

# %% [markdown]
# https://wokwi.com/projects/472523017003815937

# %% [markdown]
# Q2. [Core] Click the `+` button and add these parts: one RGB LED and three 220 ohm resistors. Do not wire anything yet. Describe where the new parts appeared on the diagram.

# %% [markdown]
# they appeared in the top left corner of the diagram right next to each other

# %% [markdown]
# Q3. [Core] Set the LED type. In Wokwi, an RGB LED is a common ANODE part by default, which means it lights up when a pin is driven LOW (**HINT: Watch a youtube video to understand common ANODE and common CATHODE LEDs**). That is backwards from what you would expect, so we will change it. Open `diagram.json`, find the RGB LED entry, and add this attribute to it:
# ```json
# "attrs": { "common": "cathode" }
# ```
# Now the LED lights up when a pin is driven HIGH, which matches everything you learned in Assignment 1. Confirm the change saved, and explain in your own words what you just changed.

# %% [markdown]
# I changed the LED to common cathode, so now it turns on when the Pico sends a high signal instead of low.

# %% [markdown]
# Q4. [Core] Wire the circuit using this connection table. Drag from one point to another to create a wire.
#
# | RGB LED pin | Connects to | Through |
# |---|---|---|
# | R | GP15 | a 220 ohm resistor |
# | G | GP14 | a 220 ohm resistor |
# | B | GP13 | a 220 ohm resistor |
# | COM | Any GND pin on the Pico | a direct wire |
#
# Confirm all four connections are made, and note down anything that was fiddly.

# %% [markdown]
# nothing really

# %% [markdown]
# Q5. [Core] Justify the wiring. For each of the four connections in the table above, write one sentence explaining WHY that connection has to exist. What job does each wire do?

# %% [markdown]
# each wire connects the led to the raspberry pi chip

# %% [markdown]
# Q6. [Core] Why does each colour leg (R, G and B) need its own separate resistor, instead of one shared resistor on the COM pin? Think about what happens when two colours are switched on at the same time.

# %% [markdown]
# Each colour needs its own resistor because you can have multiple colours on at once. The resistors make sure each colour doesn't get too much current.

# %% [markdown]
# Q7. [Core] Open `diagram.json` again and find the `connections` section. Look at how your wiring is written down as text. Pick any one connection and explain what each part of that line means.

# %% [markdown]
# One connection line basically tells Wokwi what two pins are connected. For example, it might say GP15 is connected to one side of a resistor.

# %% [markdown]
# Q8. [Core] Draw the circuit. On paper, draw a labelled diagram of what you have built. Show the Pico, the three resistors, the RGB LED, and every wire. Label the GPIO numbers and mark which line goes to ground. Photograph it or describe it here.

# %% [markdown]
# My diagram has the Pico connected to three 220-ohm resistors. Each resistor goes to one of the RGB LED's colour pins, and the COM pin goes directly to GND

# %% [markdown]
# Q9. [Stretch] Swap one of the 220 ohm resistors for a 1000 ohm one and run a program that turns that colour on. What changes about the light? Explain why, thinking about what a resistor does to the flow of electricity.

# %% [markdown]
# The colour gets dimmer with the 1000-ohm resistor because a bigger resistor lets less current flow through the LED.

# %% [markdown]
# Q10. [Stretch] Remove the `"common": "cathode"` attribute so the LED goes back to being common anode. Run the same code. What happens, and why? This is called inverted logic. Put the attribute back afterwards.

# %% [markdown]
# The LED works backwards. Since it's common anode again, LOW turns the colour on instead of HIGH. That's why it's called inverted logic.

# %% [markdown]
# #### Section B: Part 1 - Theory: Colour, Resistors and PWM - Answer each question in your own words. Add a new markdown cell under this one for your answers.
# 1. [Core] What is an RGB LED, really? How many separate light sources are inside that one plastic package, and what colour is each one?
# 2. [Core] What is the difference between a common cathode and a common anode RGB LED? In each case, does the colour switch on when the GPIO pin is HIGH or when it is LOW?
# 3. [Core] Why does an LED need a current-limiting resistor? What would happen to a real LED connected straight to a pin with no resistor?
# 4. [Core] The resistors are 220 ohm. What does the word ohm measure? What would you expect to happen if you used a much larger resistor, such as 10000 ohm?
# 5. [Core] Colour mixing with light works differently from mixing paint. Predict what colour you get from: red and green together, red and blue together, green and blue together, and all three together.
# 6. [Core] If each of the three colour pins can only be fully on or fully off, how many different combinations are possible in total? Show your working. How many of those are actual visible colours?
# 7. [Core] What does PWM stand for, and what does it actually do to a pin? Explain the idea of a duty cycle in your own words.
# 8. [Core] A PWM pin is only ever fully on or fully off, yet the LED looks dimmer. Why does switching very fast make the light appear dimmer to your eyes rather than flickering?
# 9. [Core] In MicroPython, `duty_u16()` takes a number from 0 to 65535. What brightness would you expect from 0, from about 32768, and from 65535?
# 10. [Stretch] With PWM, each colour channel can take 65536 different levels instead of just 2. Roughly how many different colours does that make possible? Compare that to your answer for question 6.
# 11. [Stretch] In the simulator, an LED with no resistor is harmless. On a real Pico it is not. Explain the difference between what a simulator shows you and what real electronics does, and why that matters.
# 12. [Stretch] When would you choose simple digital on and off control for the LED, and when would you choose PWM? Give one example of each.

# %% [markdown]
# #[Core] What is an RGB LED, really? How many separate light sources are inside that one plastic package, and what colour is each one?
#
# An RGB LED is basically 3 LEDs in one. There is a red, green, and blue LED inside.

# %% [markdown]
# #[Core] What is the difference between a common cathode and a common anode RGB LED? In each case, does the colour switch on when the GPIO pin is
#
# A common cathode turns on when the pin is HIGH. A common anode turns on when the pin is LOW.

# %% [markdown]
# #[Core] Why does an LED need a current-limiting resistor? What would happen to a real LED connected straight to a pin with no resistor?
#
# The resistor stops too much current from going through the LED. Without one, the LED or Pico could get damaged.

# %% [markdown]
# #[Core] The resistors are 220 ohm. What does the word ohm measure? What would you expect to happen if you used a much larger resistor, such as 10000 ohm?
#
# An ohm measures resistance. A bigger resistor means less current, so a 10,000 ohm resistor would make the LED much dimmer.

# %% [markdown]
# #[Core] Colour mixing with light works differently from mixing paint. Predict what colour you get from: red and green together, red and blue together, green and blue together, and all three together.
#
# Red + Green = Yellow
# Red + Blue = magenta
# Green + Blue = cyan
# All three = White

# %% [markdown]
# #[Core] If each of the three colour pins can only be fully on or fully off, how many different combinations are possible in total? Show your working. How many of those are actual visible colours?
#
# There are 8 combinations because each colour has 2 choices (on or off):
# 2 × 2 × 2 = 8.
# 7 are visible colours, because one combination is all off.

# %% [markdown]
# #[Core] What does PWM stand for, and what does it actually do to a pin? Explain the idea of a duty cycle in your own words.
#
# PWM means Pulse Width Modulation. It turns the pin on and off really fast. The duty cycle is how much of the time it is on.

# %% [markdown]
# #[Core] A PWM pin is only ever fully on or fully off, yet the LED looks dimmer. Why does switching very fast make the light appear dimmer to your eyes rather than flickering?
#
# The LED is actually switching fully on and off very quickly.

# %% [markdown]
# #[Core] In MicroPython, `duty_u16()` takes a number from 0 to 65535. What brightness would you expect from 0, from about 32768, and from 65535?
#
# The range is 0 to 65535:
# 0 = 0% brightness / completely off
# 32768 = 50% brightness
# 65535 = 100% brightness / fully on

# %% [markdown]
# #[Stretch] With PWM, each colour channel can take 65536 different levels instead of just 2. Roughly how many different colours does that make possible? Compare that to your answer for question 6.
#
# There are three colour channels, so:
# 65,536 × 65,536 × 65,536 = 281,474,976,710,656

# %% [markdown]
# #[Stretch] In the simulator, an LED with no resistor is harmless. On a real Pico it is not. Explain the difference between what a simulator shows you and what real electronics does, and why that matters.
#
# A simulator is an approximation of real electronics. It may not model the dangerous amount of current that would flow through a real LED, or it may simply allow the LED to work without showing the damage.
# In real electronics, an LED has electrical properties that can allow too much current to flow if there is no resistor. This can damage the LED or the Pico's GPIO pin.

# %% [markdown]
# #[Stretch] When would you choose simple digital on and off control for the LED, and when would you choose PWM? Give one example of each.
#
# Simple on/off control: Use it when you only need the LED to be on or off.
# Example: A warning LED that turns on when a button is pressed.
# PWM: Use it when you want to control brightness or create different colours.
# Example: Slowly fading an LED from dim to bright, or mixing red and green to make different shades of yellow.

# %% [markdown]
# #### Section C: Part 1 - Predict, Reason and Code the RGB LED - Write your prediction first, then run it in Wokwi to check. For the coding tasks, paste your working code below.

# %% [markdown]
# Q1. [Core] Predict what colour the LED shows, then run it to check:
# ```python
# from machine import Pin
#
# red = Pin(15, Pin.OUT)
# green = Pin(14, Pin.OUT)
# blue = Pin(13, Pin.OUT)
#
# red.value(1)
# green.value(0)
# blue.value(0)
# ```

# %% [markdown]
# It should be red, because red is 1 and green and blue are 0.

# %% [markdown]
# Q2. [Core] Predict the colour, then run it:
# ```python
# red.value(1)
# green.value(1)
# blue.value(0)
# ```

# %% [markdown]
# It should be yellow, because red and green are both on.

# %% [markdown]
# Q3. [Core] Predict the colour, then run it:
# ```python
# red.value(1)
# green.value(1)
# blue.value(1)
# ```

# %% [markdown]
# It should be white, because all three colours are on.

# %% [markdown]
# Q4. [Stretch] Predict what you will see, then run it. Pay attention to brightness as well as colour:
# ```python
# from machine import Pin, PWM
#
# red = PWM(Pin(15))
# red.freq(1000)
# red.duty_u16(16384)
# ```

# %% [markdown]
# It should be a dim red. The PWM is only at about 25% duty cycle, so the red LED isn't on at full brightness.

# %% [markdown]
# Q5. [Core] Write a program that cycles the LED through red, then green, then blue, one second each, and repeats forever. Print the colour name to the serial monitor each time it changes.

# %% [markdown]
# from machine import Pin
# from time import sleep
#
# red = Pin(15, Pin.OUT)
# green = Pin(14, Pin.OUT)
# blue = Pin(13, Pin.OUT)
#
# while True:
#     red.value(1)
#     green.value(0)
#     blue.value(0)
#     print("Red")
#     sleep(1)
#
#     red.value(0)
#     green.value(1)
#     blue.value(0)
#     print("Green")
#     sleep(1)
#
#     red.value(0)
#     green.value(0)
#     blue.value(1)
#     print("Blue")
#     sleep(1)

# %% [markdown]
# Q6. [Core] Write a program that shows all seven visible colours in turn (red, green, blue, yellow, magenta, cyan and white), holding each for one second and printing its name. Use only digital on and off, no PWM.

# %% [markdown]
# from machine import Pin
# from time import sleep
#
# red = Pin(15, Pin.OUT)
# green = Pin(14, Pin.OUT)
# blue = Pin(13, Pin.OUT)
#
# while True:
#     red.value(1)
#     green.value(0)
#     blue.value(0)
#     print("Red")
#     sleep(1)
#
#     red.value(1)
#     green.value(1)
#     blue.value(0)
#     print("Yellow")
#     sleep(1)
#
#     red.value(0)
#     green.value(1)
#     blue.value(0)
#     print("Green")
#     sleep(1)
#
#     red.value(0)
#     green.value(1)
#     blue.value(1)
#     print("Cyan")
#     sleep(1)
#
#     red.value(0)
#     green.value(0)
#     blue.value(1)
#     print("Blue")
#     sleep(1)
#
#     red.value(1)
#     green.value(0)
#     blue.value(1)
#     print("Magenta")
#     sleep(1)
#
#     red.value(1)
#     green.value(1)
#     blue.value(1)
#     print("White")
#     sleep(1)

# %% [markdown]
# Q7. [Core] Use a dictionary to hold your colours, then loop through it. Start from this and complete it:
# ```python
# colours = {
#     "red":    (1, 0, 0),
#     "yellow": (1, 1, 0),
#     "cyan":   (0, 1, 1),
# }
# ```
# For each entry, print the colour name and switch the LED to that colour for one second. Hint: you can read the three values out of the tuple.

# %% [markdown]
# from machine import Pin
# from time import sleep
#
# red = Pin(15, Pin.OUT)
# green = Pin(14, Pin.OUT)
# blue = Pin(13, Pin.OUT)
#
# colours = {
#     "red":    (1, 0, 0),
#     "yellow": (1, 1, 0),
#     "cyan":   (0, 1, 1),
# }
#
# for name, values in colours.items():
#     r, g, b = values
#
#     print(name)
#
#     red.value(r)
#     green.value(g)
#     blue.value(b)
#
#     sleep(1)

# %% [markdown]
# Q8. [Stretch] Using PWM, make the red channel fade smoothly from completely off up to full brightness, then back down again. Use a loop with `range()` and a step, and remember `duty_u16()` goes up to 65535.

# %% [markdown]
# from machine import Pin, PWM
# from time import sleep
#
# red = PWM(Pin(15))
# red.freq(1000)
#
# while True:
#     for brightness in range(0, 65536, 1000):
#         red.duty_u16(brightness)
#         sleep(0.01)
#
#     for brightness in range(65535, -1, -1000):
#         red.duty_u16(brightness)
#         sleep(0.01)

# %% [markdown]
# Q9. [Stretch] Make a slow colour fade that blends from red into green and then into blue, using PWM on two channels at a time so the colours mix as they change.

# %% [markdown]
# from machine import Pin, PWM
# from time import sleep
#
# red = PWM(Pin(15))
# green = PWM(Pin(14))
# blue = PWM(Pin(13))
#
# red.freq(1000)
# green.freq(1000)
# blue.freq(1000)
#
# while True:
#     # Red to green
#     for x in range(0, 65536, 1000):
#         red.duty_u16(65535 - x)
#         green.duty_u16(x)
#         blue.duty_u16(0)
#         sleep(0.02)
#
#     # Green to blue
#     for x in range(0, 65536, 1000):
#         green.duty_u16(65535 - x)
#         blue.duty_u16(x)
#         red.duty_u16(0)
#         sleep(0.02)
#
#     # Blue to red
#     for x in range(0, 65536, 1000):
#         blue.duty_u16(65535 - x)
#         red.duty_u16(x)
#         green.duty_u16(0)
#         sleep(0.02)

# %% [markdown]
# Q10. [Stretch] Why does a PWM frequency of 1000 Hz work well for an LED, while a much lower frequency such as 5 Hz would look wrong? Try it and describe what you see.

# %% [markdown]
# 1000 Hz works well because it's so fast that our eyes don't notice the LED turning on and off. At 5 Hz, you can actually see it flickering because it turns on and off only 5 times per second.

# %% [markdown]
# #### Section D: Part 2 - Building the Ultrasonic Sensor Circuit - Add the sensor to the SAME project as your RGB LED. Do not start a new one.

# %% [markdown]
# Q1. [Core] In the SAME project, click `+` and add an HC-SR04 ultrasonic distance sensor. Describe what the part looks like and how many pins it has.

# %% [markdown]
# it looks like a boombox and has 4 pins

# %% [markdown]
# Q2. [Core] Wire the sensor using this connection table:
#
# | HC-SR04 pin | Connects to on the Pico |
# |---|---|
# | VCC | VBUS (the 5 volt supply) |
# | TRIG | GP17 |
# | ECHO | GP16 |
# | GND | Any GND pin |
#
# Confirm all four wires are connected. Note down which GND pin you used.

# %% [markdown]
# i used gnd 6

# %% [markdown]
# Q3. [Core] Justify the wiring again. For each of the four sensor connections, write one sentence saying why it is needed. Which two are about power, and which two are about information?

# %% [markdown]
# vcc is needed for the electricity trig and echo are needed for base wiring and gnd is needed for the pin that connects to the ground slot.  vcc and gnd are power, tric and echo are information

# %% [markdown]
# Q4. [Core] TRIG and ECHO both carry information, but in opposite directions. Which one is an OUTPUT from the Pico, and which one is an INPUT to the Pico? Explain how you can tell from what each one does.

# %% [markdown]
# TRIG is an output because the Pico sends a signal to the sensor through it. ECHO is an input because the sensor sends a signal back to the Pico through it.

# %% [markdown]
# Q5. [Core] Start the simulation, then click on the sensor in the diagram. A slider should appear that lets you set the distance to an imaginary object, anywhere from 2 cm to 400 cm. Try moving it. Why is a control like this useful when there is no real object in front of the sensor?

# %% [markdown]
# The slider is useful because there isn't actually an object in front of the sensor in the simulator. The slider lets you pretend there is an object at different distances so you can test if the program works.

# %% [markdown]
# Q6. [Core] Draw the complete circuit. Update your paper diagram so it now shows BOTH the RGB LED and the ultrasonic sensor connected to the same Pico. Label every pin. Photograph or describe it here.

# %% [markdown]
# My diagram shows the RGB LED and the ultrasonic sensor both connected to the same Pico. The ultrasonic sensor has VCC, TRIG, ECHO, and GND labeled, and the Pico GPIO pins connected to TRIG and ECHO are labeled too. The LED pins and their Pico connections are also labeled.

# %% [markdown]
# Q7. [Core] Open `diagram.json` and count how many entries are now in the `connections` list. Does the number match the number of wires you drew? Explain any difference.

# %% [markdown]
# The number should mostly match the number of wires I drew. If it doesn't, that's because diagram.json can count some connections separately even if they look like one wire on the diagram.

# %% [markdown]
# Q8. [Stretch] [Research] A real HC-SR04 runs on 5 volts, and its ECHO pin sends out 5 volts. The Pico's GPIO pins are designed for 3.3 volts. Find out why this is a problem on real hardware, what a voltage divider is, and why you did not have to worry about it in the simulator.

# %% [markdown]
# The real HC-SR04 uses 5 volts, but the Pico's GPIO pins use 3.3 volts. So the 5 V signal from ECHO could damage the Pico. A voltage divider uses two resistors to lower the voltage to a safer level, like 3.3 V. We don't have to worry about it in the simulator because it isn't actually sending 5 V into a real Pico.

# %% [markdown]
# #### Section E: Part 2 - Theory: How Ultrasonic Distance Sensing Works - Answer in your own words. Several of these need paper and a pencil. Show your working for every calculation.
# 1. [Core] In your own words, explain how an ultrasonic sensor measures distance without touching anything. Describe the whole journey of the sound.
# 2. [Core] The sensor uses sound at 40 kHz. Human hearing stops at roughly 20 kHz. What does the word ultrasonic mean, and why can you not hear the sensor working?
# 3. [Core] Which animals use this same trick to find their way and hunt in the dark? Name at least two, and say what the technique is called.
# 4. [Core] What is the TRIG pin for? How long does the Pico hold it HIGH, and what does the sensor do the moment that pulse ends?
# 5. [Core] What does the ECHO pin do? Explain exactly what the length of time it stays HIGH represents.
# 6. [Core] Sound travels through air at about 343 metres per second. Convert that into centimetres per microsecond. Show your working. You should end up with a small decimal number.
# 7. [Core] The formula for the distance is `duration * 0.0343 / 2`. The most important part of this formula is the divide by 2. Explain why it has to be there. What journey did the sound actually make?
# 8. [Core] Work this out by hand, on paper. If the ECHO pin stays HIGH for 1000 microseconds, how far away is the object in centimetres? Show every step of your calculation.
# 9. [Core] Now work backwards. If an object is 50 cm away, roughly how long will the ECHO pin stay HIGH? Show your working.
# 10. [Stretch] What happens if the sound is sent out and nothing ever reflects back? Explain why the code needs a timeout, and what would happen without one.
# 11. [Stretch] The sensor only works reliably between about 2 cm and 400 cm. Suggest a reason for the minimum limit, and a reason for the maximum limit.
# 12. [Stretch] The speed of sound changes when the air temperature changes. What effect would a very hot or very cold day have on the readings, and how might you correct for it?
# 13. [Stretch] [Research] Astronomers measure distances to the Moon and to planets using almost exactly this idea, but with a different kind of wave. Find out how lunar laser ranging or planetary radar works, and explain what is the same and what is different compared to your sensor.

# %% [markdown]
# #[Core] In your own words, explain how an ultrasonic sensor measures distance without touching anything. Describe the whole journey of the sound.
#
# the sensor uses echo-location. it sends out a sound wave. The sound travels through the air until it hits an object, then bounces back to the sensor. The sensor measures how long it took for the sound to come back and uses that time to figure out how far away the object is.

# %% [markdown]
# #[Core] The sensor uses sound at 40 kHz. Human hearing stops at roughly 20 kHz. What does the word ultrasonic mean, and why can you not hear the sensor working?
#
# ultrasonic refers to a frequency that surpasses what humans define as "sonic" which is also known as what the soundwaves humans can hear are called. we cant hear 40 kilohertz because it is beyond our maximum hearing capability of 20 kilohertz

# %% [markdown]
# #[Core] Which animals use this same trick to find their way and hunt in the dark? Name at least two, and say what the technique is called.
#
# Bats and dolphins use this technique. It is called echolocation.

# %% [markdown]
# #[Core] What is the TRIG pin for? How long does the Pico hold it HIGH, and what does the sensor do the moment that pulse ends?
#
# The TRIG pin tells the sensor to start measuring. The Pico holds it HIGH for about 10 microseconds. When the pulse ends, the sensor sends out the ultrasonic sound.

# %% [markdown]
# #[Core] What does the ECHO pin do? Explain exactly what the length of time it stays HIGH represents.
#
# The ECHO pin tells the Pico how long the sound took to come back. It stays HIGH for the amount of time between the sound being sent out and the echo returning.

# %% [markdown]
# #[Core] Sound travels through air at about 343 metres per second. Convert that into centimetres per microsecond. Show your working. You should end up with a small decimal number.
#
# Sound travels at 343 metres per second.
# 343 m = 34,300 cm
# 1 second = 1,000,000 microseconds
# 34,300 ÷ 1,000,000 = 0.0343 cm/µs
# So the answer is 0.0343 centimetres per microsecond.

# %% [markdown]
# #[Core] The formula for the distance is duration * 0.0343 / 2. The most important part of this formula is the divide by 2. Explain why it has to be there. What journey did the sound actually make?
#
# The sound travels to the object and then back to the sensor. So the time measured is for twice the distance. We divide by 2 to get just the distance from the sensor to the object.

# %% [markdown]
# #[Core] [Core] Work this out by hand, on paper. If the ECHO pin stays HIGH for 1000 microseconds, how far away is the object in centimetres? Show every step of your calculation.
#
# Formula:
# distance = duration × 0.0343 ÷ 2
# distance = 1000 × 0.0343 ÷ 2
# distance = 34.3 ÷ 2
# distance = 17.15 cm
# So the object is 17.15 cm away.

# %% [markdown]
# #[Core] Now work backwards. If an object is 50 cm away, roughly how long will the ECHO pin stay HIGH? Show your working.
#
# Starting with:
# distance = duration × 0.0343 ÷ 2
# For 50 cm:
# 50 = duration × 0.0343 ÷ 2
# Multiply by 2:
# 100 = duration × 0.0343
# Divide by 0.0343:
# duration ≈ 2915 µs
# So the ECHO pin stays HIGH for about 2,915 microseconds.

# %% [markdown]
# #[Stretch] What happens if the sound is sent out and nothing ever reflects back? Explain why the code needs a timeout, and what would happen without one.
#
# If nothing reflects the sound back, the ECHO signal could wait forever. The code needs a timeout so it eventually stops waiting and continues running. Without a timeout, the program could get stuck waiting for an echo that never comes.

# %% [markdown]
# #[Stretch] The sensor only works reliably between about 2 cm and 400 cm. Suggest a reason for the minimum limit, and a reason for the maximum limit.
#
# The minimum limit could be because an object that is too close doesn't give the sensor enough time to send and receive the sound properly. The maximum limit is because the sound gets weaker as it travels farther and the sensor might not detect the echo.

# %% [markdown]
# #[Stretch] The speed of sound changes when the air temperature changes. What effect would a very hot or very cold day have on the readings, and how might you correct for it?
#
# Temperature changes the speed of sound. On a hot day, sound travels a little faster, and on a cold day it travels a little slower. This can make the distance reading slightly inaccurate. You could correct it by adjusting the speed-of-sound value in the calculation based on the air temperature.

# %% [markdown]
# #[Stretch] [Research] Astronomers measure distances to the Moon and to planets using almost exactly this idea, but with a different kind of wave. Find out how lunar laser ranging or planetary radar works, and explain what is the same and what is different compared to your sensor.
#
# Lunar laser ranging works in a similar way because scientists send a signal to something far away and measure how long it takes to come back. With the Moon, lasers are sent from Earth to reflectors on the Moon, and scientists measure the return time to calculate the distance.
# The main difference is that the ultrasonic sensor uses sound waves, while lunar laser ranging uses light. The distances are also much bigger, so the timing has to be extremely precise.

# %% [markdown]
# #### Section F: Part 2 - Predict, Reason and Code the Sensor - Predict first where asked, then build and run. Paste your working code below each task.

# %% [markdown]
# Q1. [Core] Read this measuring code carefully, then predict what one reading would print if the slider is set to about 100 cm:
# ```python
# from machine import Pin, time_pulse_us
# import time
#
# trigger = Pin(17, Pin.OUT)
# echo = Pin(16, Pin.IN)
#
# trigger.value(0)
# time.sleep_us(5)
# trigger.value(1)
# time.sleep_us(10)
# trigger.value(0)
#
# duration = time_pulse_us(echo, 1, 30000)
# distance = duration * 0.0343 / 2
# print(distance)
# ```

# %% [markdown]
# it would print 100

# %% [markdown]
# Q2. [Core] Look at the code above again. Explain what each of these three lines is doing and why the order matters: setting the trigger to 0, then to 1 for 10 microseconds, then back to 0.

# %% [markdown]
# the first line keeps the trigger at 0, then at 1 for 10 millisecond and then back to 0
#
# trigger.value(0)
#
# trigger.value(1)
# time.sleep_us(10)
#
# trigger.value(0)

# %% [markdown]
# Q3. [Core] What does `time_pulse_us(echo, 1, 30000)` do? What is the `1` asking it to wait for, and what is the `30000` protecting against?

# %% [markdown]
# time_pulse_us(echo, 1, 30000) This measures how long the echo pin stays at the specified level. the timeout ensures that the program doesnt wait for the echo forever if it doesnt recieve one

# %% [markdown]
# Q4. [Core] Build it and run it. Take a single distance reading and print it. Move the slider to three different distances and record the three readings you get.

# %% [markdown]
# from machine import Pin, time_pulse_us
# import time
#
# trigger = Pin(17, Pin.OUT)
# echo = Pin(16, Pin.IN)
#
# trigger.value(0)
# time.sleep_us(5)
# trigger.value(1)
# time.sleep_us(10)
# trigger.value(0)
#
# duration = time_pulse_us(echo, 1, 30000)
# distance = duration * 0.0343 / 2
#
# print(distance)
#
# 19.1737
# 51.45
# 98.86975

# %% [markdown]
# Q5. [Core] Now make it continuous: take a reading once every second, forever, and print each one. Remember you stop it with the red Stop button.

# %% [markdown]
# from machine import Pin, time_pulse_us
# import time
#
# trigger = Pin(17, Pin.OUT)
# echo = Pin(16, Pin.IN)
#
# while True:
#     trigger.value(0)
#     time.sleep_us(5)
#     trigger.value(1)
#     time.sleep_us(10)
#     trigger.value(0)
#
#     duration = time_pulse_us(echo, 1, 30000)
#     distance = duration * 0.0343 / 2
#
#     print(distance)
#     time.sleep(1)

# %% [markdown]
# Q6. [Core] Tidy up the output. Round the distance to one decimal place and print it in a friendly sentence using an f-string, for example showing the distance in centimetres with a label.

# %% [markdown]
# distance = duration * 0.0343 / 2
# print(f"Distance: {distance:.1f} cm")

# %% [markdown]
# Q7. [Core] Add decision-making. Using `if`, `elif` and `else`, print `Object very close` below 20 cm, `Object nearby` from 20 up to 100 cm, and `All clear` above that. Keep taking readings continuously.

# %% [markdown]
# from machine import Pin, time_pulse_us
# import time
#
# trigger = Pin(17, Pin.OUT)
# echo = Pin(16, Pin.IN)
#
# while True:
#     trigger.value(0)
#     time.sleep_us(5)
#     trigger.value(1)
#     time.sleep_us(10)
#     trigger.value(0)
#
#     duration = time_pulse_us(echo, 1, 30000)
#     distance = duration * 0.0343 / 2
#
#     print(f"Distance: {distance:.1f} cm")
#
#     if distance < 20:
#         print("Object very close")
#     elif distance <= 100:
#         print("Object nearby")
#     else:
#         print("All clear")
#
#     time.sleep(1)

# %% [markdown]
# Q8. [Stretch] Rewrite the zone decision from the previous task using a `match` statement with guards, instead of `if` and `elif`. Which version do you find easier to read?

# %% [markdown]
# match distance:
#     case x if x < 20:
#         print("Object very close")
#     case x if x <= 100:
#         print("Object nearby")
#     case _:
#         print("All clear")

# %% [markdown]
# Q9. [Stretch] Keep track of the closest reading seen since the program started. Print the current distance and the record-closest distance each time. Hint: you will need a variable that survives outside the loop.

# %% [markdown]
# closest = float("inf")
#
# while True:
#     trigger.value(0)
#     time.sleep_us(5)
#     trigger.value(1)
#     time.sleep_us(10)
#     trigger.value(0)
#
#     duration = time_pulse_us(echo, 1, 30000)
#     distance = duration * 0.0343 / 2
#
#     if distance < closest:
#         closest = distance
#
#     print(f"Current distance: {distance:.1f} cm")
#     print(f"Closest distance: {closest:.1f} cm")
#
#     time.sleep(1)

# %% [markdown]
# Q10. [Stretch] What would go wrong if you took readings with no delay at all between them, as fast as the Pico could manage? Think about the sound from the previous reading still bouncing around.

# %% [markdown]
# If you took readings as fast as possible with no delay, the sensor could start another measurement before echoes from the previous measurement have completely died away, and that could cause the sensor to detect an old echo as if it were a new echo.

# %% [markdown]
# #### Section G: Combined Mini Projects - Both circuits working together: a sensor that decides, and a light that reports. Paste your code and your project share link.

# %% [markdown]
# Q1. [Core] Distance Traffic Light. Combine both circuits: take a distance reading continuously, and set the RGB LED to green when the object is far away (over 100 cm), yellow when it is nearby (20 to 100 cm), and red when it is very close (under 20 cm). Print the distance and the colour each time.

# %% [markdown]
# from machine import Pin, time_pulse_us
# import time
#
# trigger = Pin(17, Pin.OUT)
# echo = Pin(16, Pin.IN)
#
# red = Pin(13, Pin.OUT)
# green = Pin(14, Pin.OUT)
# blue = Pin(15, Pin.OUT)
#
# while True:
#
#     trigger.value(0)
#     time.sleep_us(5)
#     trigger.value(1)
#     time.sleep_us(10)
#     trigger.value(0)
#
#     duration = time_pulse_us(echo, 1, 30000)
#     distance = duration * 0.0343 / 2
#
#     red.value(0)
#     green.value(0)
#     blue.value(0)
#
#     if distance < 20:
#         red.value(1)
#         colour = "red"
#     elif distance <= 100:
#         red.value(1)
#         green.value(1)
#         colour = "yellow"
#     else:
#         green.value(1)
#         colour = "green"
#
#     print(f"Distance: {distance:.1f} cm | Colour: {colour}")
#
#     time.sleep(1)

# %% [markdown]
# Q2. [Core] Asteroid Proximity Alarm. Make the LED blink red, and make it blink FASTER the closer the object gets. Hint: use the distance value to work out the delay in your blink.

# %% [markdown]
# from machine import Pin, time_pulse_us
# import time
#
# trigger = Pin(17, Pin.OUT)
# echo = Pin(16, Pin.IN)
# red = Pin(13, Pin.OUT)
#
# while True:
#     trigger.value(0)
#     time.sleep_us(5)
#     trigger.value(1)
#     time.sleep_us(10)
#     trigger.value(0)
#
#     duration = time_pulse_us(echo, 1, 30000)
#     distance = duration * 0.0343 / 2
#
#     delay = max(0.05, min(1.0, distance / 100))
#
#     red.value(1)
#     time.sleep(delay)
#     red.value(0)
#     time.sleep(delay)
#
#     print(f"Distance: {distance:.1f} cm")

# %% [markdown]
# Q3. [Stretch] Smooth Colour Ranging. Instead of three fixed colours, use PWM so the colour blends smoothly from green through to red as the object comes closer. Describe how you turned a distance into a duty value.

# %% [markdown]
# from machine import Pin, PWM, time_pulse_us
# import time
#
# trigger = Pin(17, Pin.OUT)
# echo = Pin(16, Pin.IN)
#
# red = PWM(Pin(13))
# green = PWM(Pin(14))
#
# red.freq(1000)
# green.freq(1000)
#
# while True:
#     trigger.value(0)
#     time.sleep_us(5)
#     trigger.value(1)
#     time.sleep_us(10)
#     trigger.value(0)
#
#     duration = time_pulse_us(echo, 1, 30000)
#     distance = duration * 0.0343 / 2
#
#     # Limit distance to 20-100 cm
#     d = max(20, min(100, distance))
#
#     # Convert distance into a 0-65535 duty value
#     red_duty = int((100 - d) / 80 * 65535)
#     green_duty = int((d - 20) / 80 * 65535)
#
#     red.duty_u16(red_duty)
#     green.duty_u16(green_duty)
#
#     print(f"Distance: {distance:.1f} cm")
#
#     time.sleep(0.1)

# %% [markdown]
# Q4. [Stretch] Docking Assistant. Print a simple bar made of characters that gets longer or shorter with the distance, for example a row of `#` symbols, so the serial monitor shows a moving gauge alongside the colour.

# %% [markdown]
# bar_length = int(distance / 10)
# bar_length = max(0, min(40, bar_length))
#
# bar = "#" * bar_length
#
# print(f"{distance:.1f} cm | {bar}")

# %% [markdown]
# Q5. [Stretch] Make it your own. Invent a use for these two components together that we have not covered, build it, and describe what it does and why you chose it.

# %% [markdown]
# from machine import Pin, time_pulse_us
# import time
#
# trigger = Pin(17, Pin.OUT)
# echo = Pin(16, Pin.IN)
#
# red = Pin(13, Pin.OUT)
# green = Pin(14, Pin.OUT)
#
# while True:
#     trigger.value(0)
#     time.sleep_us(5)
#     trigger.value(1)
#     time.sleep_us(10)
#     trigger.value(0)
#
#     duration = time_pulse_us(echo, 1, 30000)
#     distance = duration * 0.0343 / 2
#
#     if distance < 50:
#         red.value(1)
#         green.value(0)
#         print("Someone is nearby!")
#     else:
#         red.value(0)
#         green.value(1)
#         print("All clear!")
#
#     time.sleep(1)
#
#
#     I made a parking sensor. The LED turns green when there is lots of space, yellow when the car gets closer, and red when it is really close. I chose this because i think it is an interesting part of a car that i would like to recreate via code.

# %% [markdown]
# Q6. [Core] Reflection. Almost every robot and spacecraft works on the same three-step loop: sense something, decide what it means, then act on it. Point out exactly which lines of your Distance Traffic Light program do each of those three steps. Then, in three to five sentences, explain to a friend what you built and what surprised you.

# %% [markdown]
# from machine import Pin, time_pulse_us
# import time
#
# # Distance sensor
# trigger = Pin(17, Pin.OUT)
# echo = Pin(16, Pin.IN)
#
# # RGB LED
# red = Pin(13, Pin.OUT)
# green = Pin(14, Pin.OUT)
# blue = Pin(15, Pin.OUT)
#
# while True:
#     # SENSE: take a distance reading
#     trigger.value(0)
#     time.sleep_us(5)
#
#     trigger.value(1)
#     time.sleep_us(10)
#
#     trigger.value(0)
#
#     duration = time_pulse_us(echo, 1, 30000)
#     distance = duration * 0.0343 / 2
#
#     # Turn all colours off first
#     red.value(0)
#     green.value(0)
#     blue.value(0)
#
#     # DECIDE: choose a colour based on distance
#     if distance < 20:
#         red.value(1)
#         colour = "red"
#
#     elif distance <= 100:
#         red.value(1)
#         green.value(1)
#         colour = "yellow"
#
#     else:
#         green.value(1)
#         colour = "green"
#
#     # ACT: print what happened
#     print(f"Distance: {distance:.1f} cm | Colour: {colour}")
#
#     time.sleep(1)
#
#    sense: duration = time_pulse_us(echo, 1, 30000)
# distance = duration * 0.0343 / 2
#
# decide: if distance < 20:
# elif distance <= 100:
# else:
#
# act: red.value(1)
# green.value(1)
#
# I built a distance traffic light using an ultrasonic distance sensor and an RGB LED. The sensor measures how far away an object is, and the LED changes between red, yellow, and green depending on the distance. I was surprised that the sensor readings were not always exactly the same as the slider setting. I learned that the program constantly senses the distance, decides which zone it is in, and then controls the LED.
