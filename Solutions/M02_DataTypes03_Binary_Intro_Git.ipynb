# %% [markdown]
# #### Binary Number System
# **Q1. What are binary number? Why do we/ machine need it?**
# <br>
# **Q2. Analogy for binary values `0` and `1`, with respect to, electrical engineering, digital electronics, and boolean values.**
# <br>
# **Q3. Explain Logical operators - `and`, `or`, `not` - from binary point of view. Aslo understand truth table of each operator (You should be in a position to explain it to a 5 year old kid)**
# <br>
# **Q4. Provide examples from real world where, `and`, `not`, `or` logical operations will be used - at least 2 examples each**
# <br>
# **Q5. Convert the following `int` values into `binary`. 5, 24, 32, 77, 145. Also provide the python code for this conversion**
# <br>
# **Q6. Convert the following `binary` numbers into `int` values. 'b1100, 'b0011 0111, 'b1111 1101. Also provide the python code for this conversion**
# <br>
# **Q7. Go through the assignment in operators (previous week's assignment). You should be able to explain from Q5 - Q20 (from last week)**
#
# **Note:** Answers for each question should be in a different cell. Use markdown language and not print statement (exception: Use python code cell only for writing programs)

# %% [markdown]
# Binary numbers are 1s and 0s used to better communicate with a computer

# %% [markdown]
# in boolean, 1 is true and 0 is false, in digital electronics 1 is active, and 0 is inactive, and in electrical engineering, 1 is high voltage, and 0 is low voltage

# %% [markdown]
# if you take the example of a light switch, and, is when you have turn on at least two light switches when you want to turn on one, or, is when you can choose which to turn on, and ,not, is when you cannot turn on the light switch you want to turn on

# %% [markdown]
# in the real world and, or, and not operators are used in things like digital purchases, and questions being asked online

# %% [markdown]
# b101,b11000,b100000,b1001101,b10010001

# %% [markdown]
# 12,55,

# %% [markdown]
# #### Git
# **Task 1: Understand what is Git and why do we need it.**
# <br>
# **Task 2: Create your Git acccount**
# <br>
# **Task 3: Create a `private` repo - name it `Python_Basics`**
# <br>
# **Task 4: Create a folder structure as follows**
# ```
# Python_Basics
#     - Assignments
#         - Assignment-1
#             - upload all the solutions from assignemnt 1 *.ipynb
#         - Assignemnt-2
#             - upload all the solutions from assignemnt 2 *.ipynb
#
# and so on
# ```
# **Task 5: Understand `git init`, `git add`, `git commit` and `git push` commands**
# <br>
# **Task 6: Push the folder strucutre from task 4 into your private `Python_Basic` repository**
